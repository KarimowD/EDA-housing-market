# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <hr>
#
# <a href=""><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="This will be active in Solution Notebook"></a>
#
# <a href="" style="float: right" target="_blank">
#     <img src="https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg" alt="Open in nbbviewer" title="This will be active in Solution Notebook">
# </a><br>
#
# <a href=""><img align="center" width="80" height="80" src="https://i.ibb.co/Vqpq8gQ/Git-Hub-logo.png" alt="Open in Colab" title="This will be active in Solution Notebook"></a>
#
# <hr>
#
# <a href="https://clarusway.com/"><img align="center" src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="450" height="200" alt="CLRSWY_LOGO" title="Open and Execute in Google Colaboratory"></a><br/>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid" alt="CLRSWY_Courses"></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#E51A59; font-size:175%; text-align:center; border-radius:10px 10px;">DA&DVwPy RECAP Session</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/VjXymdr/OC-Global-Happiness-Share.jpg" class="img-fluid" alt="CLRSWY_Courses" width="800" height="200"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#E51A59; font-size:175%; text-align:center; border-radius:10px 10px;">Global Happiness Levels</p>
#
# [Image Credit](https://www.visualcapitalist.com/mapped-global-happiness-levels-in-2022/)
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK</p>

# %%
import pandas as pd  # DAwPy
import numpy as np   # DAwPy

pd.set_option('display.float_format', lambda x: '%.2f' % x)  # sets a display option for formatting floating-point numbers in Pandas DataFrame objects.
# from skimpy import clean_columns, skim  # provides summary results for a dataset.
                                        # helps to address the issue of messy Pandas column names.

import matplotlib.pyplot as plt  # DVwPy
import seaborn as sns            # Stats-1 & DAwPy

from colorama import Fore  # Colorama provides cross-platform support for colored terminal text in Python.
                           # Fore provides a class to change the text color in the terminal.

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

params = {
          'figure.figsize':(12, 5),
          'figure.titlesize':20,
          'font.size': 15,
          'axes.titlesize': 20,
          'axes.labelsize': 15,
          'xtick.labelsize': 15,
          'ytick.labelsize': 15,
          'legend.fontsize': 15,
          'boxplot.showmeans': True,
          'boxplot.meanprops.marker': 'o',
          'boxplot.meanprops.markeredgecolor': 'r',
          'boxplot.meanprops.markerfacecolor': 'w',
          'boxplot.meanprops.markersize': 10.1,
          }

# print(plt.style.library)
plt.rcParams.update(params)  # used to update the default configuration parameters of the current matplotlib session.
# plt.rcParams.update(plt.rcParamsDefault)
# print(plt.rcParams['figure.figsize'])

# pip install scipy
# pip install scikit-learn
from scipy import stats # contains statistical functions for performing statistical tests. (mode, skewness, kurtosis, IQR)

# %% [markdown]
# - **``Importing Libraries``**: Make sure to import the required libraries before beginning your analysis. You need both pandas and numpy.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - **``import warnings``**: This imports the warnings module, which is part of Python's standard library and provides a way to issue warning messages.
# - **``warnings.filterwarnings("ignore")``**: This function call tells Python to ignore all warning messages that would normally be printed. This can be useful when we want to focus on the output of your program without being distracted by warnings.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>📢 Caution ❗❗❗</strong></p>
#
#
# - Ignoring warnings can sometimes hide important issues in our code, so use this approach judiciously. It's generally better to address the underlying causes of warnings rather than suppressing them.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Before going further, let's explore which versions of the libraries will be used in this analysis :**

# %%
import pandas as pd    # DAwPy
import numpy as np     # DAwPy
import seaborn as sns  # Stats-1 & DAwPy
import matplotlib      # Stats-1 & DAwPy
import scipy           # Stats-1 & DAwPy

# Print the versions of the libraries
print("Pandas version:", pd.__version__)             
print("NumPy version:", np.__version__)                
print("Seaborn version:", sns.__version__)            
print("Matplotlib version:", matplotlib.__version__) 
print("Scipy version:", scipy.__version__)
# Out:
# Pandas version: 1.5.3
# NumPy version: 1.23.5
# Seaborn version: 0.12.2
# Matplotlib version: 3.5.3
# Scipy version: 1.10.1

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:115%; text-align:left;"><strong>👉 About Dataset:</strong></p>
#
# #### Context:
#
# **[The World Happiness Report](https://worldhappiness.report/about/#:~:text=They%20include%20GDP%20per%20capita,freedom%2C%20generosity%2C%20and%20corruption.)** is a landmark survey of the state of global happiness. The World Happiness Report is a project of the United Nations Sustainable Development Solutions Network (SDSN). It is an **``annual publication``** that aims to **``assess and compare the happiness levels of countries worldwide``**. The **``first report``** was published in **``2012``**, the second in ``2013``, the third in ``2015``, and the fourth in the ``2016`` Update. The World Happiness ``2017``, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th.
#
# The World Happiness Report attempts to **``measure the happiness level of countries by using various factors``**. These factors include **``income levels``**, **``social support``**, **``life expectancy``**, **``freedom``**, **``generosity``**, **``corruption levels``**, and **``social support``**. The report **``ranks countries using the "Happiness Score"``** derived from the combination of these indicators.
#
# The purpose of the report is to encourage policymakers and community leaders to develop policies that promote happiness. It also aims to **``understand the relationship between happiness and social, economic, and environmental factors by identifying and comparing happiness levels across different countries``**.
#
# The World Happiness Report is created by analyzing various data sources. Data obtained from surveys, databases, and other sources are used to determine the happiness levels of countries. The report provides a ranking among countries and **``highlights specific factors that influence happiness levels``**.
#
# The World Happiness Report is considered an important resource to guide governments in the policy-making process and enhance the well-being of societies. It has become a widely recognized reference worldwide and contributes to the development of effective policies that impact happiness.
#
# #### Content:
#
# The happiness scores and rankings use data from the **[Gallup World Poll](https://www.gallup.com/analytics/318875/global-research.aspx)**. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have NO impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# - **[🧐 World Happiness Report 2015](https://www.kaggle.com/datasets/unsdsn/world-happiness)**<br>
# - **[🧐 World Happiness Report 2015-2022](https://www.kaggle.com/datasets/shivkumarganesh/world-happiness-report-20152022)**<br>
# - **[🧐 World Happiness Report 2021](https://www.kaggle.com/datasets/ajaypalsinghlo/world-happiness-report-2021)**<br>
# - **[🧐 World Happiness Report 2022](https://www.kaggle.com/datasets/mathurinache/world-happiness-report)**<br>
# - **[🧐 World Happiness Report 2023](https://www.kaggle.com/datasets/ajaypalsinghlo/world-happiness-report-2023)**<br>
#
# #### Inspiration
#
# - What countries or regions rank the highest in overall happiness and each of the seven factors contributing to happiness?
# - How did country ranks or scores change in 2017 report?
# - Did any country experience a significant increase or decrease in happiness?
#
# #### What is Dystopia?
#
# **[Dystopia](https://en.wikipedia.org/wiki/Dystopia)** is an **``imaginary country``** that has the **``world’s least-happy people``**. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. **``The lowest scores observed for the six key variables, therefore, characterize Dystopia``**. Since **``life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support``**, it is referred to as **``“Dystopia,”``** in contrast to Utopia. Additionally, dystopia was used as an antonym for **[Utopia](https://en.wikipedia.org/wiki/Utopia)** by **[John Stuart Mill](https://en.wikipedia.org/wiki/John_Stuart_Mill)** in one of his 1868 Parliamentary Speeches (Hansard Commons) by adding the prefix "dys" (Ancient Greek: δυσ- "bad") to "topia"

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:115%; text-align:left;"><strong>👉 Today's Agenda:</strong></p>
#
#  - **Adding and Dropping Columns & Rows**
#  - **Index methods**
#  - **Updating & Modifying Rows**
#  - **Groupby Operations**
#  - **Conditional Selection**
#  - **Handling Missing Data & Outliers**
#  - **Some Bonuses**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Reading From CSV</p>
#
# To read data from a CSV file in pandas, we use the **``pd.read_csv()``** function. This function imports the CSV file into a DataFrame, allowing for easy data manipulation and analysis. We can customize the reading process with parameters such as **``sep``** parameter for **``delimiters``**, **``header``** parameter for **``specifying header rows``**, **``index_col``** parameter for setting the DataFrame **``index``**, and **``na_values``** parameter to **``define additional missing value indicators``**.

# %%
# Read the CSV file into a DataFrame
df0 = pd.read_csv('world-happiness-report-2021.csv')

# Display the DataFrame
df0
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe          7.84
# 1        Denmark      Western Europe          7.62
# 2    Switzerland      Western Europe          7.57
# 3        Iceland      Western Europe          7.55
# 4    Netherlands      Western Europe          7.46
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa          3.51
# 145     Botswana  Sub-Saharan Africa          3.47
# 146       Rwanda  Sub-Saharan Africa          3.42
# 147     Zimbabwe  Sub-Saharan Africa          3.15
# 148  Afghanistan          South Asia          2.52
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                              0.03          7.90          7.78
# 1                              0.04          7.69          7.55
# 2                              0.04          7.64          7.50
# 3                              0.06          7.67          7.44
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:140%; text-align:left;"><strong>👉 The Criteria for Filtering the Dataset for our Analysis:</strong></p>
#
#
# ### Selected Variables:
#
# **``The columns following the happiness score estimate the extent to which each of seven factors``**
# - ladder score,
# - logged GDP per capita,
# - social support,
# - healthy life expectancy,
# - freedom to make life choices,
# - generosity, and perceptions of corruption
#
# **``contribute to making life evaluations higher``** in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the seven factors. They have no impact on the total score reported for each country, but they might explain why some countries would rank higher than others.
#
# - **Ladder score** - ``Happiness score`` or ``subjective well-being``. This is the national average response to the question of life evaluations.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;">👉 Question: Please imagine a ladder, with steps numbered from 0 at the bottom to 10 at the top. The top of the ladder represents the best possible life for you and the bottom of the ladder represents the worst possible life for you. On which step of the ladder would you say you personally feel you stand at this time?</p>
#
#
# **Question:** Please imagine a ladder, with steps numbered from 0 at the bottom to 10 at the top. The top of the ladder represents the best possible life for you and the bottom of the ladder represents the worst possible life for you. On which step of the ladder would you say you personally feel you stand at this time?
#
# - **``Logged GDP per capita``** - The Gross Domestic Product (GDP)-per-capita time series from 2019 to 2020 using countryspecific forecasts of real GDP growth in 2020.
#
# - **``Social support``** - Is the national average of the binary responses (either 0 or 1) to the GWP question:
#   - “If you were in trouble, do you have relatives or friends you can count on to help you whenever you need them, or not.
#
# - **``Healthy life expectancy``** - Healthy life expectancies at birth are based on the data extracted from the World Health Organization’s (WHO) Global Health Observatory data repository (Last updated: 2020-09-28)
#
# - **``Freedom to make life choices``** - Is is the national average of responses to the GWP question:
#   - “Are you satisfied or dissatisfied with your freedom to choose what you do with your life?
#
# - **``Generosity``** - Generosity is the residual of regressing national average of response to the GWP question:
#   - “Have you donated money to a charity in the past month?” on GDP per capita. **[A Discussion on Generosity in the World Happiness Score](https://psychology.stackexchange.com/questions/23215/generosity-in-the-world-happiness-score)**
#
# - **``Perceptions of corruption``** - The measure is the national average of the survey responses to two questions in the GWP:
#   - “Is corruption widespread throughout the government or not”? and
#   - “Is corruption widespread within businesses or not?”
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **To select specific variables from the World Happiness Report DataFrame and set the index to the country names, we can follow these steps.**

# %%
df0.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
# Select relevant columns and create a new DataFrame
df = df0[['Country name', 'Regional indicator',
          'Ladder score', 'Logged GDP per capita',
          'Social support', 'Healthy life expectancy',
          'Freedom to make life choices', 'Generosity',
          'Perceptions of corruption']].copy()

# Set the index to 'Country name'
df.set_index('Country name', inplace=True)

# Display the resulting DataFrame
df
# Out:
#               Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Finland           Western Europe          7.84                  10.78
# Denmark           Western Europe          7.62                  10.93
# Switzerland       Western Europe          7.57                  11.12
# Iceland           Western Europe          7.55                  10.88
# Netherlands       Western Europe          7.46                  10.93
# ...                          ...           ...                    ...
# Lesotho       Sub-Saharan Africa          3.51                   7.93
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Modifying the columns names</p>
#
# Modifying column names in a pandas DataFrame is a crucial step in data cleaning and preprocessing, enhancing clarity and usability. By using methods such as rename(), columns, or set_axis(), users can easily change column names to more meaningful or standardized labels, which aids in better understanding and analysis of the data. This process can include correcting typos, changing cases, or making names more descriptive, thereby facilitating easier access and manipulation of the DataFrame. Consistent and clear column names improve the readability of code and make it simpler for others to interpret the dataset, ultimately leading to more effective data analysis and visualization.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:115%; text-align:left;"><strong>🎁 BONUS APPROACH:</strong></p>

# %%
from skimpy import clean_columns, skim

# %% [raw]
# !pip install skimpy  # run this code in Anaconda Prompt
# !pip install git+https://github.com/aeturrell/skimpy.git

# %% [markdown]
# **🤔 [How to Clean Messy Pandas Column Names with Skimpy Library](https://towardsdatascience.com/how-to-clean-messy-pandas-column-names-20dc7400cea7#:~:text=Skimpy%20is%20commonly%20used%20for,of%20messy%20Pandas%20column%20names.)**
#
# **[Skimpy](https://pypi.org/project/skimpy/#:~:text=skimpy%20is%20a%20light%20weight,can%20find%20the%20documentation%20here.)** is a light weight tool that provides **``summary statistics``** about variables in Pandas or Polars DataFrames within the console or our interactive Python window.
#
# Think of it as a **``super-charged version of Pandas' df.describe()``**. We can find the **[documentation here](https://aeturrell.github.io/skimpy/)**.
#
# Skimpy goes beyond the mean, median, and standard deviation, offering a richer set of metrics, including:
#
#   - **``Percentiles``**: Understand the distribution of your data beyond just the central tendency.
#   - **``Missing values``**: Get a detailed breakdown of missing values by column and their impact.
#   - **``Outliers``**: Identify potential outliers and assess their influence.
#   - **``Data types``**: Ensure data integrity by verifying data types and potential inconsistencies.
#   - **``Custom aggregations``**: Calculate specialized statistics like quartiles, interquartile ranges, and more.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **To use the skimpy library for data exploration and to clean column names in our DataFrame, follow these steps:**

# %%
# Explore the DataFrame in General

skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 149    │ │ float64     │ 7     │                                                          │
# │ │ Number of columns │ 8      │ │ string      │ 1     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %% [markdown]
# - **``The skim()``** function provides a summary of the cleaned DataFrame, displaying key statistics and insights about the dataset, such as data types, missing values, and distributions.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Let us clean messy column names of our Pandas DataFrame:

df = clean_columns(df)

# Display the updated DataFrame
df
# Out:
# 8 column names have been cleaned
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland           Western Europe          7.84                  10.78
# Denmark           Western Europe          7.62                  10.93
# Switzerland       Western Europe          7.57                  11.12
# Iceland           Western Europe          7.55                  10.88
# Netherlands       Western Europe          7.46                  10.93
# ...                          ...           ...                    ...
# Lesotho       Sub-Saharan Africa          3.51                   7.93
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# - The **``clean_columns()``** function cleans the column names in the DataFrame, ensuring they are tidy and consistent.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">First looking to dataset</p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The ``shape`` attribute provides a quick overview of the dataset's size and structure, which is helpful for understanding the data we are working with.**

# %%
# Explore the number of rows and columns in the DataFrame
df.shape

# # BONUS:
from colorama import Fore

# print(Fore.BLUE + f"There have been {df.shape[0]} rows and {df.shape[1]} columns", Fore.RESET)

print(Fore.BLUE + "There have been " + 
      Fore.RED + f"{df.shape[0]}" + 
      Fore.BLUE + " rows and " + 
      Fore.RED + f"{df.shape[1]}" + 
      Fore.BLUE + " columns" + Fore.RESET)
# Out:
# There have been 149 rows and 8 columns

# %% [markdown]
# The output of df.shape indicates that your DataFrame df has:
# - **``149 rows``**: This represents the **``number of countries or entries``** in your dataset.
# - **``8 columns``**: This corresponds to the **``number of variables``** we are analyzing, which include factors contributing to happiness scores.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.head()`` in pandas will display the ``first five rows`` of your DataFrame. This function is useful for quickly ``inspecting the data and understanding its structure and contents``:**

# %%
# Display the first five rows of the DataFrame

df.head()
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland          Western Europe          7.84                  10.78
# Denmark          Western Europe          7.62                  10.93
# Switzerland      Western Europe          7.57                  11.12
# Iceland          Western Europe          7.55                  10.88
# Netherlands      Western Europe          7.46                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# - **``Index``**: The index shows the country names, as we set it earlier.
# - **``Columns``**: Each column represents a different factor contributing to happiness, with the values corresponding to each country.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.tail()`` in pandas will display the ``last five rows`` of your DataFrame. This function is useful for ``inspecting the end of our dataset``, which can help identify any anomalies or the final entries in the data.**

# %%
# Display the last five rows of the DataFrame

df.tail()
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Lesotho       Sub-Saharan Africa          3.51                   7.93
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# Lesotho                 0.79                    48.70
# Botswana                0.78                    59.27
# Rwanda                  0.55                    61.40
# Zimbabwe                0.75                    56.20
# Afghanistan             0.46                    52.49
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Lesotho                               0.71       -0.13
# Botswana                              0.82       -0.25
# ...

# %% [markdown]
# - **``Index``**: Like before, the index shows the country names.
# - **``Columns``**: The columns represent different factors contributing to happiness, with the values corresponding to each country.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.sample(10)`` in pandas will return a ``random sample of 10 rows`` from our DataFrame. This is useful for quickly ``inspecting different parts of our dataset without having to view it sequentially``.**

# %%
# Let's take a sample of 10 observations:

df.sample(10)
# Out:
#                                            regional_indicator  ladder_score  \
# Country name
# Bulgaria                           Central and Eastern Europe          5.27
# Belgium                                        Western Europe          6.83
# Tajikistan                 Commonwealth of Independent States          5.47
# Cyprus                                         Western Europe          6.22
# Costa Rica                        Latin America and Caribbean          7.07
# Brazil                            Latin America and Caribbean          6.33
# Hong Kong S.A.R. of China                           East Asia          5.48
# Honduras                          Latin America and Caribbean          5.92
# Lesotho                                    Sub-Saharan Africa          3.51
# Benin                                      Sub-Saharan Africa          5.04
#
#                            logged_gdp_per_capita  social_support  \
# Country name
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.info()`` in Pandas provides a ``concise summary`` of your DataFrame, including ``details about its structure``, ``data types``, and ``memory usage``. This is particularly useful for understanding the composition of our dataset at a glance.**

# %%
# Display a summary of the DataFrame's structure

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, Finland to Afghanistan
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   regional_indicator            149 non-null    string
#  1   ladder_score                  149 non-null    float64
#  2   logged_gdp_per_capita         149 non-null    float64
#  3   social_support                149 non-null    float64
#  4   healthy_life_expectancy       149 non-null    float64
#  5   freedom_to_make_life_choices  149 non-null    float64
#  6   generosity                    149 non-null    float64
#  7   perceptions_of_corruption     149 non-null    float64
# dtypes: float64(7), string(1)
# memory usage: 14.5+ KB

# %% [markdown]
# **What does df.info() do in Pandas?**
#
# In Pandas, the df.info() function is used to provide a concise summary of a DataFrame. It provides information about the DataFrame's structure, including the number of rows and columns, column names, data types, and memory usage.
#
# When we call **[df.info()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html)**, it displays the following information:
#
# - The **``total number``** of **``rows``** and **``columns``** in the DataFrame.
# - The **``column names``** and their corresponding **``data types``**.
# - The **``count of non-null values``** for each column.
# - The **``memory usage``** of the DataFrame.
#
# This summary is useful for gaining a quick understanding of the DataFrame's composition, identifying missing or null values, and assessing the memory requirements of the DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.describe()`` in pandas provides a ``statistical summary of the numerical columns`` in your DataFrame. This summary includes key metrics that help us understand the ``distribution`` and ``central tendencies`` of the data.**

# %%
# Display a Descriptive Statistical summary of the DataFrame's numerical columns

df.describe()
# Out:
#        ladder_score  logged_gdp_per_capita  social_support  \
# count        149.00                 149.00          149.00
# mean           5.53                   9.43            0.81
# std            1.07                   1.16            0.11
# min            2.52                   6.63            0.46
# 25%            4.85                   8.54            0.75
# 50%            5.53                   9.57            0.83
# 75%            6.25                  10.42            0.91
# max            7.84                  11.65            0.98
#
#        healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# count                   149.00                        149.00      149.00
# mean                     64.99                          0.79       -0.02
# std                       6.76                          0.11        0.15
# min                      48.48                          0.38       -0.29
# ...

# %% [markdown]
# **What does df.describe() do in Pandas?**
#
# In Pandas, the **[df.describe()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html)** function is used to generate descriptive statistics of a DataFrame. It provides a summary of the central tendency, dispersion, and shape of the distribution of numerical columns in the DataFrame.
#
# When you call df.describe(), it computes the following statistics for each numerical column:
#
# - **``Count``**: The number of non-null values in the column.
# - **``Mean``**: The average value of the column.
# - **``Standard Deviation``**: The measure of the spread of values around the mean.
# - **``Minimum``**: The minimum value in the column.
# - **``25th Percentile (Q1)``**: The value below which 25% of the data falls.
# - **``Median (50th Percentile or Q2)``**: The middle value in the sorted column.
# - **``75th Percentile (Q3)``**: The value below which 75% of the data falls.
# - **``Maximum``**: The maximum value in the column.
#
# These statistics provide insights into the distribution of the data, including measures of **``central tendency``** (mean, median), **``spread``** (standard deviation), and **``outliers``** (minimum, maximum).
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.isnull().sum()`` in pandas allows us to ``check for missing values`` in our DataFrame. This function returns the ``total count of null (missing) entries for each column``, helping us identify any gaps in our dataset.**

# %%
# Let's check how many missing values in our dataset:

# Display the count of missing values in each column
df.isnull().sum()
# Out:
# regional_indicator              0
# ladder_score                    0
# logged_gdp_per_capita           0
# social_support                  0
# healthy_life_expectancy         0
# freedom_to_make_life_choices    0
# generosity                      0
# perceptions_of_corruption       0
# dtype: int64

# %% [markdown]
# - Each line shows the column name followed by the count of missing values. In this example, it indicates that all columns have **``NO missing values``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.isnull().mean() * 100`` in pandas calculates the ``percentage of missing values`` for each column in our DataFrame. This can help us understand the ``extent of missing data relative to the total number of entries``.**

# %%
# Let's check the percentage of missing values in our dataset:

# Calculate the percentage of missing values in each column
df.isnull().mean()*100
# Out:
# regional_indicator             0.00
# ladder_score                   0.00
# logged_gdp_per_capita          0.00
# social_support                 0.00
# healthy_life_expectancy        0.00
# freedom_to_make_life_choices   0.00
# generosity                     0.00
# perceptions_of_corruption      0.00
# dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.columns`` in pandas returns the ``list of column name``s in our DataFrame. This is useful for quickly viewing the structure of our dataset and understanding what data we have available.**

# %%
# Let's remember column/feature names in our dataset:

# Display the column names of the DataFrame
df.columns
# Out:
# Index(['regional_indicator', 'ladder_score', 'logged_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.index`` in pandas returns the ``index of our DataFrame``, which typically consists of the ``row labels``. In our case, since we set the index to ``"Country name,"`` this will show the ``names of the countries`` in our dataset.**

# %%
# Display the index of the DataFrame

df.index
# Out:
# Index(['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 'Norway',
#        'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
#        ...
#        'Burundi', 'Yemen', 'Tanzania', 'Haiti', 'Malawi', 'Lesotho',
#        'Botswana', 'Rwanda', 'Zimbabwe', 'Afghanistan'],
#       dtype='object', name='Country name', length=149)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **To count the ``occurrences of each unique value`` in the ``regional_indicator`` column of our DataFrame, we can use the value_counts() method. This provides insights into ``how many countries belong to each regional category``.**

# %%
# Let's check how many countries there have been in each region:

df['regional_indicator'].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: regional_indicator, dtype: Int64

# %% [markdown]
# **What does value_counts() do in Pandas?**
#
# In Pandas, the **[value_counts()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html)** function is used to count the ``occurrences of unique values`` in a DataFrame column or Series. It returns a ``new Series object`` where the ``unique values in the original column are used as the index``, and the corresponding counts of each unique value are the values in the Series.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet creates a pie chart displaying the distribution of the ``regional_indicator`` in our DataFrame using Pandas and Matplotlib.**

# %%
# Count occurrences of each unique value in the 'Regional indicator' column
regional_vc_pie = df['regional_indicator'].value_counts()

# Create a pie chart using Pandas
plt.figure(figsize=(8, 6))

# Plot the pie chart
regional_vc_pie.plot.pie(autopct='%1.1f%%', 
                          fontsize=8, 
                          startangle=90)

# Add labels and title
plt.ylabel('')
plt.title('Regional Indicator Distribution')

# Display the pie chart
plt.show()

# %% [markdown]
# - **``Select Columns``**: Here, we focus on the and Regional indicator column.
# - **``Value Counts``**: Use value_counts() to get the count of each unique regional indicator.
# - **``Plotting``**:
#   - **``plt.figure(figsize=(8, 6))``**: Sets the figure size for the pie chart.
#   - **``regional_vc_pie.plot.pie(...)``**: Creates the pie chart with percentage labels.
#   - **``plt.ylabel('')``**: Removes the default y-label for clarity.
#   - **``plt.title(...)``**: Sets the title of the chart.
#   - **``Display``**: Finally, plt.show() renders the pie chart.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code snippet creates a ``bar chart`` displaying the ``distribution of the regional_indicator`` using Seaborn.**

# %%
# Count occurrences of each unique value in the 'Regional indicator' column
regional_vc_bar = df['regional_indicator'].value_counts()

# Create a bar chart using Seaborn
plt.figure(figsize=(12, 5))

# Plot the bar chart
ax = sns.barplot(x=regional_vc_bar.index, 
                 y=regional_vc_bar.values, 
                 palette='viridis')

# Add labels and title
plt.xlabel('Regional Indicator', color="purple")
plt.ylabel('Count', color="purple")
plt.title('Regional Indicator Distribution', color="darkblue")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=8)

# Annotate the occurrences of unique values
for container in ax.containers:
    ax.bar_label(container, label_type='center', color='white')

# Display the bar chart
plt.show()

# %% [markdown]
# - **``Select Columns``**: Focus on the Country name and Regional indicator columns.
# - **``Value Counts``**: Use value_counts() to get the count of each unique regional indicator.
# - **``Plotting:``**
#   - **``plt.figure(figsize=(15, 6))``**: Sets the figure size for the bar chart.
#   - **``sns.barplot(...)``**: Creates the bar chart with the regional indicators on the x-axis and their counts on the y-axis, using a color palette for aesthetic appeal.
#   - **``Labels and Title``**: Add appropriate labels and title for clarity.
#   - **``Rotate X-axis Labels``**: Rotate the x-axis labels for better readability.
#   - **``Annotate Bars``**: The ax.bar_label(...) function annotates the bars with their respective counts, enhancing the visual information.
#   - **``Display``**: Finally, plt.show() renders the bar chart.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# ### First looking into the DataFrame by a User Defined Function:
#
# User-defined functions help to decompose a large program into small segments which makes program easy to understand, maintain and debug.
#
# Defining a function and giving it a name in Python is important for several reasons:
#  - **``Reusability``**: By giving a function a name, you can easily reuse the same block of code multiple times in your program without having to rewrite it.
#  - **``Readability``**: Giving a function a descriptive name helps make your code more readable and understandable for other developers who may work on or maintain your code in the future.
#  - **``Organization``**: Functions allow you to break down your code into smaller, more manageable pieces, making it easier to organize and maintain.
#  - **``Abstraction``**: By encapsulating a specific task or set of instructions within a function, you can create a level of abstraction that allows you to focus on the higher-level logic of your program without getting bogged down in the implementation details of individual tasks.

# %%
# def first_looking(df):
#     """
#     Prints basic information about a column in a Pandas DataFrame.

#     Parameters:
#     -----------
#     df : pandas.DataFrame
#         The DataFrame to be analyzed.
        
#     """
    
#     display("shape_of_df    : ", df.shape)
#     print("_______________________")
#     display("num_of_nulls   : ", df.isnull().sum())
#     print("_______________________")
#     display("perc_of_nulls   : ", df.isnull().mean())
#     print("_______________________")
#     print("num_of_uniques : \n")
#     for i in df.columns:
#         print(f"{i}  : {df[i].astype(str).nunique():>}")  # >: Align the string to the right
                                                        
#     print("_______________________")
#     display("value_counts: ")
#     for i in df.columns:
#         print(f"column name: \n", df[i].value_counts(dropna=False))
#         print("\n")

# %% [markdown]
# **Our function ``first_looking()`` is designed to provide a ``comprehensive overview`` of a Pandas DataFrame, including its ``shape``, ``null values``, ``unique values``, and ``value counts`` for each column.**

# %%
def first_looking(df):
    """
    Prints basic information about a column in a Pandas DataFrame.
    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame to be analyzed.
    """
    print(Fore.BLUE + "Shape of DataFrame", Fore.RESET)
    print(Fore.GREEN + "There have been " + Fore.RED + f"{df.shape[0]}" + Fore.GREEN + " rows and " + Fore.RED + f"{df.shape[1]}" + Fore.GREEN + " columns" + Fore.RESET)
    print("_"*40)
    print(Fore.BLUE + "Number of NULL values in the features\n", Fore.RESET)
    for i in df.columns:
        print(f"{i:<30}: {df[i].astype(str).isnull().sum()}")
    print("_"*40)
    print(Fore.BLUE + "Percent of NULL values in the features\n", Fore.RESET)
    for column in df.columns:
        print(f"{column:<30}: {df[column].isnull().mean()*100}")
    print("_"*40)
    print(Fore.BLUE + "Number of UNIQUE values in the features\n", Fore.RESET)
    for i in df.columns:
        print(f"{i:<30}: {df[i].astype(str).nunique()}")
    print("_"*40)
    print(Fore.BLUE + "Value Counts of Each Feature:\n", Fore.RESET)
    for i in df.columns:
        print(Fore.GREEN + f"column name: {Fore.RED}{i}{Fore.RESET}")
        value_counts_df = df[i].value_counts(dropna=False).reset_index()
        aligned_value_counts_str = "\n".join([f"{index_val:<35}: {count}" for index_val, count in zip(value_counts_df.iloc[:, 0], value_counts_df.iloc[:, 1])])
        print(aligned_value_counts_str)
        print("\n")
    print("_"*40)

# %% [markdown]
# - **``Explanation of Each Section``**
#   - **``Shape of DataFrame:``**
#     - Prints the number of rows and columns in the DataFrame.
#   - **``Number of NULL Values``**:
#     - Iterates through each column and prints the count of missing values.
#   - **``Percent of NULL Values``**:
#     - Calculates and prints the percentage of missing values for each column.
#   - **``Number of UNIQUE Values``**:
#     - Prints the count of unique values in each column.
#   - **``Value Counts``**:
#     - For each column, it prints the count of each unique value, including missing values (if any).
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **When we call ``first_looking()`` with our DataFrame, it will execute the function and print a detailed overview of the DataFrame's characteristics.**

# %%
first_looking(df)
# Out:
# Shape of DataFrame
# There have been 149 rows and 8 columns
# ________________________________________
# Number of NULL values in the features
#
# regional_indicator            : 0
# ladder_score                  : 0
# logged_gdp_per_capita         : 0
# social_support                : 0
# healthy_life_expectancy       : 0
# freedom_to_make_life_choices  : 0
# generosity                    : 0
# perceptions_of_corruption     : 0
# ________________________________________
# Percent of NULL values in the features
#
# regional_indicator            : 0.0
# ladder_score                  : 0.0
# logged_gdp_per_capita         : 0.0
# social_support                : 0.0
# healthy_life_expectancy       : 0.0
# freedom_to_make_life_choices  : 0.0
# generosity                    : 0.0
# perceptions_of_corruption     : 0.0
# ________________________________________
# Number of UNIQUE values in the features
#
# regional_indicator            : 10
# ladder_score                  : 147
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Our function ``first_looking_col(df, col)`` is designed to provide ``detailed information about a specific column`` in a Pandas DataFrame. This function includes ``statistics`` such as the ``percentage of null values``, the ``number of unique values``, and the ``value counts for that column``.**

# %%
def first_looking_col(df, col):
    """
    Prints basic information about a column in a Pandas DataFrame.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame to analyze.
    col : str
        The name of the column to analyze."""

    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().mean(), 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].astype(str).nunique())
    print("lenght_of_the_column    : ", df.shape[0])
    print("--------------------------------")
    print("value_counts: \n", df[col].value_counts(dropna=False))

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **When we call first_looking_col(df, "ladder_score") with our DataFrame, the function will print detailed information about the ladder_score column.**

# %%
first_looking_col(df, "ladder_score")
# Out:
# column name    :  ladder_score
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  147
# lenght_of_the_column    :  149
# --------------------------------
# value_counts:
#  5.93    2
# 5.48    2
# 4.85    1
# 4.98    1
# 5.07    1
#        ..
# 6.05    1
# 6.03    1
# 6.01    1
# 5.99    1
# 2.52    1
# Name: ladder_score, Length: 147, dtype: int64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">slicing, loc & iloc</p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Return the ``'Freedom to make life choices'`` and ``'Healthy life expectancy'`` values for ``Germany``, ``Ethiopia``, ``Peru``, ``Chad``, & ``Japan``.**<hr>
#
#   - **``Healthy life expectancy``** - Healthy life expectancies at birth are based on the data extracted from the World Health Organization’s (WHO) Global Health Observatory data repository (Last updated: 2020-09-28)
#
#   - **``Freedom to make life choices``** - Is the national average of responses to the GWP question “Are you satisfied or dissatisfied with your freedom to choose what you do with your life?
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using df.columns in pandas will return the list of column names in our DataFrame. This is useful for quickly identifying the variables available in our dataset.**

# %%
# Display the column names of the DataFrame

df.columns
# Out:
# Index(['regional_indicator', 'ladder_score', 'logged_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %% [markdown]
# - Each item in the index represents a column in the DataFrame, giving you a quick overview of the data structure.
# - This can help us determine which columns to analyze or visualize based on their names.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.index`` in pandas will return the index of your DataFrame, which typically consists of the row labels. This is particularly useful for understanding ``how the data is organized``, especially if the index provides meaningful identifiers.**

# %%
# Display the index of the DataFrame

df.index
# Out:
# Index(['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 'Norway',
#        'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
#        ...
#        'Burundi', 'Yemen', 'Tanzania', 'Haiti', 'Malawi', 'Lesotho',
#        'Botswana', 'Rwanda', 'Zimbabwe', 'Afghanistan'],
#       dtype='object', name='Country name', length=149)

# %% [markdown]
# - The output shows an **``Index object``** containing the row labels.
# - If the DataFrame has a default integer index, it will show a **``RangeIndex``**, indicating the start, stop, and step.
# - If we have set a **``specific column (like country names in our case)``** as the index, it will display those values, helping us identify each row's context.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Filtering the DataFrame:</strong></p>
#
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 1st Approach to get the result using loc[ ]:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.loc[]`` in pandas allows us to ``access a specific subset`` of your DataFrame by specifying both the ``row labels`` and the ``column names``.**
# - In our case, we're looking to extract data for specific countries and particular columns related to freedom of life choices and healthy life expectancy.

# %%
# Extracting specified rows and columns from the DataFrame

df.loc[['Germany','Ethiopia','Peru','Chad','Japan']     ,    ['freedom_to_make_life_choices', 'healthy_life_expectancy']]
# Out:
#               freedom_to_make_life_choices  healthy_life_expectancy
# Country name
# Germany                               0.88                    72.50
# Ethiopia                              0.75                    59.00
# Peru                                  0.82                    68.25
# Chad                                  0.58                    48.48
# Japan                                 0.80                    75.10

# %% [markdown]
# - **``Accessing Specific Rows``**: ``df.loc[['Germany', 'Ethiopia', 'Peru', 'Chad', 'Japan'], ...]``
#   - This part specifies the **``rows to be selected``**. It looks for the rows with indices corresponding to the countries: Germany, Ethiopia, Peru, Chad, and Japan.
#   - The **``loc accessor``** is used here, which allows for **``label-based indexing``**.
#
# - **``Accessing Specific Columns``**: ``['freedom_to_make_life_choices', 'healthy_life_expectancy']``
#   - This specifies the **``columns to be selected``** from the DataFrame. In this case, the columns are **``freedom_to_make_life_choices``** and **``healthy_life_expectancy``**.

# %% [markdown]
# The result is a **``new DataFrame``** showing **``only the specified countries``** and **``their corresponding values``** for the selected columns.
#
#
# - **``Row Labels``**: The countries specified (**``Germany``**, **``Ethiopia``**, **``Peru``**, **``Chad``**, **``Japan``**) are used to index the rows.
# - **``Column Names``**: The columns **``freedom_to_make_life_choices``** and **``healthy_life_expectancy``** are selected for output.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 2nd approach to get the result using iloc[ ]: </strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using df.``head(1)`` in Pandas ``retrieves the first row`` of our DataFrame. This is useful for quickly inspecting the structure and content of the DataFrame.**

# %%
# Display the first row of the DataFrame

df.head(1)
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland          Western Europe          7.84                  10.78
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
#
#               perceptions_of_corruption
# Country name
# Finland                            0.19

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# The easiest way to get the row/column index from a row/column name in Pandas is to use the **[pandas.Index.get_loc()](https://pandas.pydata.org/docs/reference/api/pandas.Index.get_loc.html)** method. This method returns the integer location of a row/column in a DataFrame or Series based on its label.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **To find the ``row index numbers`` for the ``specified countries`` in our DataFrame, we can use the ``get_loc()`` method on the DataFrame's index. This method retrieves the integer index of the specified label.**

# %%
# BONUS

# Finding the row index numbers for the related countries
germany_index = df.index.get_loc("Germany")
ethiopia_index = df.index.get_loc("Ethiopia")
peru_index = df.index.get_loc("Peru")
chad_index = df.index.get_loc("Chad")
japan_index = df.index.get_loc("Japan")

# Displaying the results
print("Index of Germany:", germany_index)
print("Index of Ethiopia:", ethiopia_index)
print("Index of Peru:", peru_index)
print("Index of Chad:", chad_index)
print("Index of Japan:", japan_index)
# Out:
# Index of Germany: 12
# Index of Ethiopia: 132
# Index of Peru: 62
# Index of Chad: 127
# Index of Japan: 55

# %% [markdown]
# - **``get_loc Method``**: This method returns the **``integer location of the specified index label``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **To find the ``column index numbers`` for the ``specified columns`` in our DataFrame, we can use the ``get_loc()`` method on the DataFrame's columns. This method retrieves the ``integer index of the specified column label``.**

# %%
# Finding the column index numbers for the specified columns
freedom_index = df.columns.get_loc('freedom_to_make_life_choices')
healthy_life_expectancy_index = df.columns.get_loc('healthy_life_expectancy')

# Displaying the results
print("Index of 'Freedom to make life choices':", freedom_index)
print("Index of 'Healthy life expectancy':", healthy_life_expectancy_index)
# Out:
# Index of 'Freedom to make life choices': 5
# Index of 'Healthy life expectancy': 4

# %% [markdown]
# - **``get_loc Method``**: This method returns the integer location of the specified column label within the DataFrame.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.iloc[]`` allows us to access ``specific rows`` and ``columns`` in our DataFrame by their ``integer index positions``. In our case, we're selecting certain rows and specific columns based on their index numbers.**

# %%
df.columns
# Out:
# Index(['regional_indicator', 'ladder_score', 'logged_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %%
# Now, let's use these row & column index numbers inside iloc[] to get the output:

df.iloc[[12, 132, 62, 127, 55], [5, 4]]
# Out:
#               freedom_to_make_life_choices  healthy_life_expectancy
# Country name
# Germany                               0.88                    72.50
# Ethiopia                              0.75                    59.00
# Peru                                  0.82                    68.25
# Chad                                  0.58                    48.48
# Japan                                 0.80                    75.10

# %% [markdown]
# - **``Row Indices``**: The numbers **``[12, 132, 62, 127, 55]``** refer to the **``specific rows``** we want to retrieve.
# - **``Column Indices``**: The numbers **``[5, 4]``** refer to the **``specific columns``** we are interested in. (Assuming that column 5 corresponds to **``"freedom_to_make_life_choices"``** and column 5 corresponds to **``"healthy_life_expectancy,"``** for example.)
# - **``Output``**: The result will be a **``DataFrame``** containing the values from those specified rows and columns.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Conditional Filtering</p>
#
# Conditional filtering in pandas allows users to extract subsets of data from a DataFrame based on specific conditions applied to one or more columns. By using boolean indexing, we can create filters that enable us to select rows that meet certain criteria, such as finding all entries where a particular column's value exceeds a threshold or matches a specific category. This powerful feature facilitates data analysis by enabling users to focus on relevant subsets, making it easier to perform operations like aggregation, visualization, or further manipulation on the filtered data. For example, we can filter a DataFrame to show only countries with a "Ladder score" greater than 6, providing insights into higher-ranking nations in a dataset.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# **Task :**
#
# - **Let's examine the ``'Ladder Scores' (Happines score)`` of countries located in Central & Eastern Europe whose ``'Perceptions of Corruption'`` scores higher than 0.9:**<hr>
#
#   - **``Ladder score``** - Happiness score or subjective well-being. This is the national average response to the question of life evaluations.
#
#   - **``Perceptions of corruption``** - The measure is the national average of the survey responses to **``two questions``** in the GWP:
#     - **``“Is corruption widespread throughout the government or not”``** and
#     - **``“Is corruption widespread within businesses or not?”``**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Finding the Minimum & Maximum Ladder Scores in the Data:</strong></p>
#
#
# **To display the ``minimum`` and ``maximum`` values of the ``ladder_score column`` in our DataFrame, we can use the following code:**

# %%
# Display the minimum value of the 'ladder_score' column
min_ladder_score = df["ladder_score"].min()
print("Minimum Ladder Score:", min_ladder_score)

# Get the maximum value of the 'ladder_score' column
max_ladder_score = df["ladder_score"].max()
print("Maximum Ladder Score:", max_ladder_score)
# Out:
# Minimum Ladder Score: 2.523
# Maximum Ladder Score: 7.842

# %% [markdown]
# By printing both values, we can quickly assess the range of ladder scores in your dataset.
# - **``min() Method``**: This method retrieves the **``smallest value``** in the **``ladder_score``** column.
# - **``max() Method``**: This method retrieves the **``largest value``** in the **``ladder_score``** column.
# By rinting both values, we can quickly assess the range of ladder scores in your dataset.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Data Based on Some Critera:</strong></p>
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">🤝 We ASSUME that the value of Perception greater than 0.9 is the indicator of HIGH Corruption and the value of Perception less than 0.4 is the indicator of LOW Corruption</p>
#
#
# **To ``filter rows`` in our DataFrame based on the ``values`` in the ``perceptions_of_corruption`` column, we can use conditional statements. Here's how we can do it for both conditions:**

# %%
# df[df['perceptions_of_corruption'] > 0.9]
# df[df['perceptions_of_corruption'] < 0.4]

# %%
# df[df['perceptions_of_corruption'] > 0.9]

# %%
# Filter DataFrame for high perceptions of corruption
df_high_corruption = df[df['perceptions_of_corruption'] > 0.9]
print("Countries with high perceptions of corruption:")
display(df_high_corruption)

# Filter DataFrame for low perceptions of corruption
df_low_corruption = df[df['perceptions_of_corruption'] < 0.4]
print("\nCountries with low perceptions of corruption:")
display(df_low_corruption)
# Out:
# Countries with high perceptions of corruption:
#                                         regional_indicator  ladder_score  \
# Country name
# Kosovo                          Central and Eastern Europe          6.37
# Slovakia                        Central and Eastern Europe          6.33
# Romania                         Central and Eastern Europe          6.14
# Croatia                         Central and Eastern Europe          5.88
# Bosnia and Herzegovina          Central and Eastern Europe          5.81
# Moldova                 Commonwealth of Independent States          5.77
# Kyrgyzstan              Commonwealth of Independent States          5.74
# Bulgaria                        Central and Eastern Europe          5.27
# Albania                         Central and Eastern Europe          5.12
# North Macedonia                 Central and Eastern Europe          5.10
# Ukraine                 Commonwealth of Independent States          4.88
# ...

# %% [markdown]
# Each filtered DataFrame (high_corruption and low_corruption) contains only the relevant rows based on the specified conditions.
#
#
# - **``High Corruption Filter``**: **``df[df['perceptions_of_corruption'] > 0.9]``** retrieves **``all rows``** where the **``perceptions_of_corruption value exceeds 0.9``**.
# - **``Low Corruption Filter``**: **``df[df['perceptions_of_corruption'] < 0.4]``** retrieves **``all rows``** where the **``perceptions_of_corruption value is less than 0.4``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;">🎯 The results reveal a stark contrast in perceptions of corruption across different countries and regions.</p>
#
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✔️ High Perceptions of Corruption:</p>
#
#   - Countries like **``Kosovo``**, **``Slovakia``**, and **``Romania``** demonstrate high perceptions of corruption, with scores above 0.9. These nations are primarily **``located in Central and Eastern Europe``**, indicating a **``regional trend where citizens perceive significant corruption within their institutions``**. Despite relatively decent ladder scores (suggesting moderate life satisfaction), the **``high corruption perceptions``** may **``undermine trust in governance``** and **``affect overall societal well-being``**. For instance, **``Kosovo``** has a total bill score of 6.37 and a perception score of 0.82, highlighting **``persistent governance issues``** despite some positive aspects of life.
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✔️ Low Perceptions of Corruption:</p>
#
#   - In contrast, countries such as **``Finland``**, **``Denmark``**, and **``Switzerland``** exhibit **``low perceptions of corruption``**, with scores around 0.95. These nations, **``predominantly in Western Europe``**, are characterized by **``strong governance``**, **``high life satisfaction``**, and **``effective institutions``**. For example, **``Finland``** has a total ladder score of 7.84, reflecting a **``high quality of life``** alongside a **``very low corruption perception``**. This correlation suggests that **``lower perceptions of corruption``** contribute to **``higher trust in government``** and **``better social outcomes``**.
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">📝 Summary:</p>
#
#   - Overall, the data underscores the **``significant impact of perceived corruption on societal trust and quality of life``**. Countries with high corruption perceptions often face challenges in governance and public trust, while those with low perceptions tend to showcase stronger institutional integrity and overall well-being. Addressing **``corruption could be vital for improving life satisfaction and governance in the regions with high corruption perceptions``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Countries in the Central and Eastern Europe Based on High Perceptions of Corruption:</strong></p>
#
#
# **In the following code, we're creating a ``conditional filter`` to select rows from your DataFrame where;**
# - The **``regional_indicator is 'Central and Eastern Europe' and the perceptions_of_corruption is greater than 0.9``**.
# - We then retrieve the ladder_score for those selected rows.

# %%
# Define the condition
cond1 = (df['regional_indicator'] == 'Central and Eastern Europe') & (df['perceptions_of_corruption'] > 0.9)

# Select the 'ladder_score' for the countries that meet the condition
selected_countries = df.loc[cond1, 'ladder_score']

# Display the selected countries' ladder scores
selected_countries
# Out:
# Country name
# Kosovo                   6.37
# Slovakia                 6.33
# Romania                  6.14
# Croatia                  5.88
# Bosnia and Herzegovina   5.81
# Bulgaria                 5.27
# Albania                  5.12
# North Macedonia          5.10
# Name: ladder_score, dtype: float64

# %% [markdown]
# - **``Conditional Filter:``**
#   - **``cond1``** combines two conditions using the & operator:
#   - It checks if regional_indicator is 'Central and Eastern Europe'.
#   - It checks if perceptions_of_corruption is greater than 0.9.
# - **``Selection:``**
#   - **``df.loc[cond1, 'ladder_score']``** uses the condition **``cond1``** to filter the rows and selects the ladder_score column for those rows.
# - **``Output:``**
#   - The **``selected_countries``** variable will contain the **``ladder_score values for the countries that meet both conditions``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Visualizing the Countries in the Central and Eastern Europe Based on High Perceptions of Corruption:</strong></p>
#
#
# **The following code ``creates a bar chart`` to visualize the ``ladder scores`` for countries in ``Central and Eastern Europe`` with ``high perceptions of corruption``**.

# %%
# Create a bar chart
plt.figure(figsize=(12, 4))

ax = sns.barplot(x=selected_countries.index, 
                 y=selected_countries.values, 
                 palette='viridis')  # Optional: choose a color palette

# Add labels and title
plt.xlabel('Countries')
plt.ylabel('Ladder Score')
plt.title('Ladder Scores for Central & Eastern Europe with High Perceptions of Corruption', fontsize=14, color="blue")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, fontsize=10)

# Annotate the occurrences of unique values on the bars
for container in ax.containers:
    ax.bar_label(container, label_type="center", color="white",  fmt='%.2f')

# Display the bar chart
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Find the average ``'Healthy Life Expectancy'`` for each region.**
#
# - **Which region has the ``maximum`` and ``minimum`` ``'Healthy Life Expectancy'``?**
#
# - **What is the ``difference between the maximum and minimum`` values of the average ``'Healthy Life Expectancy'`` across regions?**<hr>
#
#   - 👉 **``Healthy life expectancy``** - Healthy life expectancies at birth are based on the data extracted from the World Health Organization’s (WHO) Global Health Observatory data repository (Last updated: 2020-09-28)
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Exploring the Dataset:</strong></p>
#
#
# **Using ``df.head(1)`` in pandas retrieves the ``first row`` of our DataFrame. This is useful for quickly inspecting the structure and content of the DataFrame.**

# %%
df.head()
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland          Western Europe          7.84                  10.78
# Denmark          Western Europe          7.62                  10.93
# Switzerland      Western Europe          7.57                  11.12
# Iceland          Western Europe          7.55                  10.88
# Netherlands      Western Europe          7.46                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Group by Operation:</strong></p>
#
#
# **Using ``df.groupby("regional_indicator")`` in pandas allows us to ``group out DataFrame`` by the values in the ``regional_indicator`` column. This is a powerful feature for aggregating and analyzing data based on specific categories.**

# %%
# Grouping the DataFrame by 'regional_indicator'

df.groupby("regional_indicator")

# %% [markdown]
# The output **``<pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000193FB9FF610>``** indicates that we have created a **``groupby object``** in pandas but have NOT yet performed any operations on it. Here’s a breakdown of what this means:
#
# - **``pandas.core.groupby.generic.DataFrameGroupBy:``**
#   - This part of the output specifies the **``type of the object``** we have created. It indicates that it is a **``DataFrameGroupBy object``**, which is a specific type of object in pandas used for grouping DataFrames.
# - **``Memory Address:``**
#   - The at **``0x00000193FB9FF610``** portion shows the **``memory address``** where this object is stored. This address is specific to the instance of the object in our current Python session and will vary each time the code is run.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the AVERAGE Healthy Life Expectancy Scores by Regions:</strong></p>
#
#
# **To find the ``average 'Healthy Life Expectancy'`` for ``each region`` in our DataFrame, we can use the groupby method along with the ``mean()`` function.**

# %%
# Let's first find the average 'Healthy Life Expectancy' for each region:

# Group by 'regional_indicator' and calculate the average 'healthy_life_expectancy'
regional_healthy_life_exp = df.groupby("regional_indicator")["healthy_life_expectancy"].mean()

# Display the results
regional_healthy_life_exp
# Out:
# regional_indicator
# Central and Eastern Europe           68.34
# Commonwealth of Independent States   65.01
# East Asia                            71.25
# Latin America and Caribbean          67.08
# Middle East and North Africa         65.61
# North America and ANZ                72.33
# South Asia                           62.68
# Southeast Asia                       64.89
# Sub-Saharan Africa                   55.89
# Western Europe                       73.03
# Name: healthy_life_expectancy, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the MAXIMUM Healthy Life Expectancy Score by Regions:</strong></p>
#
#
# **To find the ``maximum 'Healthy Life Expectancy'`` score and identify ``which region it belongs to``, we can follow these steps:**

# %%
# Let's find the maximum 'Healthy Life Expectancy' score:

regional_healthy_life_exp.max()  # Which region does this score belong to?
# Out:
# 73.03309523809523

# %%
# Group by 'regional_indicator' and calculate the average 'healthy_life_expectancy'
regional_healthy_life_exp = df.groupby("regional_indicator")["healthy_life_expectancy"].mean()

# Find the maximum value and the corresponding region
max_value = regional_healthy_life_exp.max()
max_region = regional_healthy_life_exp.idxmax()

# Display the results
print("Maximum Healthy Life Expectancy:", max_value)
print("Region with Maximum Healthy Life Expectancy:", max_region)
# Out:
# Maximum Healthy Life Expectancy: 73.03309523809523
# Region with Maximum Healthy Life Expectancy: Western Europe

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Regions Based on the MAXIMUM Healthy Life Expectancy Score:</strong></p>
#
#
# **Using the following expression will ``create a boolean Series`` that indicates ``which regions have the maximum average healthy life expectancy``.**

# %%
# Create a boolean Series to identify the maximum values

regional_healthy_life_exp == regional_healthy_life_exp.max()
# Out:
# regional_indicator
# Central and Eastern Europe            False
# Commonwealth of Independent States    False
# East Asia                             False
# Latin America and Caribbean           False
# Middle East and North Africa          False
# North America and ANZ                 False
# South Asia                            False
# Southeast Asia                        False
# Sub-Saharan Africa                    False
# Western Europe                         True
# Name: healthy_life_expectancy, dtype: bool

# %% [markdown]
# - **``Comparison:``**
#   - The expression **``regional_healthy_life_exp.max()``** retrieves the **``maximum average healthy life expectancy``** value.
#   - The comparison **``regional_healthy_life_exp == regional_healthy_life_exp.max()``** checks each entry in the regional_healthy_life_exp Series to see if it equals the maximum value.
# - **``Boolean Series:``**
#   - The result is a **``boolean Series``** **``where each entry is True if the corresponding region's average healthy life expectancy matches the maximum value``**, and **``False otherwise``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Retrieving the Region Based on the MAXIMUM Healthy Life Expectancy Score:</strong></p>
#
#
# **Using the following expression allows us to ``retrieve the regions`` that have the ``maximum average healthy life expectancy``. This will return the ``specific regions along with their corresponding values``.**

# %%
# Retrieve the regions with the maximum healthy life expectancy

regional_healthy_life_exp[regional_healthy_life_exp == regional_healthy_life_exp.max()]
# Out:
# regional_indicator
# Western Europe   73.03
# Name: healthy_life_expectancy, dtype: float64

# %% [markdown]
# - **``Condition:``**
#   - The expression **``regional_healthy_life_exp == regional_healthy_life_exp.max()``** creates a **``boolean mask``** indicating **``which regions have the maximum average healthy life expectancy``**.
# - **``Indexing:``**
#   - **``regional_healthy_life_exp[...]``** uses this **``boolean mask``** to filter the original Series, returning **``only the regions that meet the condition``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Alternative Way of Filtering the Regions Based on the Maximum Healthy Life Expectancy Score:</strong></p>
#
#
# **Both following expressions are ways to identify the ``region(s) with the maximum average healthy life expectancy`` from the regional_healthy_life_exp Series.**

# %%
# Alternative way:

# Retrieve the index (region name) of the maximum healthy life expectancy
regional_healthy_life_exp[regional_healthy_life_exp == regional_healthy_life_exp.max()].index
# Out:
# Index(['Western Europe'], dtype='string', name='regional_indicator')

# %% [markdown]
# - **``Boolean Condition``**: ``regional_healthy_life_exp == regional_healthy_life_exp.max()`` creates a boolean mask that identifies which regions have the maximum value.
# - **``Indexing``**: By applying this mask to ``regional_healthy_life_exp``, we filter the Series to get only the maximum values, and ``.index`` retrieves the index (region names) of those filtered entries.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Alternative Way of Filtering the Regions Based on the Maximum Healthy Life Expectancy Score:</strong></p>

# %%
# Alternatively, we can use idxmax() to get the index of the maximum healthy life expectancy directly

regional_healthy_life_exp.idxmax()
# Out:
# 'Western Europe'

# %% [markdown]
# - **``idxmax() Method``**: This method directly returns the **``index``** of the **``first occurrence of the maximum value``** in the Series, which is **``much more efficient and concise``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Regions Based on the MINIMUM Healthy Life Expectancy Score:</strong></p>
#
#
# **To find the ``region(s) with the minimum average 'Healthy Life Expectancy' score`` using the regional_healthy_life_exp Series, we can use a similar approach to what we did for finding the maximum.**

# %%
# Let's find the minimum 'Healthy Life Expectancy' score:

# Retrieve the index (region name) of the minimum healthy life expectancy
regional_healthy_life_exp[regional_healthy_life_exp == regional_healthy_life_exp.min()].index
# Out:
# Index(['Sub-Saharan Africa'], dtype='string', name='regional_indicator')

# %% [markdown]
# - **``Boolean Condition``**: The expression ``regional_healthy_life_exp == regional_healthy_life_exp.min()`` creates a boolean mask that identifies which regions have the minimum average healthy life expectancy.
# - **``Indexing``**: By applying this mask to ``regional_healthy_life_exp``, we filter the Series to get only the regions that have the minimum value.
# - **``Retrieving Index``**: The ``.index`` retrieves the index (region names) of those filtered entries.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Alternative Way of Filtering the Regions Based on the Minimum Healthy Life Expectancy Score:</strong></p>
#
#
# **Alternatively. using the ``regional_healthy_life_exp.idxmin()`` method is a ``straightforward way`` to find the ``index`` (i.e., the region) with the ``minimum average 'Healthy Life Expectancy' score`` directly from the regional_healthy_life_exp Series.**

# %%
# Use idxmin() to get the index of the minimum healthy life expectancy

regional_healthy_life_exp.idxmin()
# Out:
# 'Sub-Saharan Africa'

# %% [markdown]
# - **``idxmin() Method``**: This method returns the **``index of the first occurrence of the minimum value``** in the Series. It is efficient and concise, allowing us to quickly identify the region with the lowest average healthy life expectancy.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Retrieving the Values of Healthy Life Expectancy Scores by Regions:</strong></p>
#
#
# **Using ``regional_healthy_life_exp.values`` retrieves the underlying NumPy array of the average healthy life expectancy values from the regional_healthy_life_exp Series.**

# %%
regional_healthy_life_exp
# Out:
# regional_indicator
# Central and Eastern Europe           68.34
# Commonwealth of Independent States   65.01
# East Asia                            71.25
# Latin America and Caribbean          67.08
# Middle East and North Africa         65.61
# North America and ANZ                72.33
# South Asia                           62.68
# Southeast Asia                       64.89
# Sub-Saharan Africa                   55.89
# Western Europe                       73.03
# Name: healthy_life_expectancy, dtype: float64

# %%
# Get the values from the regional_healthy_life_exp Series
values = regional_healthy_life_exp.values

# Display the values
values
# Out:
# array([68.33841176, 65.0095    , 71.25216667, 67.07605   , 65.60911765,
#        72.325     , 62.681     , 64.88844444, 55.88647222, 73.03309524])

# %% [markdown]
# - **``.values Attribute``**: This attribute returns the data contained in the Series as a NumPy array, allowing for efficient numerical operations.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the Difference Between Highest and Lowest Values of Healthy Life Expectancy Scores by Regions:</strong></p>
#
#
# **To calculate the ``maximum average difference in 'Healthy Life Expectancy' across regions``, we can use either of the following expressions:**

# %%
# Calculate the maximum average difference in 'Healthy Life Expectancy' across regions
max_difference = values.max() - values.min()

# Alternatively, using abs() to ensure positivity (though it's NOT necessary here)
max_difference_abs = abs(values.min() - values.max())

# Display the results
print("Maximum average difference in Healthy Life Expectancy:", max_difference)
print("Absolute maximum average difference:", max_difference_abs)
# Out:
# Maximum average difference in Healthy Life Expectancy: 17.146623015873004
# Absolute maximum average difference: 17.146623015873004

# %% [markdown]
# **``Both expressions yields the same maximum average difference``** in 'Healthy Life Expectancy' across regions. This value provides insight into the disparity in health outcomes between different regions.
#
#
# - **``Calculating Difference:``**
#   - **``values.max() - values.min()``** computes the difference between the maximum and minimum average healthy life expectancy values directly. This gives us the range of healthy life expectancy across the regions.
# - **``Using abs():``**
#   - **``abs(values.min() - values.max())``** also calculates the difference, but it ensures that the result is positive. However, since we know max() is always greater than or equal to min(), both methods will yield the same result.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Let's examine either the ``'Ladder Scores' (Happines score)`` of countries located in Sub-Saharan Africa OR the countries whose ``'Healthy life expectancy'`` scores lower than minimum:**<hr>
#
#   - **``Ladder score``** - Happiness score or subjective well-being. This is the national average response to the question of life evaluations.
#
#   - **``Healthy life expectancy``** - Healthy life expectancies at birth are based on the data extracted from the World Health Organization’s (WHO) Global Health Observatory data repository (Last updated: 2020-09-28)
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">😲 Across the world, people are living longer. In 1900, the average life expectancy of a newborn was 32 years. By 2021 this had more than doubled to 71 years. It's is expected to rise to 77.3 by 2050.</p>
#
#
# <p style="text-align: center;"><img src="https://i.ibb.co/2scnT2C/life-expectency-2015.png" class="img-fluid"
# alt="life_expectency_2015"></p>
#
# **[Global Life Expectancy: Closing the Gap](https://www.statista.com/chart/2266/life-expectancy-by-world-region/#:~:text=According%20to%20the%20United%20Nations,rise%20to%2077.3%20by%202050.)**<br>
# **[Life Expectancy](https://ourworldindata.org/life-expectancy#:~:text=Across%20the%20world%2C%20people%20are,than%20doubled%20to%2071%20years.)**<br>
# **[Twice as long – life expectancy around the world](https://ourworldindata.org/life-expectancy-globally)**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Descriptive Statistics of DataFrame:</strong></p>

# %%
# Let's find minimum value of Healty Life Expectancy:

df.describe()
# Out:
#        ladder_score  logged_gdp_per_capita  social_support  \
# count        149.00                 149.00          149.00
# mean           5.53                   9.43            0.81
# std            1.07                   1.16            0.11
# min            2.52                   6.63            0.46
# 25%            4.85                   8.54            0.75
# 50%            5.53                   9.57            0.83
# 75%            6.25                  10.42            0.91
# max            7.84                  11.65            0.98
#
#        healthy_life_expectancy  freedom_to_make_life_choices  generosity  \
# count                   149.00                        149.00      149.00
# mean                     64.99                          0.79       -0.02
# std                       6.76                          0.11        0.15
# min                      48.48                          0.38       -0.29
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the MINIMUM Healthy Life Expectancy Score:</strong></p>
#
#
# **The following line of code assigns the ``minimum value of the 'Healthy Life Expectancy'`` column from the DataFrame to the ``variable min_life_exp``.**

# %%
# Assign the minimum value of 'healthy_life_expectancy' to a variable
min_life_exp = df['healthy_life_expectancy'].min()

# Display the minimum life expectancy
min_life_exp
# Out:
# 48.478

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>🛑 THE COUNTRIES IN SUB-SAHARAN AFRICA OR UNDER MINIMUM LIFE EXPECTANCY 🛑</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Countries Based on Either REGION OR the MINIMUM Healthy Life Expectancy Score:</strong></p>
#
#
# **The following code creates a ``condition to filter the DataFrame`` based on specific criteria related to the ``'regional_indicator'`` and ``'healthy_life_expectancy'`` columns.**

# %%
# Create a condition to filter for Sub-Saharan Africa or low healthy life expectancy
cond2 = (df['regional_indicator'] == 'Sub-Saharan Africa') | (df['healthy_life_expectancy'] < min_life_exp)

# Display the condition
cond2
# Out:
# Country name
# Finland        False
# Denmark        False
# Switzerland    False
# Iceland        False
# Netherlands    False
#                ...
# Lesotho         True
# Botswana        True
# Rwanda          True
# Zimbabwe        True
# Afghanistan    False
# Length: 149, dtype: boolean

# %% [markdown]
# - **``Condition Components:``**
#   - **``(df['regional_indicator'] == 'Sub-Saharan Africa')``**: This part checks if the value in the 'regional_indicator' column is 'Sub-Saharan Africa'.
#   - **``(df['healthy_life_expectancy'] < min_life_exp)``**: This part checks if the 'healthy_life_expectancy' is less than the minimum value stored in min_life_exp.
# - **``Logical OR Operator (|):``**
#   - The **``|``** operator combines the two conditions such that the resulting condition, cond2, will be **``True if either of the two conditions is met``**. This means that any row where the region is 'Sub-Saharan Africa' or the healthy life expectancy is below the calculated minimum will be included.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 The Countries in Either Sub-Saharan Africa OR Under the MINIMUM Healthy Life Expectancy Score:</strong></p>
#
#
# **The following line of code ``selects specific columns`` from the DataFrame ``based on the condition`` defined in ``cond2``.**

# %%
# Select countries based on the condition and specific columns
selected_countries = df.loc[cond2, ['ladder_score', 'healthy_life_expectancy']]

# Display the selected countries DataFrame
selected_countries

# (df.loc[cond2, 'ladder_score']).mean()
# Out:
#                      ladder_score  healthy_life_expectancy
# Country name
# Mauritius                    6.05                    66.70
# Congo (Brazzaville)          5.34                    58.22
# Ivory Coast                  5.31                    50.11
# Cameroon                     5.14                    53.52
# Senegal                      5.13                    59.80
# Ghana                        5.09                    57.59
# Niger                        5.07                    53.78
# Gambia                       5.05                    55.16
# Benin                        5.04                    54.71
# Guinea                       4.98                    55.01
# South Africa                 4.96                    56.90
# Gabon                        4.85                    59.96
# Burkina Faso                 4.83                    54.15
# Mozambique                   4.79                    54.71
# Nigeria                      4.76                    50.10
# ...

# %% [markdown]
# The output presents a **``list of countries in Sub-Saharan Africa``** that meet the condition, along with their respective **``ladder scores``** and **``healthy life expectancy``** values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✍️ Comment on the Output:</p>
#
# - The data highlights **``significant disparities in both life satisfaction and health across the region``**. **``Mauritius``** stands out with the **``highest ladder score of 6.05``** and a **``healthy life expectancy of 66.70 years``**, indicating a **``relatively higher quality of life compared to its peers``**. In contrast, countries like **``Sierra Leone``** and **``Zimbabwe``** exhibit **``much lower ladder scores (3.85 and 3.15, respectively)``**, coupled with **``lower healthy life expectancies``**, reflecting the **``ongoing challenges related to governance, health care, and socio-economic conditions``**. Overall, this output underscores the urgent need for targeted interventions to improve both health outcomes and overall well-being in these countries.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Filtering with loc:**
# - **``df.loc[cond2, ...]``**: This uses the .loc[] indexer to filter the DataFrame. The cond2 variable provides the boolean mask that selects rows where either the regional indicator is 'Sub-Saharan Africa' or the healthy life expectancy is below the minimum value.
# **Selecting Columns:**
# - **``['ladder_score', 'healthy_life_expectancy']``**: This specifies that only the 'ladder_score' and 'healthy_life_expectancy' columns should be included in the resulting DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 The 8 Bottom Countries Having the Lowest Ladder Score in Sub-Saharan Africa:</strong></p>
#
#
# **The following line of code will retrieve the ``8 countries with the lowest ladder scores`` from the selected_countries DataFrame, which contains countries that either have ``high perceptions of corruption`` OR ``low healthy life expectancy``.**

# %%
# Retrieve the 8 countries with the lowest ladder scores
lowest_ladder_scores = selected_countries['ladder_score'].nsmallest(8)

# Display the result
lowest_ladder_scores
# Out:
# Country name
# Zimbabwe       3.15
# Rwanda         3.42
# Botswana       3.47
# Lesotho        3.51
# Malawi         3.60
# Tanzania       3.62
# Burundi        3.77
# Sierra Leone   3.85
# Name: ladder_score, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✍️ Comment on the Output:</p>
#
# - The output highlights the eight countries with the lowest ladder scores, revealing significant challenges in terms of perceived quality of life among these nations. Zimbabwe has the lowest score at 3.15, indicating a critical situation regarding citizen satisfaction and overall well-being. This is closely followed by Rwanda and Botswana, which, despite some progress in recent years, still face substantial socio-economic issues.
#
# - Countries like Lesotho, Malawi, and Tanzania also reflect low ladder scores, suggesting persistent struggles with poverty, health care access, and governance. Burundi and Sierra Leone further exemplify the hardships in the region, where historical conflicts and economic instability have hindered development.
#
# - Overall, this data underscores the urgent need for targeted interventions to improve living conditions, economic opportunities, and governance in these countries. Addressing these issues is essential not just for enhancing ladder scores but also for fostering a healthier, more stable, and prosperous future for their populations.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - **``selected_countries['ladder_score']``**: This accesses the 'ladder_score' column from the selected_countries DataFrame.
# - **``.nsmallest(8)``**: This method returns the 8 smallest values from the 'ladder_score' column, along with their corresponding indices (i.e., country names).
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 The 5 Top Countries Having the Lowest Ladder Score in Sub-Saharan Africa:</strong></p>
#
#
# **The following line of code will retrieve the ``top countries with the highest ladder scores`` from the ``selected_countries`` DataFrame.**

# %%
# Retrieve the top 5 countries with the highest ladder scores
top_ladder_scores = selected_countries['ladder_score'].nlargest(5)

# Display the result
top_ladder_scores
# Out:
# Country name
# Mauritius             6.05
# Congo (Brazzaville)   5.34
# Ivory Coast           5.31
# Cameroon              5.14
# Senegal               5.13
# Name: ladder_score, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✍️ Comment on the Output:</p>
#
# - The output presents the five countries with the highest ladder scores from the selected dataset, indicating a relatively better quality of life among these nations. Mauritius stands out with a score of 6.05, reflecting its strong economic performance, stable governance, and effective social policies that contribute to overall citizen satisfaction.
#
# - Congo (Brazzaville) and Ivory Coast follow, with scores of 5.34 and 5.31, respectively. These scores suggest notable progress in development and governance, though challenges remain. Cameroon and Senegal also demonstrate moderate ladder scores, indicating that while they face various socio-economic issues, there are areas of resilience and improvement.
#
# - Overall, this output highlights that despite the prevalent challenges in the region, certain countries have managed to cultivate better living conditions and higher satisfaction levels. This underscores the importance of continued investment in governance, health, and economic development to further improve quality of life across the region.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Filtering with loc:**
# - **``df.loc[cond2, ...]``**: This uses the **``.loc[]``** indexer to **``filter the DataFrame``**. The **``cond2``** variable provides the **``boolean mask``** that selects **``rows where either the regional indicator is 'Sub-Saharan Africa' or the healthy life expectancy is below the minimum value``**.
# **Selecting Columns:**
# - **``['ladder_score', 'healthy_life_expectancy']``**: This specifies that **``only the 'ladder_score' and 'healthy_life_expectancy' columns``** should be **``included in the resulting DataFrame``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Selecting 8 Bottom Countries Having the Lowest Ladder Score:</strong></p>
#
#
# **The following line of code ``sorts the selected_countries`` DataFrame by the ``'ladder_score'`` in ``ascending order ``and retrieves the ``bottom eight countries`` based on that score.**

# %%
selected_countries.sort_values('ladder_score', ascending=True).head(8)
# Out:
#               ladder_score  healthy_life_expectancy
# Country name
# Zimbabwe              3.15                    56.20
# Rwanda                3.42                    61.40
# Botswana              3.47                    59.27
# Lesotho               3.51                    48.70
# Malawi                3.60                    57.95
# Tanzania              3.62                    58.00
# Burundi               3.77                    53.40
# Sierra Leone          3.85                    51.65

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✍️ Comment on the Output:</p>
#
# - The output presents a list of countries with the lowest ladder scores, indicating significant challenges in perceived quality of life. Zimbabwe has the lowest score at 3.15, reflecting serious socio-economic issues and limited citizen satisfaction. Rwanda, while slightly higher at 3.42, still faces substantial obstacles despite recent development efforts.
#
# - Countries like **``Botswana``**,  **``Lesotho``**, and  **``Malawi``** show moderate scores between 3.47 and 3.60, suggesting ongoing struggles related to governance, health care, and economic stability. Tanzania and Burundi also reflect low satisfaction levels, emphasizing the need for targeted interventions in these areas.
#
# - Overall, this data highlights the urgent need for comprehensive strategies to address the underlying issues affecting these nations, aiming to improve living conditions and enhance overall well-being for their populations.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Visualizing the Countries Having the Lowest Ladder Scores in Sub-Saharan Africa:</strong></p>
#
#
# **The following code snippet creates a ``bar plot`` to visualize the ``ladder scores for selected countries`` that meet certain criteria.**

# %%
# Assuming df is your DataFrame
cond2 = (df['regional_indicator'] == 'Sub-Saharan Africa') | (df['healthy_life_expectancy'] < min_life_exp)
selected_countries = df.loc[cond2, ['ladder_score', 'healthy_life_expectancy']]

# Sort the selected countries by ladder score in ascending order
selected_countries = selected_countries.sort_values('ladder_score', ascending=True).head(10)

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 5))
ax = sns.barplot(x=selected_countries.index, y='ladder_score', data=selected_countries)

# Add labels and title
plt.xlabel('Country')
plt.ylabel('Ladder Score')
plt.title('Ladder Scores for Selected Countries in Sub-Saharan Africa or with Low Life Expectancy', fontsize=14, color="blue")

# Rotate x-axis labels if needed
plt.xticks(rotation=45, fontsize=10)

# Annotate the occurrences of unique values
for container in ax.containers:
    ax.bar_label(container, label_type="center", color="white", fmt='%.2f')

# Display the bar plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">✍️ Comment on the Output:</p>
#
# - This output highlights the eight countries with the lowest ladder scores from the selected dataset. It emphasizes the significant challenges these nations face in terms of perceived quality of life, with Sierra Leone and Zimbabwe showing particularly low scores. Such insights can guide policymakers and organizations in identifying areas that require urgent attention and intervention to improve living standards and socio-economic conditions.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Let's `randomly` select ``7 countries`` with their `Regional indicator`, `Ladder score`, `Perceptions of corruption` scores**
#
#   - **Condition : Those countries are NOT in `Western Europe` or their `Perceptions of corruption` scores are NOT bigger than 0.66**
#
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following line of code creates a ``condition`` to ``filter countries`` based on their ``regional indicator`` and ``perceptions of corruption scores``.**

# %%
# Create a condition to filter out countries in Western Europe OR with high perceptions of corruption
cond3 = (df['regional_indicator'] == 'Western Europe') | (df['perceptions_of_corruption'] >= 0.66)

# Display the condition
cond3
# Out:
# Country name
# Finland         True
# Denmark         True
# Switzerland     True
# Iceland         True
# Netherlands     True
#                ...
# Lesotho         True
# Botswana        True
# Rwanda         False
# Zimbabwe        True
# Afghanistan     True
# Length: 149, dtype: boolean

# %% [markdown]
# **Condition Components:**
# - **``(df['regional_indicator'] == 'Western Europe')``**: This checks if the country is classified as being in Western Europe.
# - **``(df['perceptions_of_corruption'] >= 0.66)``**: This checks if the perceptions of corruption score is greater than or equal to 0.66.
#
# **Logical OR Operator (|):**
# - The **``|``** operator combines the two conditions, meaning that cond3 will be **``True for any country``** that is **``either in Western Europe``** **``OR has a perceptions of corruption score of 0.66 or higher``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following line of code filters the DataFrame to retrieve specific columns based on the given condition.**

# %%
df[(df['regional_indicator'] == 'Western Europe') | (df['perceptions_of_corruption'] >= 0.66)][['regional_indicator', 'perceptions_of_corruption']]
# Out:
#               regional_indicator  perceptions_of_corruption
# Country name
# Finland           Western Europe                       0.19
# Denmark           Western Europe                       0.18
# Switzerland       Western Europe                       0.29
# Iceland           Western Europe                       0.67
# Netherlands       Western Europe                       0.34
# ...                          ...                        ...
# Malawi        Sub-Saharan Africa                       0.73
# Lesotho       Sub-Saharan Africa                       0.92
# Botswana      Sub-Saharan Africa                       0.80
# Zimbabwe      Sub-Saharan Africa                       0.82
# Afghanistan           South Asia                       0.92
#
# [130 rows x 2 columns]

# %% [markdown]
# **Condition:**
# - **``(df['regional_indicator'] == 'Western Europe')``**: This checks if the country is classified as being in the Western Europe region.
# - **``(df['perceptions_of_corruption'] >= 0.66)``**: This checks if the perceptions of corruption score is 0.66 or higher.
# **Logical OR Operator (|):**
# - The **``|``** operator combines the two conditions, meaning that any country that meets either condition will be included in the result.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;"><strong>🤔💭 What is tilde (~) operator in Python❓</strong></p>
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">In Python (and other C-like languages like C, C++, and Java), the tilde symbol (~) represents the bitwise NOT operator. It affects all bits, inverting them so that every '1' becomes '0' and vice versa. 😲 In other words, all the 1 bits in the operand are set to 0 and all the 0 bits in the operand are set to 1.</p>
#
# **The following line of code uses the ``inverted condition`` ``~cond3`` to filter the DataFrame and ``retrieve specific columns``.**

# %%
# Filter the DataFrame for countries NOT in Western Europe and with low perceptions of corruption
filtered_countries = df.loc[~cond3, ['regional_indicator', 'ladder_score', 'perceptions_of_corruption']]

# Display the filtered DataFrame
filtered_countries
# Out:
#                                            regional_indicator  ladder_score  \
# Country name
# New Zealand                             North America and ANZ          7.28
# Australia                               North America and ANZ          7.18
# Canada                                  North America and ANZ          7.10
# United Arab Emirates             Middle East and North Africa          6.56
# Uruguay                           Latin America and Caribbean          6.43
# Singapore                                      Southeast Asia          6.38
# Estonia                            Central and Eastern Europe          6.19
# Uzbekistan                 Commonwealth of Independent States          6.18
# Japan                                               East Asia          5.94
# Belarus                    Commonwealth of Independent States          5.53
# Hong Kong S.A.R. of China                           East Asia          5.48
# ...

# %% [markdown]
# **Inverted Condition:**
# - **``~cond3``**: The **``tilde (~)``** operator negates the condition defined in cond3. This means it selects countries that are NOT in Western Europe and have perceptions of corruption scores less than 0.66.
# **Using .loc[]:**
# - **``df.loc[~cond3, ...]``**: This indexer allows you to filter the DataFrame based on the boolean condition and select specific columns simultaneously.
# **Selecting Columns:**
# - **``['regional_indicator', 'ladder_score', 'perceptions_of_corruption']``**: This specifies that only these three columns should be included in the result.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Data and Selecting Random 7 Countries:</strong></p>
#
#
# **The following line of code ``randomly selects 7 countries`` that meet the specified criteria from the DataFrame.**

# %%
# Randomly select 7 countries that are NOT in Western Europe and have low perceptions of corruption
random_selection = df.loc[~cond3, ['regional_indicator', 'ladder_score', 'perceptions_of_corruption']].sample(7)

# Display the randomly selected countries
random_selection
# Out:
#                                       regional_indicator  ladder_score  \
# Country name
# Georgia               Commonwealth of Independent States          4.89
# Canada                             North America and ANZ          7.10
# United Arab Emirates        Middle East and North Africa          6.56
# New Zealand                        North America and ANZ          7.28
# Armenia               Commonwealth of Independent States          5.28
# Burundi                               Sub-Saharan Africa          3.77
# Belarus               Commonwealth of Independent States          5.53
#
#                       perceptions_of_corruption
# Country name
# Georgia                                    0.66
# Canada                                     0.41
# United Arab Emirates                       0.59
# New Zealand                                0.24
# Armenia                                    0.63
# Burundi                                    0.61
# ...

# %% [markdown]
# **Inverted Condition:**
# - **``~cond3``**: This condition filters out countries that are in Western Europe or have high perceptions of corruption (0.66 or higher), allowing us to focus on those that do NOT meet these criteria.
#
# **Using .loc[]:**
# - **``df.loc[~cond3, ...]``**: This accesses the DataFrame, applying the inverted condition to select relevant rows.
# **Selecting Columns:**
# - **``['regional_indicator', 'ladder_score', 'perceptions_of_corruption']``**: This specifies that only these three columns should be included in the output.
#
# **Random Sampling:**
# - **``.sample(7)``**: This method randomly selects 7 rows from the filtered DataFrame, providing a diverse representation of the data.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# # Invert the condition to select countries NOT in Western Europe and with low corruption perception
# cond3_inverted = ~cond3

# # Select the relevant columns from the DataFrame
# selected_countries = df.loc[cond3_inverted, ['regional_indicator', 'ladder_score', 'perceptions_of_corruption']]

# # Randomly select 7 countries from the filtered DataFrame
# random_selection = selected_countries.sample(n=7, random_state=1)

# # Display the selected countries
# random_selection

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Alternative Way Using ``!=`` and ``&`` signs:</strong></p>
#
#
# **Let's set the same condition ``without using ~ (tilde)``:**
#
# **🔥Pay attention to the change of logical operator!!🔥**
#
#   - **Condition : Those countries are NOT in `Western Europe` or their `Perceptions of corruption` scores are NOT bigger than 0.66**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The folowing line of code ``filters the DataFrame to select countries`` that are ``NOT in Western Europe`` and have ``perceptions of corruption scores below 0.66``.**

# %%
# Filter the DataFrame for countries not in Western Europe and with low perceptions of corruption
filtered_countries = df.loc[
                            (df['regional_indicator'] != 'Western Europe') & (df['perceptions_of_corruption'] < 0.66),
                            ['regional_indicator', 'ladder_score', 'perceptions_of_corruption']
                           ]

# Display the filtered DataFrame
filtered_countries
# Out:
#                                            regional_indicator  ladder_score  \
# Country name
# New Zealand                             North America and ANZ          7.28
# Australia                               North America and ANZ          7.18
# Canada                                  North America and ANZ          7.10
# United Arab Emirates             Middle East and North Africa          6.56
# Uruguay                           Latin America and Caribbean          6.43
# Singapore                                      Southeast Asia          6.38
# Estonia                            Central and Eastern Europe          6.19
# Uzbekistan                 Commonwealth of Independent States          6.18
# Japan                                               East Asia          5.94
# Belarus                    Commonwealth of Independent States          5.53
# Hong Kong S.A.R. of China                           East Asia          5.48
# ...

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Adding & Dropping Columns and Rows</p>
#
#
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and manipulation. One of its core functionalities is the ability to efficiently add and drop columns and rows in a DataFrame. To add a new column, we can simply assign a value or a series to a new column name, such as df['new_column'] = value. Alternatively, the ``assign()`` method allows us to add multiple columns in a more readable way with ``df = df.assign(new_col1=value1, new_col2=value2)``.
#
# When it comes to dropping columns, the ``drop()`` method is commonly used, where we specify ``axis=1`` to indicate that we want to remove a column, like ``df = df.drop('column_name', axis=1)``. We can modify the original DataFrame by using the ``inplace=True`` parameter, making changes directly without needing to reassign it. Adding rows can be achieved using the ``append()`` method, but for better performance, especially with multiple rows, it is recommended to use ``pd.concat()``, such as ``df = pd.concat([df, new_rows], ignore_index=True)``.
#
# To drop rows, we again use the ``drop()`` method, specifying the indices of the rows we want to remove, like ``df = df.drop(index)``. We can also drop rows based on specific conditions, such as ``df = df[df['column_name'] != value]``, which retains rows where the condition is true. Overall, these operations for adding and dropping columns and rows in pandas are straightforward and essential for effective data preprocessing and analysis, allowing for flexible manipulation of your datasets.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 How to add new column❓</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The folloeing code snippet uses NumPy to ``generate an array of random numbers``.**

# %%
# Set the seed for reproducability
np.random.seed(42)

# Create random numbers
np.random.rand(149)
# Out:
# array([0.37454012, 0.95071431, 0.73199394, 0.59865848, 0.15601864,
#        0.15599452, 0.05808361, 0.86617615, 0.60111501, 0.70807258,
#        0.02058449, 0.96990985, 0.83244264, 0.21233911, 0.18182497,
#        0.18340451, 0.30424224, 0.52475643, 0.43194502, 0.29122914,
#        0.61185289, 0.13949386, 0.29214465, 0.36636184, 0.45606998,
#        0.78517596, 0.19967378, 0.51423444, 0.59241457, 0.04645041,
#        0.60754485, 0.17052412, 0.06505159, 0.94888554, 0.96563203,
#        0.80839735, 0.30461377, 0.09767211, 0.68423303, 0.44015249,
#        0.12203823, 0.49517691, 0.03438852, 0.9093204 , 0.25877998,
#        0.66252228, 0.31171108, 0.52006802, 0.54671028, 0.18485446,
#        0.96958463, 0.77513282, 0.93949894, 0.89482735, 0.59789998,
#        0.92187424, 0.0884925 , 0.19598286, 0.04522729, 0.32533033,
#        0.38867729, 0.27134903, 0.82873751, 0.35675333, 0.28093451,
#        0.54269608, 0.14092422, 0.80219698, 0.07455064, 0.98688694,
# ...

# %% [markdown]
# **Setting the Seed:**
# - **``np.random.seed(42)``** sets the seed for NumPy's random number generator to ensure reproducibility. Using a fixed seed (like 42) means that every time you run this code, you will get the same sequence of random numbers.
# **Generating Random Numbers:**
# - **``np.random.rand(149)``** function generates an array of 149 random numbers uniformly distributed between 0 and 1. The rand() function creates random floats in the half-open interval [0.0, 1.0)
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a New Column:</strong></p>
#
#
# **The following code snippet ``adds a new column`` to a DataFrame ``using random values``.**

# %%
# Set the seed for reproducability
np.random.seed(42)

# Add a new column the DataFrame
df['new_column'] = np.random.rand(149)

# Display the updated DataFrame
df
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland           Western Europe          7.84                  10.78
# Denmark           Western Europe          7.62                  10.93
# Switzerland       Western Europe          7.57                  11.12
# Iceland           Western Europe          7.55                  10.88
# Netherlands       Western Europe          7.46                  10.93
# ...                          ...           ...                    ...
# Lesotho       Sub-Saharan Africa          3.51                   7.93
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 Assuming that df originally has at least 149 rows, the output will be the DataFrame df with an additional column named 'new_column', containing 149 random values.</p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 How to drop a column❓</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Dropping the New Column:</strong></p>
#
#
# **The following code snippet ``removes the column named 'new_column'`` from the DataFrame.**

# %%
# Drop the column named "new_column"
df.drop('new_column', axis=1, inplace=True)

# Display the updated DataFrame
df
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland           Western Europe          7.84                  10.78
# Denmark           Western Europe          7.62                  10.93
# Switzerland       Western Europe          7.57                  11.12
# Iceland           Western Europe          7.55                  10.88
# Netherlands       Western Europe          7.46                  10.93
# ...                          ...           ...                    ...
# Lesotho       Sub-Saharan Africa          3.51                   7.93
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# - **``df.drop()``**: This method is used to drop specified labels from rows or columns.
# - **``'new_column'``**: This indicates the column you want to remove from the DataFrame.
# - **``axis=1``**: This specifies that you are dropping a column (as opposed to axis=0, which would indicate rows).
# - **``inplace=True``**: This modifies the original DataFrame directly without needing to assign the result to a new variable.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Feature Engineering</p>
#
# Feature engineering is a crucial step in the data preprocessing phase of machine learning and data analysis, involving the transformation and creation of new features from raw data to enhance model performance. It encompasses a variety of techniques, such as selecting, modifying, and combining existing features, as well as generating new ones that can provide additional insights. Effective feature engineering can significantly improve the predictive power of models by capturing underlying patterns and relationships in the data that may not be immediately apparent. This process often requires domain knowledge, creativity, and a deep understanding of the algorithms being used, as the right features can lead to better accuracy and more robust models. Overall, feature engineering plays a vital role in bridging the gap between raw data and actionable insights, making it a key component of successful data-driven projects.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Create a new feature consisting of the ``square roots of the product`` of the data of the ``two features with the highest correlation`` (feature engineering):**
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a New Column:</strong></p>
#
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;">👉 To create a new feature consisting of the square roots of the product of the two features with the highest correlation, we can follow these steps:</p>
#
#
#
#
#   - **``Calculate the Correlation Matrix``**: This gives us a matrix of correlation coefficients between pairs of features.
#   - **``Identify the Two Features with the Highest Correlation``**: Extract the names of the two features that have the highest correlation value.
#   - **``Create the New Feature``**: Compute the square root of the product of these two features.

# %%
# Let's first calculate the correlation matrix:

# Step 1: Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only=True).abs()

# Display the correlation matrix
correlation_matrix
# Out:
#                               ladder_score  logged_gdp_per_capita  \
# ladder_score                          1.00                   0.79
# logged_gdp_per_capita                 0.79                   1.00
# social_support                        0.76                   0.79
# healthy_life_expectancy               0.77                   0.86
# freedom_to_make_life_choices          0.61                   0.43
# generosity                            0.02                   0.20
# perceptions_of_corruption             0.42                   0.34
#
#                               social_support  healthy_life_expectancy  \
# ladder_score                            0.76                     0.77
# logged_gdp_per_capita                   0.79                     0.86
# social_support                          1.00                     0.72
# healthy_life_expectancy                 0.72                     1.00
# freedom_to_make_life_choices            0.48                     0.46
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a Heatmap:</strong></p>
#
#
# **The following code snippets create a heatmap of the correlation matrix using Seaborn.**

# %%
# Step 1: Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only=True).abs()

# Step 2: Create a heatmap using Seaborn
plt.figure(figsize=(8, 6))  # Set the size of the figure

# Create the heatmap
sns.heatmap(correlation_matrix, 
            annot=True,              # Annotate cells with correlation coefficients
            cmap='coolwarm',         # Color map
            annot_kws={"size": 10},  # Annotation font size
            square=True,             # Make cells square-shaped
            cbar_kws={"shrink": 1.0}  # Color bar size
           )

# Add title
plt.title('Correlation Matrix', fontsize=16)

# Adjust axis label font size and rotate x-axis labels
plt.xticks(fontsize=10, rotation=60)  # Rotate x-axis labels by 45 degrees
plt.yticks(fontsize=10)

# Display the heatmap
plt.show()

# %% [markdown]
# This heatmap visually represents the correlation between features in our dataset, making it easier to identify relationships and dependencies at a glance. It is a valuable tool for exploratory data analysis and for guiding feature selection in machine learning tasks.
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Checking the Columns of Correlation Matrix:</strong></p>
#
#
# **The line of code ``correlation_matrix.columns`` retrieves the ``column names from the correlation_matrix DataFrame``. This can be useful to understand which features are included and to confirm the dimensions of the correlation matrix.**

# %%
# Example: Retrieve the column names from the correlation matrix
column_names = correlation_matrix.columns

# Display the column names
column_names
# Out:
# Index(['ladder_score', 'logged_gdp_per_capita', 'social_support',
#        'healthy_life_expectancy', 'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Checking the Length of Correlation Matrix:</strong></p>
#
#
# **The line of code ``len(correlation_matrix.columns)`` calculates the ``number of columns in the correlation_matrix DataFrame``. This is useful for determining how many features are involved in the correlation analysis.**

# %%
# Get the number of columns in the correlation matrix
num_columns = len(correlation_matrix.columns)

# Display the number of columns
num_columns
# Out:
# 7

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Finding the Features Having the Highest Correlation:</strong></p>
#
#
# **The following code snippet finds the ``two features`` in a DataFrame that have the ``highest correlation with each other``.**

# %%
# Initialize variables to track the maximum correlation and corresponding features
max_corr = 0
max_corr_features = []

# Iterate through the correlation matrix to find the highest correlation pair
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        corr_value = correlation_matrix.iloc[i, j]
        
        # Update max_corr and max_corr_features if a higher correlation is found
        if corr_value > max_corr:
            max_corr = corr_value
            max_corr_features = [correlation_matrix.columns[i], correlation_matrix.columns[j]]

# Output the features with the highest correlation
print(f"The two features with the highest correlation: {max_corr_features[0]} & {max_corr_features[1]}")
print(f"Correlation value: {max_corr}")
# Out:
# The two features with the highest correlation: logged_gdp_per_capita & healthy_life_expectancy
# Correlation value: 0.8594606242792721

# %% [markdown]
# This code effectively identifies and outputs the **``two features with the highest correlation``** in our dataset, along with their correlation value. It's a valuable step in feature selection and understanding relationships within our data.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a New Column:</strong></p>
#
#
# **The following code snippet ``creates a new column`` in the DataFrame, which is calculated as the ``square root of the product of two existing columns``:**
# - **``logged_gdp_per_capita``** & **``healthy_life_expectancy``**.

# %%
# Add a new column the DataFrame
df["new_column"] = np.sqrt(df.logged_gdp_per_capita * df.healthy_life_expectancy)

# Display the updated DataFrame
df.head()
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland          Western Europe          7.84                  10.78
# Denmark          Western Europe          7.62                  10.93
# Switzerland      Western Europe          7.57                  11.12
# Iceland          Western Europe          7.55                  10.88
# Netherlands      Western Europe          7.46                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# **Creating the New Column:**
# - ``df["new_column"] = np.sqrt(df.logged_gdp_per_capita * df.healthy_life_expectancy)``
#   - **``np.sqrt(...)``**: This function calculates the square root of the values inside the parentheses.
#   - **``df.logged_gdp_per_capita and df.healthy_life_expectancy``**: These are the existing columns from the DataFrame. The product of these two columns is computed, and then the square root of that product is assigned to a new column named new_column.
# **Displaying the DataFrame:**
# - ``df.head()``
#   - The **``head()``** function displays the first five rows of the updated DataFrame. This is useful for quickly checking the results and ensuring that the new column has been added correctly.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Dropping the New Column:</strong></p>
#
#
# **The following code snippet ``removes the column named new_column`` from the DataFrame.**

# %%
# Drop the column named "new_column"
df.drop("new_column", axis=1, inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland          Western Europe          7.84                  10.78
# Denmark          Western Europe          7.62                  10.93
# Switzerland      Western Europe          7.57                  11.12
# Iceland          Western Europe          7.55                  10.88
# Netherlands      Western Europe          7.46                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# - **``df.drop()``**: This method is used to drop specified labels from rows or columns.
# - **``"new_column"``**: This specifies the column you want to remove from the DataFrame.
# - **``axis=1``**: This indicates that you are dropping a column (as opposed to axis=0, which would indicate rows).
# - **``inplace=True``**: This modifies the original DataFrame directly, meaning the column will be removed without needing to reassign the result to a new variable.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# #### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Adding row/s to DataFrame</p>
#
# Adding rows to a DataFrame in pandas is a fundamental operation that allows us to expand our dataset by including new data points. This can be particularly useful for appending individual observations or integrating data from other sources. We can add rows using methods such as ``loc[...]`` for indexing or ``append()`` for combining DataFrames. For example, using ``pd.concat()`` is often recommended for better performance, especially when adding multiple rows at once. Additionally, when adding rows, it's essential to ensure that the new data aligns with the existing structure of the DataFrame, maintaining consistent column names and data types. Overall, the ability to add rows provides flexibility in data manipulation and facilitates ongoing data analysis and modeling tasks.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Adding a new observation/row with loc[...]:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code snippet ``creates a copy of the DataFrame`` and then ``checks the last row`` of the copied DataFrame, df1.**

# %%
# Let's check which observation is in the last row:

# Create a Copy of the DataFrame
df1 = df.copy()

# Check the Last Row
df1.tail(1)
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Afghanistan          South Asia          2.52                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# Afghanistan             0.46                    52.49
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Afghanistan                           0.38       -0.10
#
#               perceptions_of_corruption
# Country name
# Afghanistan                        0.92

# %% [markdown]
# This approach effectively allows us to examine the last observation in our dataset, which can be useful for verifying data integrity or understanding the most recent entry.
#
# - **``df.copy()``** creates a new DataFrame df1 that is a copy of df. Using the **``copy() method ensures that any changes made to df1 do NOT affect the original DataFrame df``**.
# Checking the Last Row:
# - The **``tail(1)``** function retrieves the last row of the DataFrame. This function is useful for quickly inspecting the most recent observations in our dataset.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a New Series:</strong></p>
#
#
# **The following code snippet ``creates a new observation`` as a pandas Series, which can later be added to a DataFrame.**

# %%
# Let's manually create a new observation:

# Create a New Observation
new_row = pd.Series({"regional_indicator": "Western Europe", 
                    "ladder_score": 0.0,
                    "logged_gdp_per_capita" : 0.0, 
                    "social_support" : 0.0, 
                    "healthy_life_expectancy" : 0.0,
                    "freedom_to_make_life_choices" : 0.0, 
                    "generosity" : 0.0, 
                    "perceptions_of_corruption" :0.0})

# Display the new Row
new_row
# Out:
# regional_indicator              Western Europe
# ladder_score                              0.00
# logged_gdp_per_capita                     0.00
# social_support                            0.00
# healthy_life_expectancy                   0.00
# freedom_to_make_life_choices              0.00
# generosity                                0.00
# perceptions_of_corruption                 0.00
# dtype: object

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Renaming the Series:</strong></p>
#
#
# **The following code snippet ``assigns a name to the newly created Series new_row``, effectively labeling this observation.**

# %%
# Naming the New Row
new_row.name = "New_Country1"

# Displaying the Named Row
new_row
# Out:
# regional_indicator              Western Europe
# ladder_score                              0.00
# logged_gdp_per_capita                     0.00
# social_support                            0.00
# healthy_life_expectancy                   0.00
# freedom_to_make_life_choices              0.00
# generosity                                0.00
# perceptions_of_corruption                 0.00
# Name: New_Country1, dtype: object

# %% [markdown]
# - **``new_row.name = "New_Country1"``** sets the ``name of the Series``, new_row, to **``"New_Country1"``**. By assigning a name to the Series, it can be easily identified when added to a DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Checking the Shape of DataFrame:</strong></p>
#
#
# **The following code snippet displays the ``number of rows`` in the DataFrame.**

# %%
display(df1.shape[0], len(df1))
# Out:
# 149
# 149

# %% [markdown]
# Both df1.shape[0] and len(df1) return the same value, confirming the number of rows in the DataFrame. This code effectively verifies the number of observations in the DataFrame, ensuring we have the expected dataset size for further analysis.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Adding a New Entry:</strong></p>
#
#
# **When we add a new row to a DataFrame using ``loc`` and a pandas Series, the ``name of the Series (in this case, "New_Country1") does NOT automatically become the index label of the new row`` in the DataFrame. Instead, the DataFrame ``assigns a new index based on the existing index``.**

# %%
# Adding the New Row
df1.loc[len(df1)] = new_row

# Viewing the Last Rows
df1.tail(5)

# However, the name of the observation in the last index was NOT changed to "New_Country1" even if we assigned it above!!
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
# 149               Western Europe          0.00                   0.00
#
#               social_support  healthy_life_expectancy  \
# Country name
# Botswana                0.78                    59.27
# Rwanda                  0.55                    61.40
# Zimbabwe                0.75                    56.20
# Afghanistan             0.46                    52.49
# 149                     0.00                     0.00
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Botswana                              0.82       -0.25
# Rwanda                                0.90        0.06
# ...

# %% [markdown]
# - **``df1.loc[len(df1)] = new_row``** adds new_row to df1 at the index equal to the current length of df1. However, it does **``NOT update the DataFrame index``** to reflect the name of the Series.
# - **``df1.tail(5)``** displays the last five rows of df1, but the index for the newly added row will simply be the next integer (e.g., if df1 had 100 rows before, the new row will have an index of 100).
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Checking the Last Entry:</strong></p>
#
#
# **The following code snippet ``retrieves the last index`` of the DataFrame.**

# %%
# Let's find the last index number to rename it:

# Accessing the Last Index and Storing the Last Index
last_index = df1.index[-1]

# Displayin the Last Index
last_index
# Out:
# 149

# %% [markdown]
# The value of the last index is stored in the variable last_index, which can then be used for further operations, such as renaming that specific row.
#
#
# **last_index = df1.index[-1]**
# - **``df1.index``**: This attribute returns the index labels of the DataFrame df1.
# - **``[-1]``**: This indexing retrieves the last element from the index, which represents the index of the last row in the DataFrame.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Renaming the Last Entry:</strong></p>
#
#
# **The following code snippet ``renames the last index`` of the DataFrame to ``"New_Country1"``.**

# %%
# Renaming the Index
df1.rename(index={last_index: 'New_Country1'}, inplace=True)

# Displaying the Last Three Rows:
df1.tail(3)
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
# New_Country1      Western Europe          0.00                   0.00
#
#               social_support  healthy_life_expectancy  \
# Country name
# Zimbabwe                0.75                    56.20
# Afghanistan             0.46                    52.49
# New_Country1            0.00                     0.00
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Zimbabwe                              0.68       -0.05
# Afghanistan                           0.38       -0.10
# New_Country1                          0.00        0.00
#
#               perceptions_of_corruption
# Country name
# Zimbabwe                           0.82
# Afghanistan                        0.92
# New_Country1                       0.00

# %% [markdown]
# - **``df1.rename()``**: This method is used to rename the index or columns of a DataFrame.
# - **``index={last_index: 'New_Country1'}``**: This specifies that the index currently stored in last_index should be renamed to "New_Country1".
# - **``inplace=True``**: This modifies the original DataFrame df1 directly, rather than returning a new DataFrame.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Adding a new observation/row with concat() function:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a New DataFrame:</strong></p>
#
#
# **The following code snippet ``creates a new observation`` as a DataFrame instead of a Series. This is useful for appending multiple rows or maintaining consistent DataFrame formats.**

# %%
# First of all, the new observation/row to be inserted must be converted into a DataFrame:

# Creating a New Row as a DataFrame
new_row2 = pd.DataFrame({'regional_indicator': ['Western Europe'],
                         'ladder_score': [0.000],
                         'logged_gdp_per_capita': [0.000],
                         'social_support': [0.000],
                         'healthy_life_expectancy': [0.000],
                         'freedom_to_make_life_choices': [0.000],
                         'generosity': [0.000],
                         'perceptions_of_corruption': [0.000]},
                        index=['New_Country2'])

# Displaying the Last Five Rows
new_row2
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# New_Country2     Western Europe          0.00                   0.00
#
#               social_support  healthy_life_expectancy  \
# New_Country2            0.00                     0.00
#
#               freedom_to_make_life_choices  generosity  \
# New_Country2                          0.00        0.00
#
#               perceptions_of_corruption
# New_Country2                       0.00

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Concatenating Two DataFrames on Specific Axis:</strong></p>
#
#
# **The following code snippet ``appends the newly created DataFrame new_row2 to the existing DataFrame df1`` using pd.concat().**

# %%
# Concatenating DataFrames
df1 = pd.concat([df1, new_row2])

# Displaying the Last Five Rows
df1.tail(5)
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
# New_Country1      Western Europe          0.00                   0.00
# New_Country2      Western Europe          0.00                   0.00
#
#               social_support  healthy_life_expectancy  \
# Rwanda                  0.55                    61.40
# Zimbabwe                0.75                    56.20
# Afghanistan             0.46                    52.49
# New_Country1            0.00                     0.00
# New_Country2            0.00                     0.00
#
#               freedom_to_make_life_choices  generosity  \
# Rwanda                                0.90        0.06
# Zimbabwe                              0.68       -0.05
# ...

# %% [markdown]
# The result of the concatenation is assigned back to df1, updating it to include the new row.
#
# - **``pd.concat(...)``**: This function is used to concatenate two or more pandas DataFrames along a particular axis (default is along rows).
# - **``[df1, new_row2]``**: This list contains the DataFrames to be concatenated. Here, new_row2 is being added to the end of df1.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Adding a new observation/row with append() function:</strong></p>
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">Knowing the version of pandas can be important for compatibility and understanding the features available in our environment.</p>
#
#
# **⚠️ ``WATCH OUT``** You will get an error of ``AttributeError: module 'pandas' has no attribute 'append'`` if you're using the latest version of Pandas.
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:orange; font-size:125%; text-align:left;">💥 In this analysis Pandas version 1.5.3 has been used for performing append operation.</p>
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;">⛔ append() method is deprecated since Pandas' 2.0 update: Use concat() instead. For further details see Deprecated DataFrame.append and Series.append</p>
#
#   - For further details see **[Deprecated DataFrame.append and Series.append](https://pandas.pydata.org/pandas-docs/version/1.5/whatsnew/v1.4.0.html#whatsnew-140-deprecations-frame-series-append)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code checks the version of the pandas library that we are currently using.**

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a New Entry from the DataFrame itself:</strong></p>
#
#
# **The following code snippet ``selects the row corresponding to Germany`` from the DataFrame df1, ``changes its name``, and effectively ``prepares it as a new observation``.**

# %%
# Instead of writing a new observation, let's pick up the Germany, change its name, and create a new observation/row from it:

# Selecting the Row for Germany
new_row = df1.loc['Germany'] 

# Renaming the New Row
new_row.name = 'New_Country3'

# Displaying the New Row
new_row
# Out:
# regional_indicator              Western Europe
# ladder_score                              7.16
# logged_gdp_per_capita                    10.87
# social_support                            0.90
# healthy_life_expectancy                  72.50
# freedom_to_make_life_choices              0.88
# generosity                                0.01
# perceptions_of_corruption                 0.46
# Name: New_Country3, dtype: object

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Appending New Entry with DataFrame:</strong></p>
#
#
# **The following line ``attempts to add new_row`` (which contains the data from Germany with a new name) to the existing DataFrame df1.**

# %%
# Appending the Row
df1= df1.append(new_row)

# Displaying the last five rows
df1.tail(5)

# FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
# New_Country1      Western Europe          0.00                   0.00
# New_Country2      Western Europe          0.00                   0.00
# New_Country3      Western Europe          7.16                  10.87
#
#               social_support  healthy_life_expectancy  \
# Zimbabwe                0.75                    56.20
# Afghanistan             0.46                    52.49
# New_Country1            0.00                     0.00
# New_Country2            0.00                     0.00
# New_Country3            0.90                    72.50
#
#               freedom_to_make_life_choices  generosity  \
# Zimbabwe                              0.68       -0.05
# Afghanistan                           0.38       -0.10
# ...

# %% [markdown]
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;">⛔ The warning we encountered indicates that the ``append()`` method is deprecated in pandas and will be removed in future versions. Instead, it is recommended to use ``pd.concat()`` for adding rows or combining DataFrames.</p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="text-align: center;"><img src="https://i.ibb.co/hYWQVd6/append-feature-warning.png" class="img-fluid"
# alt="CLRSWY"></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Display the updated DataFrame

df1
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Finland           Western Europe          7.84                  10.78
# Denmark           Western Europe          7.62                  10.93
# Switzerland       Western Europe          7.57                  11.12
# Iceland           Western Europe          7.55                  10.88
# Netherlands       Western Europe          7.46                  10.93
# ...                          ...           ...                    ...
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
# New_Country1      Western Europe          0.00                   0.00
# New_Country2      Western Europe          0.00                   0.00
# New_Country3      Western Europe          7.16                  10.87
#
#               social_support  healthy_life_expectancy  \
# Finland                 0.95                    72.00
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Dropping New Entries:</strong></p>
#
#
# **The following code snippet ``removes the rows`` with the index labels ``"New_Country1"`` and ``"New_Country2"`` from the DataFrame.**

# %%
# Dropping the specified rows
df1.drop(["New_Country1", "New_Country2"], inplace=True)

# Display the last five roes of updated DataFrame
df1.tail(5)
# Out:
#               regional_indicator  ladder_score  logged_gdp_per_capita  \
# Botswana      Sub-Saharan Africa          3.47                   9.78
# Rwanda        Sub-Saharan Africa          3.42                   7.68
# Zimbabwe      Sub-Saharan Africa          3.15                   7.94
# Afghanistan           South Asia          2.52                   7.70
# New_Country3      Western Europe          7.16                  10.87
#
#               social_support  healthy_life_expectancy  \
# Botswana                0.78                    59.27
# Rwanda                  0.55                    61.40
# Zimbabwe                0.75                    56.20
# Afghanistan             0.46                    52.49
# New_Country3            0.90                    72.50
#
#               freedom_to_make_life_choices  generosity  \
# Botswana                              0.82       -0.25
# Rwanda                                0.90        0.06
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# df1.drop(["New_Country1", "New_Country2", "New_Country3"], axis=0, inplace=True)
# df1.tail(5)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# #### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Changing the order of columns</p>
#
# Changing the order of columns in a DataFrame is a common data manipulation task in pandas that allows you to organize and present data more effectively. This can be particularly useful for enhancing readability, aligning data with specific analytical needs, or preparing datasets for visualization. You can reorder columns by specifying a new order in a list and using indexing, or by utilizing the reindex() method. This flexibility enables you to tailor your DataFrame's structure to better suit your analysis or reporting requirements, ensuring that the most relevant information is prominently displayed. Whether you are preparing data for a presentation or simply optimizing your workflow, rearranging columns can significantly improve data accessibility and interpretation.
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Ordering the features based on desired sequence using loc[...]:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The command df.head(3) retrieves the first three rows of the DataFrame.**

# %%
df.head(3)
# Out:
#              regional_indicator  ladder_score  logged_gdp_per_capita  \
# Country name
# Finland          Western Europe          7.84                  10.78
# Denmark          Western Europe          7.62                  10.93
# Switzerland      Western Europe          7.57                  11.12
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# Switzerland                           0.92        0.03
#
#               perceptions_of_corruption
# Country name
# Finland                            0.19
# Denmark                            0.18
# Switzerland                        0.29

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's MANUALLY put the "ladder_score" feature/column at the end:</strong></p>
#
#
# **To move the "ladder_score" column to the end of the DataFrame while maintaining the order of the other columns, we can modify the new_column_order list to reflect this change.**

# %%
df.columns
# Out:
# Index(['regional_indicator', 'ladder_score', 'logged_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %%
# Define the New Column Order
new_column_order = ['regional_indicator', 'logged_gdp_per_capita', 'social_support', 'healthy_life_expectancy',
                   "freedom_to_make_life_choices", "generosity", "perceptions_of_corruption", "ladder_score"]

# Rearranging the DataFrame
df = df.loc[:, new_column_order]

# Displaying the First Three Rows
df.head(3)
# Out:
#              regional_indicator  logged_gdp_per_capita  social_support  \
# Country name
# Finland          Western Europe                  10.78            0.95
# Denmark          Western Europe                  10.93            0.95
# Switzerland      Western Europe                  11.12            0.94
#
#               healthy_life_expectancy  freedom_to_make_life_choices  \
# Country name
# Finland                         72.00                          0.95
# Denmark                         72.70                          0.95
# Switzerland                     74.40                          0.92
#
#               generosity  perceptions_of_corruption  ladder_score
# Country name
# Finland            -0.10                       0.19          7.84
# Denmark             0.03                       0.18          7.62
# Switzerland         0.03                       0.29          7.57

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Ordering the features based on desired sequence using iloc[...]:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's take the "ladder_score" column to the beginning (Using Index Numbers):</strong></p>
#
# **The command len(df.columns) ``retrieves the number of columns`` in the DataFrame.**

# %%
len(df.columns)
# Out:
# 8

# %% [markdown]
# - **``df.columns``**: This attribute returns the index of the column labels in the DataFrame.
# - **``len()``**: This function calculates the length of the object passed to it. In this case, it returns the number of columns in df.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``rearranges the columns`` of the DataFrame using ``integer-based indexing with iloc``.**

# %%
# Defining the New Column Order
new_column_order = [7, 0, 1, 2, 3, 4, 5, 6]  

# Rearranging the DataFrame
df = df.iloc[:, new_column_order]

# Displaying the First Three Rows
df.head(3)
# Out:
#               ladder_score regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84     Western Europe                  10.78
# Denmark               7.62     Western Europe                  10.93
# Switzerland           7.57     Western Europe                  11.12
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# Switzerland                           0.92        0.03
#
#               perceptions_of_corruption
# Country name
# Finland                            0.19
# Denmark                            0.18
# Switzerland                        0.29

# %% [markdown]
# - **``df.iloc[:, new_column_order]``**: This selects all rows (:) and the columns specified by new_column_order. The DataFrame is updated to reflect this new column arrangement.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Updating the DataFrame by selecting the feature/columns in the desired order:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The command df.columns ``retrieves the column labels`` of the DataFrame.**

# %%
# Display the column names

df.columns
# Out:
# Index(['ladder_score', 'regional_indicator', 'logged_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %% [markdown]
# - **``df.columns``**: This attribute returns an Index object containing the column names of the DataFrame. It provides a convenient way to view all the column labels currently in the DataFrame.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's MANUALLY take the "ladder_score" column to the beginning:</strong></p>
#
# **The following code snippet ``rearranges the columns`` of the DataFrame to a ``specified order``.**

# %%
# Defining the New Column Order
new_column_order = ['regional_indicator', 'logged_gdp_per_capita',
                    'social_support', 'healthy_life_expectancy',
                    'freedom_to_make_life_choices', 'generosity',
                    'perceptions_of_corruption', 'ladder_score']

# Rearranging the DataFrame:
df = df[new_column_order]

# Displaying the First Three Row
df.head(3)
# Out:
#              regional_indicator  logged_gdp_per_capita  social_support  \
# Country name
# Finland          Western Europe                  10.78            0.95
# Denmark          Western Europe                  10.93            0.95
# Switzerland      Western Europe                  11.12            0.94
#
#               healthy_life_expectancy  freedom_to_make_life_choices  \
# Country name
# Finland                         72.00                          0.95
# Denmark                         72.70                          0.95
# Switzerland                     74.40                          0.92
#
#               generosity  perceptions_of_corruption  ladder_score
# Country name
# Finland            -0.10                       0.19          7.84
# Denmark             0.03                       0.18          7.62
# Switzerland         0.03                       0.29          7.57

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Updating column index order by `reindex()` method:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's take the "ladder_score" column to the beginning again (Using reindex() method):</strong></p>
#
#
# **The following code snippet ``rearranges the columns`` of the DataFrame ``using the reindex()`` method.**

# %%
# Defining the New Column Order
new_column_order = ['ladder_score', 'regional_indicator', 'logged_gdp_per_capita',
                    'social_support', 'healthy_life_expectancy',
                    'freedom_to_make_life_choices', 'generosity',
                    'perceptions_of_corruption']

# Reindexing the DataFrame
df = df.reindex(columns=new_column_order)

# Displaying the First Three Rows
df.head(3)
# Out:
#               ladder_score regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84     Western Europe                  10.78
# Denmark               7.62     Western Europe                  10.93
# Switzerland           7.57     Western Europe                  11.12
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# Switzerland                           0.92        0.03
#
#               perceptions_of_corruption
# Country name
# Finland                            0.19
# Denmark                            0.18
# Switzerland                        0.29

# %% [markdown]
# Using **``reindex()``** is an effective way to rearrange the columns of our DataFrame while preserving the existing data. This functionality is particularly useful for organizing data in a format that is more suitable for analysis or presentation.
#
#
# - The **``reindex()``** method is used to rearrange the columns according to the specified new_column_order. This method also allows for flexibility in adding or removing columns, but in this case, it is purely for reordering.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Updating & Modifying Rows</p>
#
# Updating and modifying rows in a pandas DataFrame is a crucial aspect of data manipulation that allows analysts to refine and adjust datasets for accurate analysis. This process involves altering existing data based on specific criteria or conditions, enabling users to correct errors, fill in missing values, or apply transformations. By utilizing methods such as ``.loc[]``, ``.iloc[]``, or boolean indexing, users can efficiently access and modify individual rows or subsets of data. This flexibility not only enhances the quality of the dataset but also ensures that the data accurately reflects the underlying phenomena being studied, ultimately leading to more reliable insights and conclusions. Whether adjusting values for a single observation or applying changes across multiple rows, effective row modification is essential for maintaining data integrity and relevance.
#
# - **to update one row** --> ``df1.loc[2, ['last_name', 'email']] = ['Smith', 'JohnSmith@email.com']``
# - **to update multiple rows** : We have several options:
#   - First is the basic one: ``df['email']= df['email'].str.lower()``
#   - Advance Options:
#     - **``Apply``**: Works both on Series (one column) and DataFrames. But mostly use with Series:
#        - **``Apply on series``** --> ``df['email'].apply(len)`` <-- it gives the length of the email on the email column(e-mail series)
#     - **``Replace``**: Works like map, but keeps the NOT defined values intact.
#       - ``df['first_name'].replace{'chris':'Mike','jane':'Angela'}`` <-- John keeps its value.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The command ``df2 = df.copy()`` creates a ``copy of the DataFrame df`` and ``assigns it to a new variable df2``.**

# %%
# Creating a Copy of the DataFrame
df2 = df.copy()

# Displaying the First Few Rows
df2.head()
# Out:
#               ladder_score regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84     Western Europe                  10.78
# Denmark               7.62     Western Europe                  10.93
# Switzerland           7.57     Western Europe                  11.12
# Iceland               7.55     Western Europe                  10.88
# Netherlands           7.46     Western Europe                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Updating & Modifying operations with loc [...]:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Update the ladder score of Afghanistan as South_Asia's mean value.**
#
# **The following command ``counts the occurrences of each unique value in the regional_indicator`` column of the DataFrame.**

# %%
# Calculate the frequency of each unique value in the "regional_indicator" column

df2["regional_indicator"].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: regional_indicator, dtype: Int64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the Average of ladder_score by regional_indicator:</strong></p>
#
#
# **The following command ``calculates the mean (average) of the ladder_score for each unique value in the regional_indicator`` column of the DataFrame.**

# %%
# Grouping the DataFrame, Selecting the "ladder_score" Column, and Calculating the Mean
df2.groupby("regional_indicator")["ladder_score"].mean()

# the mean of South Asia is 4.44
# Out:
# regional_indicator
# Central and Eastern Europe           5.98
# Commonwealth of Independent States   5.47
# East Asia                            5.81
# Latin America and Caribbean          5.91
# Middle East and North Africa         5.22
# North America and ANZ                7.13
# South Asia                           4.44
# Southeast Asia                       5.41
# Sub-Saharan Africa                   4.49
# Western Europe                       6.91
# Name: ladder_score, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following command ``retrieves the mean of ladder_score`` for the ``region labeled "South Asia"`` from the previously calculated Series mean_ladder_by_regional.**

# %%
# Calculating Mean Ladder Scores by Region
mean_ladder_by_regional = df2.groupby("regional_indicator").ladder_score.mean()

# Accessing the Mean Value for South Asia
mean_ladder_by_regional["South Asia"]
# Out:
# 4.441857142857143

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following command ``calculates the mean of ladder_score`` specifically for the ``region labeled "South Asia"``.**

# %%
# OR if we just want to see the value of any group we can use the get_group() method: 

df2.groupby("regional_indicator").get_group("South Asia").ladder_score.mean()
# Out:
# 4.441857142857143

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Filtering the Data Based on South Asia:</strong></p>
#
#
# **The following command ``filters the DataFrame`` to return ``only the rows where the regional_indicator column is equal to "South Asia"``.**

# %%
# Filtering the DataFrame
df2[df2.regional_indicator == "South Asia"]

# df.groupby(['regional_indicator']).get_group('South Asia')
# Out:
#               ladder_score regional_indicator  logged_gdp_per_capita  \
# Country name
# Nepal                 5.27         South Asia                   8.12
# Maldives              5.20         South Asia                   9.83
# Bangladesh            5.03         South Asia                   8.45
# Pakistan              4.93         South Asia                   8.46
# Sri Lanka             4.33         South Asia                   9.47
# India                 3.82         South Asia                   8.76
# Afghanistan           2.52         South Asia                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# Nepal                   0.77                    64.23
# Maldives                0.91                    70.60
# Bangladesh              0.69                    64.80
# Pakistan                0.65                    58.71
# Sri Lanka               0.83                    67.30
# India                   0.60                    60.63
# ...

# %% [markdown]
# - This expression creates a **``boolean mask``** that checks each value in the regional_indicator column to see **``if it matches "South Asia"``**.
# - The DataFrame is then indexed using this boolean mask, returning **``only the rows where the condition is True``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Finding Ladder Score of a Specific Country:</strong></p>
#
#
# **The following command ``retrieves the ladder_score`` for the row in the DataFrame ``where the index is labeled 'Afghanistan'``.**

# %%
# Accessing the Row by Index and Selecting the ladder_score Column

df2.loc['Afghanistan']["ladder_score"]
# Out:
# 2.523

# %% [markdown]
# - The loc method is used to access a row in the DataFrame by its index label. In this case, it retrieves the entire row corresponding to 'Afghanistan'.
# - After accessing the row, this part selects the ladder_score value from that row.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Changing the Ladder Score of a Specific Country:</strong></p>
#
#
# **The following code first retrieves the row in the DataFrame where the index is 'Afghanistan'. This results in a Series representing that specific row. And it accesses the value in the ladder_score column of the Series obtained in the previous step. Then the code attempts to assign the value of mean_ladder_by_regional["South Asia"] to the ladder_score field for the row corresponding to 'Afghanistan'.**

# %%
# Be carefull about the following WARNING !!!!

df2.loc['Afghanistan']         ["ladder_score"]                 = mean_ladder_by_regional["South Asia"]
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5304\2768612492.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc['Afghanistan']         ["ladder_score"]                 = mean_ladder_by_regional["South Asia"]

# %% [markdown]
# The **``warning message``** above is a **``"SettingWithCopyWarning"``** in Pandas. This warning occurs when we are **``trying to modify (assign a value) a slice of a DataFrame that is a copy of the original data``**, rather than a view of it, which can lead to unexpected behavior.
# - To avoid this warning and ensure that we are modifying the original DataFrame, we can use the **``.loc accessor``** in a single operation without chaining the indexing.
#   - **``Use .loc correctly``**: Make sure to access the DataFrame in one step, like so:
#     - df2.loc['Afghanistan', 'ladder_score'] = mean_ladder_by_regional["South Asia"]
#
# By using this approach, we directly update the DataFrame without creating a copy, which helps avoid the warning.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;"><strong>🤔💭 What Happened❓ </strong></p>
#
#
# **The following expression ``retrieves the value from the ladder_score column`` for the row ``where the index is 'Afghanistan'`` in the DataFrame.**

# %%
df2.loc['Afghanistan']["ladder_score"]

# Ladder score could NOT be updated!! because we didn't select ladder_score with loc!!
# Out:
# 2.523

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Changing the Ladder Score of a Specific Country (Using loc[]):</strong></p>
#
#
# **By using the following single operation, we directly access the specific element in the DataFrame and modify it in place, avoiding any potential issues with chained indexing and copies of the data.**

# %%
# Update the ladder_score for 'Afghanistan'.
df2.loc['Afghanistan', 'ladder_score'] = mean_ladder_by_regional["South Asia"] 

# Display the updated value that was just assigned.
df2.loc['Afghanistan']["ladder_score"]
# Out:
# 4.441857142857143

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Updating & Modifying operations with apply() method:</strong></p>
#
#
# **The following code shows the first five values in the healthy_life_expectancy column, along with their index positions.**

# %%
df2['healthy_life_expectancy'].head()
# Out:
# Country name
# Finland       72.00
# Denmark       72.70
# Switzerland   74.40
# Iceland       73.00
# Netherlands   72.40
# Name: healthy_life_expectancy, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``applies`` the NumPy function ``np.square`` to ``each value in the healthy_life_expectancy`` column of the DataFrame.**

# %%
# Accessing the Column and Applying the Function

df2['healthy_life_expectancy'].apply(np.square)
# Out:
# Country name
# Finland       5184.00
# Denmark       5285.29
# Switzerland   5535.36
# Iceland       5329.00
# Netherlands   5241.76
#                 ...
# Lesotho       2371.69
# Botswana      3512.81
# Rwanda        3769.96
# Zimbabwe      3158.55
# Afghanistan   2755.52
# Name: healthy_life_expectancy, Length: 149, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# Based on the our dataset's **``'Healthy life expectancy' scores``**, lets make a new column with the name of **``'explained_healthy_life_expectancy'``** with the new values which should consist of:
#
# - Let's think **``'Healthy life expectancy''s mean score``** as our **``threshold``**.
#
#   - If 'Healthy life expectancy' is **``equal and greater than 75%``** of the 'Healthy life expectancy' score of the dataset , it should be written **``'Long Life expectancy'``**
#
#   - If 'Healthy life expectancy' **``less than 75%``** of the 'Healthy life expectancy' score of the dataset but bigger than our threshold, it should be written **``'Longer than normal expectancy'``**
#
#   - If 'Healthy life expectancy' **``equal or less than our threshold but bigger than 25%``** of the 'Healthy life expectancy' score of the dataset, it should be written **``'Normal life expectancy'``**
#
#   - If 'Healthy life expectancy' **``equal or less than 25%``** of the 'Healthy life expectancy' score of the dataset, it should be written **``'Lower life expectancy'``**
#
# - Since We have projects with United states make sure that United States should be written as **'United States of America'**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [raw]
#     if life >= _75 :
#         return 'Long life expectancy'
#     elif life > mean  and life < _75:
#         return 'Longer than normal expectancy'
#     elif life  > _25  and life  <= mean:
#         return 'Normal life expectancy'
#     else:
#         return 'Lower life expectancy'

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``retrieves the first five entries`` from the healthy_life_expectancy column of the DataFrame.**

# %%
# Accessing the Column and Getting the First Few Rows

df2['healthy_life_expectancy'].head()
# Out:
# Country name
# Finland       72.00
# Denmark       72.70
# Switzerland   74.40
# Iceland       73.00
# Netherlands   72.40
# Name: healthy_life_expectancy, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Exploring Descriptive Statistics:</strong></p>
#
#
# **The following code provides a ``summary of the statistical properties`` of the healthy_life_expectancy column in the DataFrame.**

# %%
# Display the Descriptive Statistics of 'healthy_life_expectancy'

df2['healthy_life_expectancy'].describe()
# Out:
# count   149.00
# mean     64.99
# std       6.76
# min      48.48
# 25%      59.80
# 50%      66.60
# 75%      69.60
# max      76.95
# Name: healthy_life_expectancy, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Extracting the Mean from Descriptive Statistics:</strong></p>
#
#
# **The following code ``extracts the mean value of the healthy_life_expectancy`` column from the DataFrame.**

# %%
# Extracting the Mean and Assigning to a Variable
mean = df2['healthy_life_expectancy'].describe().loc["mean"]

# Display the mean value
mean
# Out:
# 64.99279865771811

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Extracting the Third Quartile from Descriptive Statistics:</strong></p>
#
#
# **The following code snippet ``extracts the 75th percentile value of the healthy_life_expectancy`` column from the DataFrame.**

# %%
# Extracting the 75th Percentile and Assigning to a Variable
_75 = df2['healthy_life_expectancy'].describe().loc["75%"]

# Display the 75th Percentile
_75
# Out:
# 69.6

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Extracting the First Quartile from Descriptive Statistics:</strong></p>
#
#
# **The following code snippet ``extracts the 25th percentile value of the healthy_life_expectancy`` column from the DataFrame.**

# %%
# Extracting the 75th Percentile and Assigning to a Variable
_25 = df2['healthy_life_expectancy'].describe().loc["25%"]

# Display the 75th Percentile
_25
# Out:
# 59.802

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Creating a User Defined Function Based on Conditions:</strong></p>
#
#
# **The following User Defined Function ``long_life(life)`` ``classifies life expectancy values`` into categories based on the ``25th percentile``, ``mean``, and ``75th percentile``.**

# %%
def long_life(life):
    if life >= _75 :
        return 'Long Life expectancy'
    elif life > mean  and life < _75:
        return 'Long life expectancy'
    elif life  > _25  and life  <= mean:
        return 'Normal life expectancy'
    else:
        return 'Low life expectancy'

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Applying the User Defined Function:</strong></p>
#
#
# **The following code enhances the DataFrame by ``adding a new column`` that ``categorizes health life expectancy`` based on the thresholds defined in the long_life function.**
# - The **``sample(7)``** method allows us to **``randomly view a selection of rows``** to verify the results.

# %%
# Apply the long_life function to each value in the healthy_life_expectancy column
df2['explained_health_life_expectancy'] = df2['healthy_life_expectancy'].apply(long_life)

# Retrieve a random sample of 7 rows from the DataFrame 
df2.sample(7)
# Out:
#               ladder_score           regional_indicator  \
# Country name
# Poland                6.17   Central and Eastern Europe
# India                 3.82                   South Asia
# Burkina Faso          4.83           Sub-Saharan Africa
# Chile                 6.17  Latin America and Caribbean
# Zimbabwe              3.15           Sub-Saharan Africa
# Germany               7.16               Western Europe
# Liberia               4.62           Sub-Saharan Africa
#
#               logged_gdp_per_capita  social_support  healthy_life_expectancy  \
# Country name
# Poland                        10.38            0.90                    69.70
# India                          8.76            0.60                    60.63
# Burkina Faso                   7.68            0.67                    54.15
# Chile                         10.07            0.88                    70.00
# Zimbabwe                       7.94            0.75                    56.20
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Accessing a Specific Country:</strong></p>
#
#
# **The following code snippet ``retrieves specific columns`` from the DataFrame for the country ``'Poland'``.**

# %%
# Let's check the findings based on the United States:

df2.loc[['Poland'], ['healthy_life_expectancy', 'explained_health_life_expectancy']]
# Out:
#               healthy_life_expectancy explained_health_life_expectancy
# Country name
# Poland                          69.70             Long Life expectancy

# %% [markdown]
# This code effectively retrieves and displays the specified columns for the country 'Poland', allowing us to see both the life expectancy value and its corresponding classification.
#
# - **``df2.loc[...]``** is used for label-based indexing to select specific rows and columns.
# - **``[['Poland']]``** specifies that you want to access the row where the index is 'Poland'.
# - **``[['healthy_life_expectancy', 'explained_health_life_expectancy']]``** specifies that you want to access the columns named healthy_life_expectancy and explained_health_life_expectancy.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Let's update the ``healthy_life_expectancy`` column with ``explained_health_life_expectancy`` values and drop the ``explained_health_life_expectancy`` column later:**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Updating healthy_life_expectancy Feature:</strong></p>
#
#
# **The following code ``replaces the numerical life expectancy values with their corresponding classifications`` and then ``removes the intermediate classification column``, streamlining the DataFrame to focus only on the new healthy_life_expectancy classifications.**
# - The **``sample(5)``** method allows us to **``randomly inspect a few rows``** of the resulting DataFrame.

# %%
# Replace the numerical life expectancy values with their corresponding classifications
df2['healthy_life_expectancy'] = df2['explained_health_life_expectancy']

# Dropping a Column
df2.drop("explained_health_life_expectancy", axis=1, inplace=True)

# Display the Updated DataFrame
df2.sample(5)
# Out:
#                 ladder_score            regional_indicator  \
# Country name
# Czech Republic          6.96    Central and Eastern Europe
# North Cyprus            5.54                Western Europe
# Poland                  6.17    Central and Eastern Europe
# Nepal                   5.27                    South Asia
# Morocco                 4.92  Middle East and North Africa
#
#                 logged_gdp_per_capita  social_support healthy_life_expectancy  \
# Country name
# Czech Republic                  10.56            0.95    Long Life expectancy
# North Cyprus                    10.58            0.82    Long Life expectancy
# Poland                          10.38            0.90    Long Life expectancy
# Nepal                            8.12            0.77  Normal life expectancy
# Morocco                          8.90            0.56    Long life expectancy
#
#                 freedom_to_make_life_choices  generosity  \
# Country name
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 Updating & Modifying operations with `replace()` method:</strong></p>
#
# - **``Replace``**: Works like map, but keeps the values not defined intact.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Let's update the "Long life expectancy" values in the ``'healthy_life_expectancy'`` column with "Don't worry, be happy, life is short"**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Updating the Value of Specific Country on healthy_life_expectancy Feature:</strong></p>
#
#
# **The following code ``replaces`` occurrences of the string ``'Long Life expectancy'`` in the healthy_life_expectancy column with the ``new string "Don't worry, be happy, life is short"``.**

# %%
# Replacing Values
df2['healthy_life_expectancy'].replace({'Long Life expectancy': "Don't worry, be happy, life is short"}, inplace=True)

# While using replace() method, we do NOT need to write all unique values as we do in map() method!

# Accessing a Specific Value
df2.loc['Poland', 'healthy_life_expectancy']
# Out:
# "Don't worry, be happy, life is short"

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Groupby operations</p>

# %% [markdown]
# **Let's assume a scenario where we need to find the ``average happiness scores (Ladder score)`` of the ``regions``.**
#
# **Basen on this scenario, what can we say?**
# - Can it be concluded that happiness is likely to differ by region?
# - Can it be concluded that happiness is likely to differ by region?
# - Can it be assumed that the average happiness score for one region would be higher than others?
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.head()`` in pandas will display the ``first five rows`` of your DataFrame. This function is useful for quickly ``inspecting the data and understanding its structure and contents``:**

# %%
# Display the first five rows of the DataFrame

df.head()
# Out:
#               ladder_score regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84     Western Europe                  10.78
# Denmark               7.62     Western Europe                  10.93
# Switzerland           7.57     Western Europe                  11.12
# Iceland               7.55     Western Europe                  10.88
# Netherlands           7.46     Western Europe                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Using ``df.columns`` in pandas returns the ``list of column name``s in our DataFrame. This is useful for quickly viewing the structure of our dataset and understanding what data we have available.**

# %%
# Display the column names of the DataFrame

df.columns
# Out:
# Index(['ladder_score', 'regional_indicator', 'logged_gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Exploring the Counts of Unique Values by Regions:</strong></p>
#
#
# **The following code snippet ``counts the occurrences of each unique value`` in the ``regional_indicator`` column of the DataFrame.**

# %%
# Count the number of occurrences of each unique value

df["regional_indicator"].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: regional_indicator, dtype: Int64

# %% [markdown]
# The .value_counts() method counts the number of occurrences of each unique value in the regional_indicator column. It returns a Series where the index consists of the unique values and the values are the counts.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Exploring the Percentage of Unique Values by Regions:</strong></p>
#
#
# **The following code snippet calculates the percentage of each unique value in the regional_indicator column of the DataFrame.**

# %%
# The percentages of each unique value

df["regional_indicator"].value_counts(normalize=True)*100
# Out:
# Sub-Saharan Africa                   24.16
# Western Europe                       14.09
# Latin America and Caribbean          13.42
# Middle East and North Africa         11.41
# Central and Eastern Europe           11.41
# Commonwealth of Independent States    8.05
# Southeast Asia                        6.04
# South Asia                            4.70
# East Asia                             4.03
# North America and ANZ                 2.68
# Name: regional_indicator, dtype: Float64

# %% [markdown]
# The result will be a Series where the index consists of unique values from the regional_indicator column, and the values are the percentages of each unique value. This code provides a quick way to understand the distribution of categories within the regional_indicator column in terms of percentage, giving insights into the relative size of each category compared to the total.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Exploring the Index of DataFrame:</strong></p>
#
#
# **The following expression ``retrieves the index`` of the DataFrame.**

# %%
# Access to the index of the DataFrame

df.index
# Out:
# Index(['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 'Norway',
#        'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
#        ...
#        'Burundi', 'Yemen', 'Tanzania', 'Haiti', 'Malawi', 'Lesotho',
#        'Botswana', 'Rwanda', 'Zimbabwe', 'Afghanistan'],
#       dtype='object', name='Country name', length=149)

# %% [markdown]
# **``df.index``** gives you access to the index of the DataFrame, which is a label that identifies each row in the DataFrame. The index can be thought of as the row identifiers. Using df.index is helpful for understanding how the DataFrame is structured in terms of row labels, which can be useful for data manipulation and selection operations.
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code creates a DataFrameGroupBy object.**
# - This object allows us to perform operations on grouped data, but it does not yet return any results. Instead, it prepares the data for further analysis.

# %%
# Group by the Data

df.groupby(['regional_indicator'])

# %% [markdown]
# The output **``<pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001F21F6E91F0>``** indicates that we are looking at a **``DataFrameGroupBy object``** in pandas. This object is created when we use the **``groupby()``** method on a DataFrame.
# - When we call **``df.groupby(...)``**, pandas creates a **``DataFrameGroupBy object``**. This object allows us to perform operations on grouped data, but it does NOT yet return any results. Instead, it prepares the data for further analysis.
# - **Memory Address:**
#   - The **``0x000001F21F6E91F0 part of the output``** indicates the **``memory address``** where this object is stored. This is specific to our session and will differ each time we run the code.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the Average Ladder Score by Regions:</strong></p>
#
#
# **The following code snippet ``calculates the average ladder score for each unique value`` in the regional_indicator column of the DataFrame.**

# %%
# Let's find the average ladder score of the regions:

df.groupby(['regional_indicator']).ladder_score.mean()
# Out:
# regional_indicator
# Central and Eastern Europe           5.98
# Commonwealth of Independent States   5.47
# East Asia                            5.81
# Latin America and Caribbean          5.91
# Middle East and North Africa         5.22
# North America and ANZ                7.13
# South Asia                           4.44
# Southeast Asia                       5.41
# Sub-Saharan Africa                   4.49
# Western Europe                       6.91
# Name: ladder_score, dtype: float64

# %% [markdown]
# - **Grouping the Data**: ``df.groupby(['regional_indicator'])``
#   - This part of the code groups the DataFrame by the values in the regional_indicator column. Each unique value in this column will represent a group.
# - **Selecting the Column**: ``.ladder_score``
#   - After grouping, this selects the ladder_score column from the grouped object. This means you are focusing on the ladder scores within each group.
# - **Calculating the Mean**: ``.mean()``
#   - Finally, this calculates the mean (average) of the ladder_score for each group created by the groupby operation.
#
# **Result:**
# - The result will be a Series where the index consists of unique values from the regional_indicator column, and the values are the average ladder scores for each of those regions.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Calculating the Overall Average Ladder Score:</strong></p>
#
#
# **The following code ``calculates the overall average (mean) of the ladder_score`` column in the DataFrame.**

# %%
# Let's find the overall average of the ladder score:

df.ladder_score.mean()
# Out:
# 5.532838926174497

# %% [markdown]
# This line of code efficiently **``computes the overall average ladder score across all entries``** in the DataFrame, providing a quick summary statistic that can be useful for understanding the general performance indicated by the ladder scores.
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>👉 Exploring the Average Ladder Score by a Specific Region:</strong></p>
#
#
# **The following code snippet ``calculates the average ladder score specifically for the region "Central and Eastern Europe"`` within the DataFrame.**

# %%
# Let's find the average of the ladder score in Central and Eastern Europe:

df.groupby(['regional_indicator']).get_group("Central and Eastern Europe").ladder_score.mean()
# Out:
# 5.984764705882353

# %% [markdown]
# - **Grouping the Data**: ``df.groupby(['regional_indicator'])``
#   - This part groups the DataFrame by the values in the regional_indicator column. Each unique value in this column will create its own group.
#
# - **Selecting the Group**: ``.get_group("Central and Eastern Europe")``
#   - This method retrieves the group corresponding to the "Central and Eastern Europe" region from the grouped object.
#
# - **Accessing the Column**: ``.ladder_score``
#   - After obtaining the specific group, this selects the ladder_score column from that group.
# - **Calculating the Mean**: ``.mean()``
#   - Finally, this calculates the mean (average) of the ladder_score values for the "Central and Eastern Europe" group.
#
# **Result:**
# - The result will be a single numerical value representing the average ladder score for the "Central and Eastern Europe" region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``calculates the average ladder score specifically for the region "Middle East and North Africa"`` within the DataFrame.**

# %%
# Let's find the average of the ladder score in Middle East and North Africa:

df.groupby(['regional_indicator']).get_group("Middle East and North Africa").ladder_score.mean()
# Out:
# 5.219764705882353

# %% [markdown]
# - **Grouping the Data**: ``df.groupby(['regional_indicator'])``
#   - This part groups the DataFrame by the values in the regional_indicator column. Each unique value in this column will create its own group.
#
# - **Selecting the Group**: ``.get_group("Middle East and North Africa")``
#   - This method retrieves the group corresponding to the "Middle East and North Africa" region from the grouped object.
#
# - **Accessing the Column**: ``.ladder_score``
#   - After obtaining the specific group, this selects the ladder_score column from that group.
# - **Calculating the Mean**: ``.mean()``
#   - Finally, this calculates the mean (average) of the ladder_score values for the "Middle East and North Africa" group.
#
# **Result:**
# - The result will be a single numerical value representing the average ladder score for the "Middle East and North Africa" region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``calculates the average ladder score specifically for the region "South Asia`` within the DataFrame.**

# %%
# Let's find the average of the ladder score in South Asia:

df.groupby(['regional_indicator']).get_group("South Asia").ladder_score.mean()
# Out:
# 4.441857142857143

# %% [markdown]
# - **Grouping the Data**: ``df.groupby(['regional_indicator'])``
#   - This part groups the DataFrame by the values in the regional_indicator column. Each unique value in this column will create its own group.
#
# - **Selecting the Group**: ``.get_group("South Asia")``
#   - This method retrieves the group corresponding to the "South Asia" region from the grouped object.
#
# - **Accessing the Column**: ``.ladder_score``
#   - After obtaining the specific group, this selects the ladder_score column from that group.
# - **Calculating the Mean**: ``.mean()``
#   - Finally, this calculates the mean (average) of the ladder_score values for the "South Asia" group.
#
# **Result:**
# - The result will be a single numerical value representing the average ladder score for the "South Asia" region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``calculates the average ladder score specifically for the region "Western Europe`` within the DataFrame.**

# %%
# Let's find the average of the ladder score in Western Europe:

df.groupby(['regional_indicator']).get_group("Western Europe").ladder_score.mean()
# Out:
# 6.914904761904763

# %% [markdown]
# - **Grouping the Data**: ``df.groupby(['regional_indicator'])``
#   - This part groups the DataFrame by the values in the regional_indicator column. Each unique value in this column will create its own group.
#
# - **Selecting the Group**: ``.get_group("Western Europe")``
#   - This method retrieves the group corresponding to the "Western Europe" region from the grouped object.
#
# - **Accessing the Column**: ``.ladder_score``
#   - After obtaining the specific group, this selects the ladder_score column from that group.
# - **Calculating the Mean**: ``.mean()``
#   - Finally, this calculates the mean (average) of the ladder_score values for the "Western Europe" group.
#
# **Result:**
# - The result will be a single numerical value representing the average ladder score for the "Western Europe" region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>VISUALIZATION:</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Visually display the ``average corruption perception index`` (perceptions_of_corruption) by ``region``:**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code snippet ``calculates the average perceptions of corruption for each region`` defined in the regional_indicator column of the DataFrame.**

# %%
# Calculate the average perceptions of corruption by region
region_cpi = df.groupby('regional_indicator')['perceptions_of_corruption'].mean()

# Display the Result
region_cpi
# Out:
# regional_indicator
# Central and Eastern Europe           0.85
# Commonwealth of Independent States   0.73
# East Asia                            0.68
# Latin America and Caribbean          0.79
# Middle East and North Africa         0.76
# North America and ANZ                0.45
# South Asia                           0.80
# Southeast Asia                       0.71
# Sub-Saharan Africa                   0.77
# Western Europe                       0.52
# Name: perceptions_of_corruption, dtype: float64

# %% [markdown]
# - **Grouping the Data**: ``df.groupby('regional_indicator')``
#   - This groups the DataFrame df by the values in the regional_indicator column, creating separate groups for each unique region.
# - **Selecting the Column**: ``['perceptions_of_corruption']``
#   - After grouping, this selects the perceptions_of_corruption column from the grouped object, focusing on that specific variable.
# - **Calculating the Mean**: ``.mean()``
#   - This method computes the mean (average) of the perceptions_of_corruption values for each group (region).
#
# **Result:**
# - The result will be a Series where the index consists of unique values from the regional_indicator column, and the values are the average perceptions of corruption for each region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``retrieves the index of the Series region_cpi``, which contains the average perceptions of corruption for each region.**

# %%
# Display the indices of the region_cpi

region_cpi.index
# Out:
# Index(['Central and Eastern Europe', 'Commonwealth of Independent States',
#        'East Asia', 'Latin America and Caribbean',
#        'Middle East and North Africa', 'North America and ANZ', 'South Asia',
#        'Southeast Asia', 'Sub-Saharan Africa', 'Western Europe'],
#       dtype='string', name='regional_indicator')

# %% [markdown]
# - **Accessing the Index:**
#   - **``region_cpi.index``** provides the labels of the index for the Series. In this case, the index consists of the unique values from the regional_indicator column, which represent different geographical regions.
# - **Result:**
#   - The output will be an Index object containing the names of the regions for which the average perceptions of corruption were calculated.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``retrieves the values of the Series region_cpi``, which contains the average perceptions of corruption for each region.**

# %%
# Display the values of the region_cpi

region_cpi.values
# Out:
# array([0.85052941, 0.72508333, 0.68333333, 0.7926    , 0.76223529,
#        0.44925   , 0.79742857, 0.70911111, 0.76594444, 0.52309524])

# %% [markdown]
# - **Accessing the Values:**
#   - **``region_cpi.values``** provides an array of the values in the Series. In this case, these values represent the average perceptions of corruption corresponding to each region.
#
# - **Result:**
#   - The output will be a NumPy array containing the average perceptions of corruption for the regions indexed in region_cpi.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet creates a ``bar plot`` to visualize the ``average perceptions of corruption by region`` using matplotlib and seaborn.**

# %%
# Initializing a new figure and axes with a specified size of 10 inches wide and 4 inches tall.
fig, ax = plt.subplots(figsize=(10, 4))

# Creating a bar plot 
sns.barplot(x=region_cpi.index, y=region_cpi.values, order=region_cpi.sort_values(ascending=False).index) # x eksenindeki sıralamayı değiştirdik.

# Adding Title and Labels
plt.title('Average of Perceptions of Corruption by Regional Indicator', fontsize=14, c="darkblue")
plt.xlabel('Regions', fontsize=12)
plt.ylabel('perceptions_of_corruption', fontsize=12)

# Customizing Ticks
plt.xticks(fontsize=10,rotation=80)

# Adding Bar Labels
ax.bar_label(ax.containers[0], size = 8, c="darkred");

# %% [markdown]
# - **``Regional Differences``**: The visualization highlights significant disparities in perceptions of corruption across different regions. For instance, regions with higher average scores may indicate a widespread belief in corruption among government officials and institutions, while regions with lower scores might be perceived as having more effective governance and transparency.
# - **``Identifying Critical Areas``**: Regions that appear at the top of the chart with the highest perceptions of corruption could be areas of concern for policymakers and stakeholders. This suggests that these regions might benefit from targeted anti-corruption efforts, reforms in governance, or increased public accountability measures.
# - **``Potential for Improvement``**: Conversely, regions with lower perceptions of corruption may serve as models for best practices. Understanding what measures or policies these regions have implemented could provide valuable lessons for improving governance in higher-corruption areas.
# - **``Cultural and Societal Factors``**: The results may also reflect deeper cultural and societal attitudes towards authority and governance. Regions with a history of political instability or weak institutions might show higher levels of corruption perception.
# - **``Implications for Development``**: High perceptions of corruption can negatively affect economic development, foreign investment, and public trust in government. The visualization can help stakeholders prioritize regions for intervention and resource allocation to address these challenges.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Show the distribution of the ``'perceptions_of_corruption'`` in the dataset:**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``creates a kernel density estimate (KDE) plot`` to visualize the ``distribution of perceptions of corruption`` within the DataFrame.**

# %%
# Creating the Figure and Axes
fig, ax = plt.subplots(figsize=(10, 4))

# Creating the KDE Plot
sns.kdeplot(df, x="perceptions_of_corruption")

# Adding Title
plt.title('Density of Perceptions of Corruption', fontsize=14, c="darkblue");

# %% [markdown]
# When a kernel density estimate (KDE) plot is left-skewed (or negatively skewed), it indicates that most of the data points are concentrated towards the higher end of the scale, with a longer tail extending towards the lower values. Here's how to interpret this skewness based on the perceptions of corruption data set:
#
# **Interpretation of Left Skewness:**
# - **``Concentration of High Perceptions``**:
#   - A left-skewed distribution suggests that a majority of respondents perceive corruption levels to be relatively low. This can indicate a general sentiment that institutions and governance in the region are seen as more trustworthy.
# - **``Fewer Low Perception Values``**:
#   - The tail on the left side of the distribution indicates that there are fewer cases where perceptions of corruption are very high. This could mean that extreme negative views about corruption are not commonly held within the population surveyed.
# - **``Implications for Governance``**:
#   - If the majority of the population perceives low levels of corruption, this could be a positive sign for the effectiveness of governance and public institutions. It may reflect successful anti-corruption measures or a cultural norm that emphasizes integrity.
# - **``Potential for Improvement``**:
#   - While a left-skewed distribution is generally positive, it’s important to consider the context. If there are outlier cases of high corruption perceptions (visible in the left tail), these may require targeted interventions or reforms to address specific issues.
# - **``Public Trust``**:
#   - The perception of lower corruption can correlate with higher public trust in government and institutions, which is crucial for the stability and development of society.
#
# In summary, a left-skewed KDE plot of perceptions of corruption suggests that most respondents view corruption as low, indicating positive governance perceptions. However, the presence of any outliers or extreme cases should be investigated further to ensure that specific issues are not overlooked. This insight can guide policymakers in maintaining or enhancing public trust and institutional integrity.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Show the ``distribution of the perceptions_of_corruption by all regions`` in a ``single plot``:**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code snippet ``creates a series of kernel density estimate (KDE) plots`` to visualize the ``distribution of perceptions of corruption`` across ``different regions``, using seaborn's displot function.**

# %%
# Creating the Displot with modified figure size
ax = sns.displot(data=df, 
                  x="perceptions_of_corruption", 
                  hue="regional_indicator", 
                  kind="kde", 
                  col="regional_indicator", 
                  col_wrap=2,
                  height=4,        # Height of each subplot
                  aspect=1.5,      # Aspect ratio of each subplot
                  legend=False)    # Disable the legend
# Adding a Title
ax.fig.suptitle("Perceptions of Corruption Distribution of all regions", fontsize=16, fontweight='bold', color="darkblue")

# Adjusting Layout
plt.tight_layout(pad=3)

# Displaying the Plots
plt.show()

# %% [markdown]
# The resulting visualizations shows the distribution of perceptions of corruption for each region, allowing for direct comparisons. Here’s how to interpret the results:
#
# - **``Regional Comparisons``**:
#   - Each subplot represents a different region, allowing for easy comparison of how perceptions of corruption vary across geographic areas.
# - **``Shape of Distributions``**:
#   - By examining the shape of each KDE plot, we can identify whether perceptions are generally low, high, or vary significantly within each region.
# - **``Identifying Patterns``**:
#   - Skewness or peaks in the distributions can indicate consensus on corruption perceptions within a region. For instance, a left-skewed distribution would suggest that most respondents perceive low corruption levels.
# - **``Outlier Regions``**:
#   - Regions with distinct distributions (e.g., more spread out or bimodal distributions) may point to varying perceptions or experiences of corruption within those areas, warranting further investigation.
# - **``Actionable Insights``**:
#   - This visualization can help policymakers and stakeholders understand regional differences in corruption perceptions, guiding targeted interventions or policy initiatives to address specific concerns.
#
# Overall, this approach effectively communicates complex information in a visually intuitive manner, facilitating discussions around governance and corruption across different regions.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Show the distribution of the ``'perceptions_of_corruption'`` by Asia:**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# The expression df.regional_indicator.value_counts().index retrieves the index of the Series returned by the value_counts() method applied to the regional_indicator column of the DataFrame df. Here’s a breakdown of what this does:

# %%
df.regional_indicator.value_counts().index
# Out:
# Index(['Sub-Saharan Africa', 'Western Europe', 'Latin America and Caribbean',
#        'Middle East and North Africa', 'Central and Eastern Europe',
#        'Commonwealth of Independent States', 'Southeast Asia', 'South Asia',
#        'East Asia', 'North America and ANZ'],
#       dtype='string')

# %% [markdown]
# - **``df.regional_indicator.value_counts()``** counts the occurrences of each unique value in the regional_indicator column, returning a Series where the index consists of the unique values and the values are the counts of their occurrences.
# - **``Accessing the Index:``**
#   - The **``.index``** attribute retrieves the index of the Series, which in this case contains the unique regional indicators.
# - **``Result:``**
#   - The output will be an Index object containing the names of the regions present in the regional_indicator column.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet creates a pandas Series from the index of the Series returned by value_counts() applied to the regional_indicator column of the DataFrame**

# %%
# Retrieve unique names of the regions present in the regional_indicator column
region_serie = pd.Series(df.regional_indicator.value_counts().index)

# Display the Result
region_serie
# Out:
# 0                    Sub-Saharan Africa
# 1                        Western Europe
# 2           Latin America and Caribbean
# 3          Middle East and North Africa
# 4            Central and Eastern Europe
# 5    Commonwealth of Independent States
# 6                        Southeast Asia
# 7                            South Asia
# 8                             East Asia
# 9                 North America and ANZ
# dtype: string

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``filters the region_serie`` to ``only include entries that contain the substring "Asia" at the end of the string```.**

# %%
# Filter the regions specifically related to "Asia",

region_serie[region_serie.astype("str").str.contains("Asia$")]
# Out:
# 6    Southeast Asia
# 7        South Asia
# 8         East Asia
# dtype: string

# %% [markdown]
# - **Converting to String**: **region_serie.astype("str")**
#   - This converts the values in region_serie to string type. This is necessary to use string methods like str.contains().
# - **Filtering with Regex**: ``.str.contains("Asia$")``
#   - This checks each string in the Series to see if it ends with "Asia". The $ character in the regex pattern signifies the end of the string.
# - **Applying the Filter**: ``region_serie[...]``
#   - This uses the boolean mask created by the contains method to filter region_serie, returning only those entries that match the condition.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``filters the region_serie`` to return ``only the entries that end with "Asia"`` and then retrieves the underlying NumPy array of those values.**

# %%
# Extract the regions that specifically relate to "Asia"

region_serie[region_serie.astype("str").str.contains("Asia$")].values

# Asia_serie[Asia_serie.astype("str").str.endswith("Asia")
# Out:
# <StringArray>
# ['Southeast Asia', 'South Asia', 'East Asia']
# Length: 3, dtype: string

# %% [markdown]
# This expression effectively filters and extracts the regions that specifically relate to "Asia", providing a clear and concise representation of these entries in a NumPy array format, which can be useful for further analysis or processing.
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet creates a ``new DataFrame`` df_Asia that contains ``only the rows`` from the original DataFrame df where the regional_indicator is either ``"Southeast Asia"``, ``"South Asia"``, or ``"East Asia"``.**

# %%
# Filtering the Original DataFrame and Creating a New DataFrame

df_Asia = df[(df.regional_indicator=="Southeast Asia") | 
             (df.regional_indicator=="South Asia") | 
             (df.regional_indicator=="East Asia")]
# df.loc[(df.regional_indicator=="Southeast Asia") | (df.regional_indicator=="South Asia") | (df.regional_indicator=="East Asia")]

# Display the New DataFrame
df_Asia
# Out:
#                            ladder_score regional_indicator  \
# Country name
# Taiwan Province of China           6.58          East Asia
# Singapore                          6.38     Southeast Asia
# Thailand                           5.99     Southeast Asia
# Japan                              5.94          East Asia
# Philippines                        5.88     Southeast Asia
# South Korea                        5.84          East Asia
# Mongolia                           5.68          East Asia
# Hong Kong S.A.R. of China          5.48          East Asia
# Vietnam                            5.41     Southeast Asia
# Malaysia                           5.38     Southeast Asia
# Indonesia                          5.34     Southeast Asia
# China                              5.34          East Asia
# Nepal                              5.27         South Asia
# Maldives                           5.20         South Asia
# Laos                               5.03     Southeast Asia
# ...

# %% [markdown]
# The resulting DataFrame df_Asia will include all columns from the original DataFrame but will only contain rows where the regional_indicator is "Southeast Asia," "South Asia," or "East Asia."
#
# - **Filtering the DataFrame**:
#   - df[(df.regional_indicator=="Southeast Asia") | (df.regional_indicator=="South Asia") | (df.regional_indicator=="East Asia")]
#     - This line uses boolean indexing to filter df. The condition checks if the regional_indicator column matches any of the specified regions.
#   - The **``|``** operator is used for logical OR, meaning that a row will be included in df_Asia if it meets any of the conditions.
# - **Creating the New DataFrame**:
#   - **``df_Asia = ...``**
#     - The result of the filtering operation is assigned to df_Asia, creating a new DataFrame that contains only the relevant rows.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using regular expressions (regex) to filter the DataFrame can indeed simplify our code when we want to match multiple patterns.**
# - The following code snippet filters the DataFrame to create a new DataFrame Asia_df that includes only the rows where the regional_indicator column contains "Asia" at the end of the string.

# %%
# OR we can shorten the code using regex.

# Filtering the Original DataFrame and Creating a New DataFrame
Asia_df = df[df['regional_indicator'].str.contains('Asia$')]

# Display the New DataFrame
Asia_df
# Out:
#                            ladder_score regional_indicator  \
# Country name
# Taiwan Province of China           6.58          East Asia
# Singapore                          6.38     Southeast Asia
# Thailand                           5.99     Southeast Asia
# Japan                              5.94          East Asia
# Philippines                        5.88     Southeast Asia
# South Korea                        5.84          East Asia
# Mongolia                           5.68          East Asia
# Hong Kong S.A.R. of China          5.48          East Asia
# Vietnam                            5.41     Southeast Asia
# Malaysia                           5.38     Southeast Asia
# Indonesia                          5.34     Southeast Asia
# China                              5.34          East Asia
# Nepal                              5.27         South Asia
# Maldives                           5.20         South Asia
# Laos                               5.03     Southeast Asia
# ...

# %% [markdown]
# Using **``regex with str.contains()``** offers a more concise way to filter the DataFrame when dealing with multiple patterns. This approach is particularly useful when the patterns share a common substring or when we want to match a variety of similar terms efficiently.
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``creates a series of kernel density estimate (KDE)`` plots to visualize the ``distribution of perceptions of corruption`` specifically for ``Asian regions`` using the Asia_df DataFrame.**

# %%
# Creating the KDE with modified figure size
ax = sns.displot(data=Asia_df, 
                 x="perceptions_of_corruption", 
                 hue="regional_indicator", 
                 kind="kde", 
                 col="regional_indicator", 
#                  col_wrap=2,
                 height=8,        # Height of each subplot
                 aspect=0.9,      # Aspect ratio of each subplot
                 legend=False)    # Disable the legend

# Adding a Title
ax.fig.suptitle("Distribution of Perceptions of Corruption in Asia", fontsize=28, color="darkblue")

# Adjusting Layout
plt.tight_layout(pad=3)

# Displaying the Plots
plt.show()

# %% [markdown]
# The resulting visualizations will show the distribution of perceptions of corruption for each Asian region represented in Asia_df. Here’s how to interpret the results:
#
# - **``Regional Comparisons``**:
#   - Each subplot displays the KDE for a different region, allowing for direct comparisons of how perceptions of corruption vary among Southeast Asia, South Asia, and East Asia.
# - **``Shape of Distributions``**:
#   - The shape of each KDE plot provides insights into the perceptions of corruption within each region. **``Peaks indicate where perceptions are concentrated``**, while the **``width of the distribution indicates variability``**.
# - **``Identifying Trends``**:
#   - We can identify whether perceptions are generally low or high in specific regions. For example, a left-skewed distribution may indicate that most respondents perceive low levels of corruption.
# - **``Outliers and Variability``**:
#   - Analyzing the tails of the distributions can help identify areas with extreme perceptions, which may require further investigation.
# - **``Summary``**:
#   - This approach effectively visualizes and compares perceptions of corruption across different Asian regions, facilitating discussions about governance, transparency, and public trust in these areas.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **To provide management with more concrete information, convert the ``'perceptions_of_corruption'`` scores to ``'investment_risk_factor'``, and create a new feature/column from these scores. (This factor will indicate that a lower score demonstrates a higher risk for the investment.)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following line of code calculates a ``new column`` called ``investment_risk_factor`` in the DataFrame.**
# - This new column is derived from the existing perceptions_of_corruption column.

# %%
# Creating the 'investment_risk_factor' column
df['investment_risk_factor'] = 100 - df['perceptions_of_corruption']

# Displaying the Updated DataFrame
df
# Out:
#               ladder_score  regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84      Western Europe                  10.78
# Denmark               7.62      Western Europe                  10.93
# Switzerland           7.57      Western Europe                  11.12
# Iceland               7.55      Western Europe                  10.88
# Netherlands           7.46      Western Europe                  10.93
# ...                    ...                 ...                    ...
# Lesotho               3.51  Sub-Saharan Africa                   7.93
# Botswana              3.47  Sub-Saharan Africa                   9.78
# Rwanda                3.42  Sub-Saharan Africa                   7.68
# Zimbabwe              3.15  Sub-Saharan Africa                   7.94
# Afghanistan           2.52          South Asia                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# The line **``df['investment_risk_factor'] = 100 - df['perceptions_of_corruption']``** computes the investment risk factor by subtracting each value in the perceptions_of_corruption column from 100.
# - This means that a **``higher score in perceptions_of_corruption``** (indicating lower corruption) results in a **``lower investment_risk_factor``**, while a **``lower score``** (indicating higher corruption) results in a **``higher risk factor``**.
#
# <hr>
#
# - **``Understanding Investment Risk``**:
#   - The logic behind this calculation is that a **``higher perception of corruption``** corresponds to a **``higher investment risk``**. By subtracting the perception score from 100, we invert the perception score:
#     - lower corruption perceptions (higher scores) result in lower investment risk factors, and vice versa.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Compare Investment Risk Factor by region:**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code snippet ``calculates the average investment risk factor`` by ``region`` and creates a ``bar plot`` to visualize this information.**

# %%
# Calculating the Average Investment Risk Factor by Region:
region_irf = df.groupby('regional_indicator')['investment_risk_factor'].mean()

# Creating a figure with a specified size
plt.figure(figsize=(10,4))

# Creating the BAR Plot with modified figure size
ax=sns.barplot(x=region_irf.index, y=region_irf.values)

# Adding a Title
plt.title('Investment Risk Factor Score by Regions', fontsize=14, color ="darkblue")

# Adding Titles and Labels
plt.xlabel('Regions', fontsize=12)
plt.ylabel('Investment Risk Factor', fontsize=12)

# Modifying the Ticks Labels
plt.xticks(fontsize=10, rotation=80)

# Annotating Bar Labels
ax.bar_label(ax.containers[0], size=8, c="darkred");

# Displaying the Plots
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression retrieves the ``minimum`` and ``maximum`` values from the ``investment_risk_factor`` column in the DataFrame.**

# %%
# Finding the Minimum and Maximum Values

df.investment_risk_factor.min(), df.investment_risk_factor.max()
# Out:
# (99.061, 99.918)

# %% [markdown]
# This operation provides quick insights into the **``range of investment risk factors``** within our dataset, which can help in understanding the variability of perceived investment risks among different regions or cases.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;">🤔💭 Barplots do ``NOT provide insight well`` because ``investment_risk_factor values`` are ``very close to each other`` and tightly packed (between 99.061 and 99.918). Let's look at the barplots by normalizing these values with the min-max scaler.</p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **To normalize the investment_risk_factor values using min-max scaling, we can define a function that applies the normalization to our data.**
# - This will help visualize the differences between regions more effectively, especially when the values are tightly packed.

# %%
# Normalization using min-max scaling

# Define the Min-Max Normalization Function:
def min_max_normalize(data):
    min_val = data.min()
    max_val = data.max()
    return (data - min_val) / (max_val - min_val)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``applies the min_max_normalize function`` to the ``investment_risk_factor column`` of the DataFrame.**

# %%
# Apply the Normalization to the Investment Risk Factor

min_max_normalize(df['investment_risk_factor'])

# investment_risk_factor values normalized by min_max_normalize() DEF
# Out:
# Country name
# Finland       0.88
# Denmark       0.89
# Switzerland   0.75
# Iceland       0.31
# Netherlands   0.70
#               ...
# Lesotho       0.03
# Botswana      0.16
# Rwanda        0.90
# Zimbabwe      0.14
# Afghanistan   0.02
# Name: investment_risk_factor, Length: 149, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Alternative Way of normalizing:</strong></p>
#
#
# **While normalizing, we can also use the ``MinMaxScaler()`` function of the ``scikit-learn library``:**
#
# - **Using the MinMaxScaler from the sklearn.preprocessing module is an excellent alternative for normalizing our data. Here’s a breakdown of how this method works and how to implement it:**

# %%
# Import the MinMaxScaler
from sklearn.preprocessing import MinMaxScaler

# Initialize the Scaler
scaler = MinMaxScaler()

# Fit and Transform the Data
df['risk_factor_normalized'] = scaler.fit_transform(df[['investment_risk_factor']])

# Display the Transformed Data
df['risk_factor_normalized']
# Out:
# Country name
# Finland       0.88
# Denmark       0.89
# Switzerland   0.75
# Iceland       0.31
# Netherlands   0.70
#               ...
# Lesotho       0.03
# Botswana      0.16
# Rwanda        0.90
# Zimbabwe      0.14
# Afghanistan   0.02
# Name: risk_factor_normalized, Length: 149, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``calculates the average normalized investment risk factor`` for ``each region`` in our DataFrame.**

# %%
# Grouping the Data and Calculating the Mean
region_irf = df.groupby('regional_indicator')['risk_factor_normalized'].mean()

# Displaying the Variable
region_irf
# Out:
# regional_indicator
# Central and Eastern Europe           0.10
# Commonwealth of Independent States   0.25
# East Asia                            0.30
# Latin America and Caribbean          0.17
# Middle East and North Africa         0.21
# North America and ANZ                0.57
# South Asia                           0.17
# Southeast Asia                       0.27
# Sub-Saharan Africa                   0.20
# Western Europe                       0.49
# Name: risk_factor_normalized, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``creates a bar plot`` to visualize the ``average normalized investment risk factor by region``.**

# %%
# Creating a figure with a specified size
plt.figure(figsize=(10, 4))

# Creating the BAR Plot with modified figure size
ax=sns.barplot(x=region_irf.index, y=region_irf.values, order=region_irf.sort_values(ascending=False).index )

# Adding a Title
plt.title('Investment Risk Factor by Regions-(Lower score indicates higher risk))', fontsize=12, color ="darkblue")

# Adding Titles and Labels
plt.xlabel('Regions', fontsize=12)
plt.ylabel('Investment Risk Factor', fontsize=12)

# Modifying the Ticks Labels
plt.xticks(fontsize=10, rotation=80)

# Annotating Bar Labels
ax.bar_label(ax.containers[0], size=8, c="darkred");

# Displaying the Plots
plt.show()

# %% [markdown]
# The resulting bar plot will visually represent the average normalized investment risk factors for each region, helping to identify which regions have higher or lower perceived risks. The title clarifies that a lower score indicates a higher risk, guiding the interpretation of the plot.
# - This visualization effectively communicates regional differences in investment risk factors based on normalized values, allowing management to make informed decisions regarding investment opportunities in various regions. The inclusion of bar labels enhances clarity, enabling quick insights into the specific values associated with each region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following line of code ``creates a new column`` called ``investment_risk_factor`` in the DataFrame.**
# - This column is derived from the existing perceptions_of_corruption column.

# %%
# Creating a New Column
df['investment_risk_factor'] = 1 - df['perceptions_of_corruption']

# Display the Updated DataFrame
df
# Out:
#               ladder_score  regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84      Western Europe                  10.78
# Denmark               7.62      Western Europe                  10.93
# Switzerland           7.57      Western Europe                  11.12
# Iceland               7.55      Western Europe                  10.88
# Netherlands           7.46      Western Europe                  10.93
# ...                    ...                 ...                    ...
# Lesotho               3.51  Sub-Saharan Africa                   7.93
# Botswana              3.47  Sub-Saharan Africa                   9.78
# Rwanda                3.42  Sub-Saharan Africa                   7.68
# Zimbabwe              3.15  Sub-Saharan Africa                   7.94
# Afghanistan           2.52          South Asia                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# - The operation essentially reverses the scale of the perceptions_of_corruption. If the perceptions_of_corruption score ranges from 0 to 1 (with **``0``** indicating **``very high corruption``** and **``1``** indicating **``NO corruption``**), then:
#   - A **``high corruption perception (low score)``** will result in a **``high investment risk factor (high score)``**.
#   - Conversely, a **``low corruption perception (high score)``** will yield a **``low investment risk factor (low score)``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the average investment risk factor`` by ``region`` and visualizes it using a bar plot.**

# %%
# Calculating the Average Investment Risk Factor by Region:
region_irf = df.groupby('regional_indicator')['investment_risk_factor'].mean()

# Creating a figure with a specified size
plt.figure(figsize=(10, 4))

# Creating the BAR Plot with modified figure size
ax=sns.barplot(x=region_irf.index, y=region_irf.values, order=region_irf.sort_values(ascending=False).index)

# Adding a Title
plt.title('Investment Risk Factors by Regions)', fontsize=12, color ="darkblue")

# Adding Titles and Labels
plt.xlabel('Regions', fontsize=12)
plt.ylabel('Investment Risk Factor', fontsize=12)

# Modifying the Ticks Labels
plt.xticks(fontsize=10, rotation=80)

# Annotating Bar Labels
ax.bar_label(ax.containers[0], size=8, c="darkred");

# Displaying the Plots
plt.show()

# %% [markdown]
# The bar plot will effectively show the average investment risk factors for each region, sorted in descending order. This visualization helps to quickly identify which regions have higher investment risks based on their perceptions of corruption.
# - This code provides a clear and informative visualization of the investment risk factors across different regions. The use of bar labels enhances the plot's clarity, allowing viewers to easily understand the specific values associated with each region, which can be crucial for making informed investment decisions.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ## <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:115%; text-align:left;"><strong>👉 Let's examine the logged_gdp_per_capita feature/column for potential outliers:</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Using ``df.head()`` in pandas will display the ``first five rows`` of your DataFrame. This function is useful for quickly ``inspecting the data and understanding its structure and contents``:**

# %%
# Display the first five rows of the DataFrame

df.head()
# Out:
#               ladder_score regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84     Western Europe                  10.78
# Denmark               7.62     Western Europe                  10.93
# Switzerland           7.57     Western Europe                  11.12
# Iceland               7.55     Western Europe                  10.88
# Netherlands           7.46     Western Europe                  10.93
#
#               social_support  healthy_life_expectancy  \
# Country name
# Finland                 0.95                    72.00
# Denmark                 0.95                    72.70
# Switzerland             0.94                    74.40
# Iceland                 0.98                    73.00
# Netherlands             0.94                    72.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Finland                               0.95       -0.10
# Denmark                               0.95        0.03
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code provides a statistical summary of the logged_gdp_per_capita column in our DataFrame.**
# - This summary includes key descriptive statistics that help us understand the distribution and range of the data.

# %%
# Descriptive Statistics of "logged_gdp_per_capita" column

df["logged_gdp_per_capita"].describe()
# Out:
# count   149.00
# mean      9.43
# std       1.16
# min       6.63
# 25%       8.54
# 50%       9.57
# 75%      10.42
# max      11.65
# Name: logged_gdp_per_capita, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# ### First, let's visually check potential outliers:
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet creates a ``box plot`` to visually ``assess potential outliers`` in the logged_gdp_per_capita feature.**

# %%
# Creating a figure with a specified size
plt.figure(figsize=(8, 4))

# Creating the HORIZONTAL BOX Plot
sns.boxplot(df["logged_gdp_per_capita"], orient="h", whis=1);  # No outlier appears at 1.5 IQR threshold.

# %% [markdown]
# - **Box Plot Creation:**
#   - **``sns.boxplot()``**: This function from the Seaborn library creates a box plot, which is useful for visualizing the distribution of data and identifying outliers.
# - **Data Input:**
#   - **``df["logged_gdp_per_capita"]``**: This specifies that the box plot should be created using the logged_gdp_per_capita column from the DataFrame.
# - **Orientation:**
#   - **``orient="h"``**: This parameter sets the orientation of the box plot to horizontal. This can make it easier to read, especially if the labels are long.
# - **Whisker Length:**
#   - **``whis=1``**: This parameter specifies the length of the whiskers in terms of the interquartile range (IQR). Setting whis=1 means that the whiskers will extend to the first quartile minus 1 times the IQR and the third quartile plus 1 times the IQR. If we want to use the standard threshold for outliers (1.5 times the IQR), we would typically omit this parameter or set it to 1.5.
#
# **Interpreting the Box Plot:**
# - **``Box``**: Represents the interquartile range (IQR), which contains the middle 50% of the data (from Q1 to Q3).
# - **``Line inside the Box``**: Indicates the median (Q2) of the data.
# - **``Whiskers``**: Extend from the box to the highest and lowest values within the whisker range (1.0 IQR in your case). Points outside this range are considered potential outliers.
# - **``Outliers``**: If any points are plotted as individual dots outside the whiskers, these are considered outliers.
#
# **Conclusion:**
# - By executing this code, we will generate a box plot that visually represents the distribution of logged_gdp_per_capita. If NO outliers appear beyond the whiskers, it suggests that there are NO extreme values according to the 1.0 IQR threshold. However, if we want to adhere to the more standard 1.5 IQR threshold for outlier detection, we may want to adjust the whis parameter accordingly or leave it out to use the default setting.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet creates a ``histogram`` to visualize the ``distribution of the logged_gdp_per_capita`` feature in our DataFrame**

# %%
# Creating a figure with a specified size
plt.figure(figsize=(10, 4))

# Creating the HSITOGRAM
sns.histplot(df["logged_gdp_per_capita"], bins=20);

# %% [markdown]
# - **``sns.histplot()``**: This function from the Seaborn library generates a histogram, which is useful for visualizing the frequency distribution of a dataset.
# - **``df["logged_gdp_per_capita"]``**: Specifies that the histogram should be plotted using the logged_gdp_per_capita column from the DataFrame.
# - **``bins=20``**: This parameter sets the number of bins (or intervals) to 20. Bins represent ranges of values, and the height of each bin indicates the frequency of data points within that range.
#
# **Distribution Shape**: The shape of the histogram gives insights into the distribution of the data:
# - **``Normal Distribution``**: If the histogram is bell-shaped, the data may be normally distributed.
# - **``Skewed Distribution``**: If the histogram has a long tail on one side, the data may be skewed (right or left).
# - **``Bimodal or Multimodal``**: If there are multiple peaks, the data may have multiple modes or clusters.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### Let's manually calculate Q1, Q3, IQR, Lower Limit, Upper Limit for detecting potential outliers:
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the 25th percentile`` (also known as the ``first quartile, Q1``) of the logged_gdp_per_capita column in our DataFrame.**

# %%
np.percentile(df["logged_gdp_per_capita"], [25])
# Out:
# array([8.541])

# %% [markdown]
# - **``np.percentile(..., [25])``**: This function computes the value below which 25% of the data fall. The result is a single value representing the first quartile. In this case, 8.541 would be the 25th percentile of the logged_gdp_per_capita values, meaning that 25% of the observations are less than or equal to 8.541.
#
# **Interpretation:**
# - **``25th Percentile (Q1)``**: The 25th percentile indicates the lower quartile of the data. It helps in understanding the distribution and spread of the data. Knowing Q1 allows us to see where the lower quarter of your values lies and can be useful for identifying outliers when combined with the 75th percentile (Q3) and the interquartile range (IQR).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the 75th percentile`` (also known as the ``third quartile, Q1``) of the logged_gdp_per_capita column in our DataFrame.**

# %%
np.percentile(df["logged_gdp_per_capita"], [75])
# Out:
# array([10.421])

# %% [markdown]
# - **``np.percentile(..., [75])``**: This function computes the value below which 75% of the data fall. The result is a single value representing the third quartile. In this example, 10.421 would be the 75th percentile of the logged_gdp_per_capita values, meaning that 75% of the observations are less than or equal to 10.421.
#
# **Interpretation:**
# - **``75th Percentile (Q3)``**: The 75th percentile indicates the upper quartile of the data. It helps in understanding the distribution and spread, particularly in identifying the upper range of values. Knowing Q3, along with the 25th percentile (Q1), allows us to calculate the interquartile range (IQR), which is essential for outlier detection.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the first quartile (Q1)`` and ``the third quartile (Q3)`` of the logged_gdp_per_capita column in our DataFrame**

# %%
# Calculating Quartiles
Q1, Q3 = np.percentile(df["logged_gdp_per_capita"], [25, 75])

# Display Q1 and Q3
Q1, Q3
# Out:
# (8.541, 10.421)

# %% [markdown]
# - **``Q1 (25th Percentile)``**: This value indicates that 25% of the logged_gdp_per_capita observations are less than or equal to this value. It provides insight into the lower range of the data.
# - **``Q3 (75th Percentile)``**: This value indicates that 75% of the observations are less than or equal to this value. It represents the upper range of the data.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the Interquartile Range (IQR)`` using the previously computed values of Q1 and Q3.**

# %%
# Calculating Inter Quartile Range (IQR)
IQR = Q3-Q1

# Display IQR
IQR
# Out:
# 1.879999999999999

# %% [markdown]
# - **``IQR (Interquartile Range)``**: This statistic measures the spread of the middle 50% of your data. It is calculated by subtracting the first quartile (Q1) from the third quartile (Q3):
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following command ``calculates the Interquartile Range (IQR)`` of the logged_gdp_per_capita column in our DataFrame using the ``iqr()`` function from the scipy.stats module.**

# %%
# Calculating Inter Quartile Range (IQR) Using "scipy.stats module"

stats.iqr(df["logged_gdp_per_capita"])
# Out:
# 1.879999999999999

# %% [markdown]
# The IQR indicates the range within which the central 50% of our data lies. A **``higher IQR``** suggests **``greater variability in the middle 50%``** of the dataset.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following command ``calculates the lower limit`` for detecting outliers using the Interquartile Range (IQR) and the first quartile (Q1).**

# %%
# Calculating the Lower limit
lower_lim = Q1-1.5*IQR

# Displaying the Lower limit
lower_lim
# Out:
# 5.721000000000002

# %% [markdown]
# - **``Q1``**: The first quartile (25th percentile) of our data, which represents the value below which 25% of the data falls.
# - **``IQR``**: The interquartile range, calculated as Q3−Q1.
# - **``Lower Limit Calculation``**: The formula Q1−1.5×IQR establishes a threshold below which values are considered potential outliers.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following command ``calculates the upper limit`` for detecting outliers using the Interquartile Range (IQR) and the third quartile (Q1).**

# %%
# Calculating the Upper limit
upper_lim = Q3+1.5*IQR

# Displaying the Upper limit
upper_lim
# Out:
# 13.240999999999998

# %% [markdown]
# - **``Q1``**: The first quartile (25th percentile) of our data, which represents the value below which 25% of the data falls.
# - **``IQR``**: The interquartile range, calculated as Q3−Q1.
# - **``Upper Limit Calculation``**: The formula Q1+1.5×IQR establishes a threshold below which values are considered potential outliers.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``identifies potential outliers`` in the logged_gdp_per_capita column based on the calculated lower and upper limits.**

# %%
# Calculating Potential Outliers
potential_outliers = df[(df["logged_gdp_per_capita"] < lower_lim) | (df["logged_gdp_per_capita"] > upper_lim)]

# Displaying Potential Outliers
potential_outliers
# Out:
# Empty DataFrame
# Columns: [ladder_score, regional_indicator, logged_gdp_per_capita, social_support, healthy_life_expectancy, freedom_to_make_life_choices, generosity, perceptions_of_corruption, investment_risk_factor, risk_factor_normalized]
# Index: []

# %% [markdown]
# - **``Potential Outliers``**: The rows in potential_outliers may be considered outliers based on the IQR method. Any value below the lower_lim or above the upper_lim indicates that these values are significantly different from the rest of the data.
# - **``Further Investigation``**: It’s important to further investigate these potential outliers to understand their context. Outliers may represent valid extreme values or could be errors in the data.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;">👉 Depending on the needs in our analysis, the threshold value normally used as 1.5 IQR as default can also be used as 1 IQR. In this case, more outliers could potentially be identified.</p>
#
#
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **In the following modified approach, we're recalculating the lower and upper limits for detecting outliers using a ``multiplier of 1`` instead of the standard 1.5 for the Interquartile Range (IQR). This will result in a ``narrower range for identifying potential outliers``.**

# %%
# Recalculating Lower and Upper Limits
lower_lim = Q1-1*IQR
upper_lim = Q3+1*IQR

# Recalculating Potential Outliers
potential_outliers = df[(df["logged_gdp_per_capita"]<lower_lim) | (df["logged_gdp_per_capita"] > upper_lim)]

# Displaying Potential Outliers
potential_outliers
# Out:
#               ladder_score  regional_indicator  logged_gdp_per_capita  \
# Country name
# Burundi               3.77  Sub-Saharan Africa                   6.63
#
#               social_support  healthy_life_expectancy  \
# Country name
# Burundi                 0.49                    53.40
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Burundi                               0.63       -0.02
#
#               perceptions_of_corruption  investment_risk_factor  \
# Country name
# Burundi                            0.61                    0.39
#
#               risk_factor_normalized
# Country name
# Burundi                         0.39

# %% [markdown]
# - **``Narrower Range for Outliers``**: By using a **``multiplier of 1``** instead of 1.5, we are likely to identify **``more values as outliers``**, as the range is now tighter. This can lead to a **``higher number of identified potential outliers``** compared to the standard method.
# - **``Potential Impact``**: This change may be useful if we suspect that even slightly extreme values should be flagged for further investigation, but it may also lead to labeling some valid data points as outliers.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# ### BONUS User Defined Functions (DEFs) for detecting potential outliers:
#
# - #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 How to detect outliers applying Tukey's Fence Rule❓</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following User Defined Function ``find_outliers`` is a useful utility for detecting outliers in a specified column of a DataFrame based on the ``Interquartile Range (IQR)``.**

# %%
def find_outliers(dataframe, column_name, threshold=1):
    """
    Identify outliers in a specified column of a DataFrame using the Interquartile Range (IQR) method.

    Parameters:
    ----------
    dataframe : pandas.DataFrame
        The DataFrame containing the data.
    column_name : str
        The name of the column in which to identify outliers.
    threshold : float, optional
        The multiplier for the IQR to define outliers. 
        Default is 1, which is a less common threshold. 
        A typical threshold is 1.5 for standard outlier detection.

    Returns:
    -------
    tuple : (pandas.DataFrame, pandas.DataFrame)
        - A DataFrame with an additional column "Outlier_Column" marking 
          each entry as "Not Outlier" or the name of the column if it is an outlier.
        - A DataFrame containing only the rows identified as outliers.
    """
    
    # Create a copy of the dataframe
    dataframe_copy = dataframe.copy()
    
    # Get the values of the specified column
    column = dataframe_copy[column_name]
    
    # Calculate Quartile 1 (Q1) and Quartile 3 (Q3) values
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    
    # Calculate the Interquartile Range (IQR) value
    iqr = q3 - q1
    
    # Calculate the lower and upper thresholds to identify outliers
    lower_threshold = q1 - threshold * iqr
    upper_threshold = q3 + threshold * iqr
    
    # Create a mask to identify outliers
    outlier_mask = (column < lower_threshold) | (column > upper_threshold)
    
    # Select the rows with outliers
    outliers = dataframe_copy[outlier_mask]
    
    # Mark the outliers in a new column named "Outlier_Column"
    dataframe_copy.loc[outlier_mask, "Outlier_Column"] = column_name
    
    # Define the NaN values in "Outlier_Column" as "Not Outlier"
    dataframe_copy["Outlier_Column"].fillna("Not Outlier", inplace=True)
    
    return dataframe_copy, outliers

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code uses the ``find_outliers`` function to identify and display outliers in the logged_gdp_per_capita column of our DataFrame.**

# %%
# Find outliers
modified_df, outliers = find_outliers(df, 'logged_gdp_per_capita', threshold=1)

# Print the results
print("Modified DataFrame:")
display(modified_df)
print("\nOutliers:")
outliers
# Out:
# Modified DataFrame:
#               ladder_score  regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84      Western Europe                  10.78
# Denmark               7.62      Western Europe                  10.93
# Switzerland           7.57      Western Europe                  11.12
# Iceland               7.55      Western Europe                  10.88
# Netherlands           7.46      Western Europe                  10.93
# ...                    ...                 ...                    ...
# Lesotho               3.51  Sub-Saharan Africa                   7.93
# Botswana              3.47  Sub-Saharan Africa                   9.78
# Rwanda                3.42  Sub-Saharan Africa                   7.68
# Zimbabwe              3.15  Sub-Saharan Africa                   7.94
# Afghanistan           2.52          South Asia                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``retrieves the row corresponding to "Burundi"`` from the modified_df DataFrame.**

# %%
modified_df.loc["Burundi"]
# Out:
# ladder_score                                     3.77
# regional_indicator                 Sub-Saharan Africa
# logged_gdp_per_capita                            6.63
# social_support                                   0.49
# healthy_life_expectancy                         53.40
# freedom_to_make_life_choices                     0.63
# generosity                                      -0.02
# perceptions_of_corruption                        0.61
# investment_risk_factor                           0.39
# risk_factor_normalized                           0.39
# Outlier_Column                  logged_gdp_per_capita
# Name: Burundi, dtype: object

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 How to detect outliers applying standart deviation (sd)❓</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following User Defined Function ``find_outliers`` ``identifies outliers`` based on the ``mean`` and ``standard deviation`` of a specified column in a DataFrame.**

# %%
def find_outliers(dataframe, column_name, threshold=1):
    """
    Identify outliers in a specified column of a DataFrame using the mean and standard deviation method.

    Parameters:
    ----------
    dataframe : pandas.DataFrame
        The DataFrame containing the data.
    column_name : str
        The name of the column in which to identify outliers.
    threshold : float, optional
        The number of standard deviations from the mean to determine outliers. 
        Default is 1. A typical threshold for outlier detection is often set to 2 or 3.

    Returns:
    -------
    tuple : (pandas.DataFrame, pandas.DataFrame)
        - A DataFrame with an additional column "Outlier_Column" marking 
          each entry as "Not Outlier" or the name of the column if it is an outlier.
        - A DataFrame containing only the rows identified as outliers.
    """
    
    # Create a copy of the DataFrame
    dataframe_copy = dataframe.copy()
    
    # Get the values of the specified column
    column = dataframe_copy[column_name]
    
    # Calculate the mean and standard deviation of the column
    mean = column.mean()
    std = column.std()
    
    # Calculate the lower and upper thresholds to determine outliers
    lower_threshold = mean - threshold * std
    upper_threshold = mean + threshold * std
    
    # Create a mask to identify outliers
    outlier_mask = (column < lower_threshold) | (column > upper_threshold)
    
    # Select the rows with outliers
    outliers = dataframe_copy[outlier_mask]
    
    # Mark the outliers in a new column named "Outlier_Column"
    dataframe_copy.loc[outlier_mask, "Outlier_Column"] = column_name
    
    # Define the NaN values in "Outlier_Column" as "Not Outlier"
    dataframe_copy["Outlier_Column"].fillna("Not Outlier", inplace=True)
    
    return dataframe_copy, outliers

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code finds outliers in the logged_gdp_per_capita column of the DataFrame.**

# %%
# Find outliers
modified_df, outliers = find_outliers(df, 'logged_gdp_per_capita', threshold=2)

# Print the results
print("Modified DataFrame:")
display(modified_df)
print("\nOutliers:")
outliers
# Out:
# Modified DataFrame:
#               ladder_score  regional_indicator  logged_gdp_per_capita  \
# Country name
# Finland               7.84      Western Europe                  10.78
# Denmark               7.62      Western Europe                  10.93
# Switzerland           7.57      Western Europe                  11.12
# Iceland               7.55      Western Europe                  10.88
# Netherlands           7.46      Western Europe                  10.93
# ...                    ...                 ...                    ...
# Lesotho               3.51  Sub-Saharan Africa                   7.93
# Botswana              3.47  Sub-Saharan Africa                   9.78
# Rwanda                3.42  Sub-Saharan Africa                   7.68
# Zimbabwe              3.15  Sub-Saharan Africa                   7.94
# Afghanistan           2.52          South Asia                   7.70
#
#               social_support  healthy_life_expectancy  \
# Country name
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
modified_df.loc[["Niger", "Burundi", "Malawi"]]
# Out:
#               ladder_score  regional_indicator  logged_gdp_per_capita  \
# Country name
# Niger                 5.07  Sub-Saharan Africa                   7.10
# Burundi               3.77  Sub-Saharan Africa                   6.63
# Malawi                3.60  Sub-Saharan Africa                   6.96
#
#               social_support  healthy_life_expectancy  \
# Country name
# Niger                   0.64                    53.78
# Burundi                 0.49                    53.40
# Malawi                  0.54                    57.95
#
#               freedom_to_make_life_choices  generosity  \
# Country name
# Niger                                 0.81        0.02
# Burundi                               0.63       -0.02
# Malawi                                0.78        0.04
#
#               perceptions_of_corruption  investment_risk_factor  \
# Country name
# Niger                              0.69                    0.31
# ...

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:125%; text-align:left;"><strong>🤔💭 Why do they give different results❓</strong></p>
#
# The **``threshold=2 in Tukey's Fence Rule``** and the **``threshold=2 when using standard deviation``** do **``NOT have the same meaning``**. They use different approaches and can produce different results.
#
# - 👉 When using a **``standard deviation-based approach``**, the **``threshold=2``** indicates that we consider a value as an outlier if it is **``more than 2 standard deviations``** away from the mean. This approach is based on the distribution of the data and defines outliers using the standard deviation.
#
# - 👉 On the other hand, **``Tukey's Fence Rule``** is based on the quartiles of the data. The **``threshold=2``** determines the **``lower``** and **``upper``** threshold values by **``multiplying the IQR (Interquartile Range) value``**. If a value is smaller than Q1 - 2 * IQR or larger than Q3 + 2 * IQR, it is considered as an outlier. This method relies on the central tendency and distribution of the data.
#
# Therefore, while the **``threshold=2``** has a **``different meaning``** in a standard deviation-based approach, it has a different meaning in Tukey's Fence Rule. Both methods are different approaches to identifying outliers based on different statistical and distributional characteristics.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ## <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:115%; text-align:left;"><strong>👉 How to detect Skewness & Kurtosis?</strong></p>

# %% [markdown]
# **Skewness and Kurtosis:**
#
# [Skewness](https://www.investopedia.com/terms/k/kurtosis.asp) and [Kurtosis](https://www.investopedia.com/terms/s/skewness.asp) are two important statistical terms used in analyzing the distribution of data. They help us understand how the data is spread around the mean and how much it deviates from a normal distribution.
#
# - **Skewness:**
#
#   - Skewness measures the symmetry of the data distribution.
#   - In a normal distribution, the skewness value is 0.
#   - If the skewness value is positive, the distribution is right-skewed (with more data points above the mean).
#   - If the skewness value is negative, the distribution is left-skewed (with more data points below the mean).
#
# - **Kurtosis:**
#
#   - Kurtosis measures the peakedness or flatness of the data distribution.
#   - In a normal distribution, the kurtosis value is 3, which is Mesokurtic distribution used to describe the outlier characteristic of a probability distribution that is close to zero..
#   - If the kurtosis value is greater than 3, the distribution is called "leptokurtic" and has heavier tails. This means there are more data points near the mean and more extreme data points.
#   - If the kurtosis value is less than 3, the distribution is called "platykurtic" and is flatter than a normal distribution. This means there are fewer data points near the mean and fewer extreme data points.
#
# **[Skewness and Kurtosis: Quick Guide](https://www.analyticsvidhya.com/blog/2021/05/shape-of-data-skewness-and-kurtosis/)**<br>
# **[Understanding Skewness in Data and Its Impact on Data Analysis](https://www.analyticsvidhya.com/blog/2020/07/what-is-skewness-statistics/)**<br>
# **[What Is Kurtosis In Statistics?](https://www.simplypsychology.org/kurtosis.html)**<br>
# **[The Complete Guide to Skewness and Kurtosis](https://www.simplilearn.com/tutorials/statistics-tutorial/skewness-and-kurtosis)**<br>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# **Skewnes value for each feature in the DataFrame can be calculated one by one:**
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the skewness`` of the logged_gdp_per_capita column in our DataFrame, using ``skew()`` function from the scipy.stats module.**

# %%
# Calculate skewness

stats.skew(df["logged_gdp_per_capita"])
# Out:
# -0.3484712781192719

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### BONUS User Defined Functions (DEFs) for calculating Skewness values:
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following User Defined Function ``get_skewness`` is a useful utility for calculating the skewness of all numerical columns in a given DataFrame.**

# %%
import numpy as np

def get_skewness(dataframe):
    """
    Calculate the skewness of numerical columns in a DataFrame.

    Parameters:
    ----------
    dataframe : pandas.DataFrame
        The DataFrame containing the data.

    Returns:
    -------
    pandas.Series
        A Series containing the skewness values for each numerical column.
    """
    numerical_columns = dataframe.select_dtypes(include=[np.number])  # Select numerical features/columns
    skewness_values = numerical_columns.skew()  # Calculate skewness values
    return skewness_values

# %%
# Calculate skewness for the DataFrame

get_skewness(df)
# Out:
# ladder_score                   -0.10
# logged_gdp_per_capita          -0.35
# social_support                 -0.94
# healthy_life_expectancy        -0.52
# freedom_to_make_life_choices   -0.75
# generosity                      1.01
# perceptions_of_corruption      -1.58
# investment_risk_factor          1.58
# risk_factor_normalized          1.58
# dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code ``calculates the kurtosis`` of the logged_gdp_per_capita column in our DataFrame, using the ``kurtosis()`` function from the scipy.stats module.**

# %%
# Calculate kurtosis

stats.kurtosis(df["logged_gdp_per_capita"])
# Out:
# -0.8283005045350476

# %% [markdown]
# The function returns a Series containing the skewness values for each numerical column.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### Now, let's create a User Defined Function (DEF) for calculating Kurtosis values:
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following User Defined Function ``get_kurtosis`` function is an effective way to calculate the kurtosis for all numerical columns in a given DataFrame.**

# %%
import numpy as np

def get_kurtosis(dataframe):
    """
    Calculate the kurtosis of numerical columns in a DataFrame.

    Parameters:
    ----------
    dataframe : pandas.DataFrame
        The DataFrame containing the data.

    Returns:
    -------
    pandas.Series
        A Series containing the kurtosis values for each numerical column.
    """
    numerical_columns = dataframe.select_dtypes(include=[np.number])  # Select numerical features/columns
    kurtosis_values = numerical_columns.kurtosis()  # Calculate kurtosis values
    return kurtosis_values

# %%
# Get kurtosis values

get_kurtosis(df)
# Out:
# ladder_score                   -0.37
# logged_gdp_per_capita          -0.82
# social_support                  0.39
# healthy_life_expectancy        -0.56
# freedom_to_make_life_choices    0.41
# generosity                      1.64
# perceptions_of_corruption       2.25
# investment_risk_factor          2.25
# risk_factor_normalized          2.25
# dtype: float64

# %% [markdown]
# The function returns a Series containing the kurtosis values for each numerical column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's visually check the distribution of given feature/s:</strong></p>
#
#
# **The following code creates a ``distribution plot (displot)`` for the logged_gdp_per_capita column in our DataFrame.**

# %%
# Create a distribution plot with specified figure size
sns.displot(data=df, x="logged_gdp_per_capita", bins=20, kde=True, height=4, aspect=1.5)

# Show the plot
plt.show()

# %% [markdown]
# The output will be a combined histogram and KDE plot showing the distribution of the logged_gdp_per_capita values. We will see:
# - The histogram bars representing the frequency of observations in each bin. Gives an idea of the distribution of logged_gdp_per_capita values, showing how many data points fall into each bin.
# - The KDE curve showing the estimated probability density function of the data. Provides a smoothed line over the histogram, illustrating the underlying distribution shape more clearly.
#
#
# <hr>
#
# - **``height``**: This parameter controls the height of the figure in inches. In this example, it is set to 4.
# - **``aspect``**: This parameter controls the aspect ratio of the plot. It is defined as the ratio of width to height. Setting it to **``1.5``** means the **``width will be 1.5 times the height``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet sets up a figure with a specified size and creates a kernel density estimate (KDE) plot for the logged_gdp_per_capita column in the DataFrame.**

# %%
# Set the figure size
plt.figure(figsize=(8, 4))

# Create a KDE plot
sns.kdeplot(data=df, x="logged_gdp_per_capita");

# %% [markdown]
# The output will be a smooth curve representing the estimated density of the logged_gdp_per_capita values. The area under the curve represents the distribution of the data, and the plot will give us insights into the shape, center, and spread of the data points.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code sets up a figure with a specified size and creates a ``horizontal box plot`` for the logged_gdp_per_capita column in the DataFrame.**

# %%
# Set the figure size
plt.figure(figsize=(8, 4))

# Create a horizontal box plot
sns.boxplot(data=df, x="logged_gdp_per_capita", orient='h');
# When the whisker is drawn with the default value of 1.5, the outlier does NOT appear.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code sets up a figure with a specified size and creates a box plot to visualize the ``distribution of logged_gdp_per_capita`` across ``different regions`` indicated by regional_indicator in our DataFrame.**

# %%
plt.figure(figsize=(10, 8))

sns.boxplot(data=df, x="logged_gdp_per_capita", y="regional_indicator");

# %% [markdown]
# - Each box represents the interquartile range (IQR) of logged_gdp_per_capita for a specific region.
# - The line inside each box indicates the median.
# - Whiskers extend to the maximum and minimum values within 1.5 times the IQR.
# - Outliers may be plotted as individual points beyond the whiskers.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 TASK:</strong></p>
#
# - **Let's visually examine with a scatter plot how `ladder_score` is distributed by `logged_gdp_per_capita` values:**
#
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code sets up a figure with a specified size and creates a ``scatter plot`` to visualize the ``relationship between ladder_score and logged_gdp_per_capita`` in our DataFrame.**

# %%
# Set the figure size
plt.figure(figsize=(10, 5))

# Create a scatter plot
sns.scatterplot(x="ladder_score", y="logged_gdp_per_capita", data=df);

# %% [markdown]
# **Scatter Plot Insights:** The plot helps visualize the correlation between the two variables.
# - We can look for patterns such as:
#   - **``Positive Correlation``**: As logged_gdp_per_capita increases, does the ladder_score also increase?
#   - **``Negative Correlation``**: Does an increase in logged_gdp_per_capita correspond with a decrease in ladder_score?
#   - **``No Correlation``**: Are the points scattered without any discernible pattern?
#
# Outliers can also be identified easily; points that are far away from the general cluster may indicate unusual observations.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code sets up a ``regression plot`` using Seaborn's regplot, which ``combines a scatter plot with a fitted regression line``.**

# %%
# Set the figure size (optional, uncomment if desired)
# plt.figure(figsize=(12, 8), dpi=100)

# Create a regression plot
sns.regplot(x="ladder_score", y="logged_gdp_per_capita", data=df);

# in regplot; a calculated regression line (best fitting line with CI) is added onto the scatter plot.
# This line shows a general trend of the relationship between variables x and y.

# %% [markdown]
# **Interpretation:**
# - **``Regression Line``**: The line represents the best-fitting linear relationship between ladder_score and logged_gdp_per_capita.
#   - If the line slopes upwards, it suggests a positive correlation—higher GDP per capita is associated with higher ladder scores.
#   - If the line slopes downwards, it suggests a negative correlation.
#   - A flat line indicates no linear relationship.
# - **``Confidence Interval (CI)``**: The shaded area around the regression line represents the 95% confidence interval for the predictions. Wider areas indicate less certainty about the estimates, while narrower areas suggest more certainty.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's colorize the observation points according to `regional_indicator` values:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code sets up a figure with a specified size and creates a ``scatter plot`` that visualizes the ``relationship between ladder_score and logged_gdp_per_capita``, using ``different colors`` to represent ``different regions`` indicated by regional_indicator.**

# %%
# Set the figure size
plt.figure(figsize=(12, 5))

# Create a scatter plot with hue
sns.scatterplot(x="ladder_score", 
                y="logged_gdp_per_capita", 
                hue="regional_indicator", 
                data=df)

# Customize the legend
plt.legend(loc='upper left', fontsize=7)

# Show the plot
plt.show()

# %% [markdown]
# **Scatter Plot Insights:**
# - The plot allows us to visually assess the relationship between ladder_score and logged_gdp_per_capita across different regions.
# - We can observe clusters of points that correspond to different regions, helping to identify patterns or differences in well-being and economic indicators by region.
# - It also makes it easier to see how the distribution of ladder_score and logged_gdp_per_capita varies among regions.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's examine the ladder scores of the CE_Europe region:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``filters the DataFrame`` to create a ``new DataFrame df_CE_Europe``, which contains ``only the rows`` where the regional_indicator is ``"Central and Eastern Europe``.**

# %%
# Filter the rows including "Central and Eastern Europe"
df_CE_Europe = df1[df1["regional_indicator"] == "Central and Eastern Europe"]

# Display the Filtered DataFrame
df_CE_Europe
# Out:
#                                 regional_indicator  ladder_score  \
# Czech Republic          Central and Eastern Europe          6.96
# Slovenia                Central and Eastern Europe          6.46
# Kosovo                  Central and Eastern Europe          6.37
# Slovakia                Central and Eastern Europe          6.33
# Lithuania               Central and Eastern Europe          6.25
# Estonia                 Central and Eastern Europe          6.19
# Poland                  Central and Eastern Europe          6.17
# Romania                 Central and Eastern Europe          6.14
# Serbia                  Central and Eastern Europe          6.08
# Latvia                  Central and Eastern Europe          6.03
# Hungary                 Central and Eastern Europe          5.99
# Croatia                 Central and Eastern Europe          5.88
# Bosnia and Herzegovina  Central and Eastern Europe          5.81
# ...

# %% [markdown]
# **DataFrame Filtering:**
# - **``df1["regional_indicator"] == "Central and Eastern Europe"``**: This creates a boolean mask that is True for rows where the regional_indicator column matches "Central and Eastern Europe" and False otherwise.
#
# **Applying the Filter:**
# - **``df1[...]``**: This syntax filters df1 using the boolean mask. The result is a new DataFrame, df_CE_Europe, that includes only the rows where the condition is True.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``resets the index`` of the df_CE_Europe DataFrame.**

# %%
# Reset the index
df_CE_Europe = df_CE_Europe.reset_index()

# Display the Updated DataFrame
df_CE_Europe
# Out:
#                      index          regional_indicator  ladder_score  \
# 0           Czech Republic  Central and Eastern Europe          6.96
# 1                 Slovenia  Central and Eastern Europe          6.46
# 2                   Kosovo  Central and Eastern Europe          6.37
# 3                 Slovakia  Central and Eastern Europe          6.33
# 4                Lithuania  Central and Eastern Europe          6.25
# 5                  Estonia  Central and Eastern Europe          6.19
# 6                   Poland  Central and Eastern Europe          6.17
# 7                  Romania  Central and Eastern Europe          6.14
# 8                   Serbia  Central and Eastern Europe          6.08
# 9                   Latvia  Central and Eastern Europe          6.03
# 10                 Hungary  Central and Eastern Europe          5.99
# 11                 Croatia  Central and Eastern Europe          5.88
# 12  Bosnia and Herzegovina  Central and Eastern Europe          5.81
# ...

# %% [markdown]
# **Resetting the Index:**
# - **``df_CE_Europe.reset_index()``**: This method resets the index of the DataFrame. The default behavior is to create a new integer index starting from 0 for the rows in df_CE_Europe.
#   - If the original index had meaningful values (e.g., country names), and we want to keep them as a column, we can use reset_index(drop=False). Otherwise, using drop=True will discard the old index.
#
# **Assigning the Result:**
# - The result of reset_index() is assigned back to df_CE_Europe, effectively updating it with the new index.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``renames the index column`` of the df_CE_Europe DataFrame to ``"country_name``."**

# %%
# Rename the "index" column
df_CE_Europe.rename(columns = {"index": "country_name"}, inplace=True)

# Display the Updated DataFrame
df_CE_Europe
# Out:
#               country_name          regional_indicator  ladder_score  \
# 0           Czech Republic  Central and Eastern Europe          6.96
# 1                 Slovenia  Central and Eastern Europe          6.46
# 2                   Kosovo  Central and Eastern Europe          6.37
# 3                 Slovakia  Central and Eastern Europe          6.33
# 4                Lithuania  Central and Eastern Europe          6.25
# 5                  Estonia  Central and Eastern Europe          6.19
# 6                   Poland  Central and Eastern Europe          6.17
# 7                  Romania  Central and Eastern Europe          6.14
# 8                   Serbia  Central and Eastern Europe          6.08
# 9                   Latvia  Central and Eastern Europe          6.03
# 10                 Hungary  Central and Eastern Europe          5.99
# 11                 Croatia  Central and Eastern Europe          5.88
# 12  Bosnia and Herzegovina  Central and Eastern Europe          5.81
# ...

# %% [markdown]
# **Renaming Columns:**
# - **``df_CE_Europe.rename(...)``**: This method is used to rename columns in a DataFrame.
# - **``columns={"index": "country_name"}``**: This dictionary specifies that the column currently named "index" should be renamed to "country_name".
#
# **In-Place Modification:**
# - **``inplace=True``**: This parameter allows the renaming to be done in place, meaning the original DataFrame is modified directly without needing to assign the result to a new variable.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code snippet ``generates descriptive statistics`` for the ladder_score column in the df_CE_Europe DataFrame.**

# %%
df_CE_Europe["ladder_score"].describe()
# Out:
# count   17.00
# mean     5.98
# std      0.49
# min      5.10
# 25%      5.81
# 50%      6.08
# 75%      6.25
# max      6.96
# Name: ladder_score, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the mean ladder_score`` for ``each country`` in the df_CE_Europe DataFrame by ``grouping the data based on the country_name`` column.**

# %%
# Calculate the mean ladder_score for each country

df_CE_Europe.groupby("country_name")["ladder_score"].mean()
# Out:
# country_name
# Albania                  5.12
# Bosnia and Herzegovina   5.81
# Bulgaria                 5.27
# Croatia                  5.88
# Czech Republic           6.96
# Estonia                  6.19
# Hungary                  5.99
# Kosovo                   6.37
# Latvia                   6.03
# Lithuania                6.25
# Montenegro               5.58
# North Macedonia          5.10
# Poland                   6.17
# Romania                  6.14
# Serbia                   6.08
# Slovakia                 6.33
# Slovenia                 6.46
# Name: ladder_score, dtype: float64

# %% [markdown]
# The output provides a Series where the **``index``** represents the **``country names``**, and the **``values``** represent the **``average ladder score for each country``**.
# - This allows us to quickly compare the average well-being or happiness scores across different countries in the Central and Eastern Europe region.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the mean ladder_score`` for ``each country`` in the df_CE_Europe DataFrame, ``sorts the results in descending orde``r, and displays the countries with the highest average ladder scores first.**

# %%
# Sort Values in Descending Order

df_CE_Europe.groupby("country_name")["ladder_score"].mean().sort_values(ascending=False)
# Out:
# country_name
# Czech Republic           6.96
# Slovenia                 6.46
# Kosovo                   6.37
# Slovakia                 6.33
# Lithuania                6.25
# Estonia                  6.19
# Poland                   6.17
# Romania                  6.14
# Serbia                   6.08
# Latvia                   6.03
# Hungary                  5.99
# Croatia                  5.88
# Bosnia and Herzegovina   5.81
# Montenegro               5.58
# Bulgaria                 5.27
# Albania                  5.12
# North Macedonia          5.10
# Name: ladder_score, dtype: float64

# %% [markdown]
# The output provides a Series where the **``index``** represents the **``country names``**, and the **``values``** represent the **``average ladder score for each country, sorted from highest to lowest``**.
# - This allows for quick identification of which countries in the Central and Eastern Europe region have the highest average measures of well-being or happiness.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``groups the df_CE_Europe`` DataFrame by ``country_name``, ``calculates the mean ladder_score`` for ``each country``, ``sorts the results in descending order``, and ``resets the index`` to create a clean DataFrame.**

# %%
grp = df_CE_Europe.groupby("country_name")["ladder_score"].mean().sort_values(ascending=False).reset_index()

# Display the DataFrame
grp
# Out:
#               country_name  ladder_score
# 0           Czech Republic          6.96
# 1                 Slovenia          6.46
# 2                   Kosovo          6.37
# 3                 Slovakia          6.33
# 4                Lithuania          6.25
# 5                  Estonia          6.19
# 6                   Poland          6.17
# 7                  Romania          6.14
# 8                   Serbia          6.08
# 9                   Latvia          6.03
# 10                 Hungary          5.99
# 11                 Croatia          5.88
# 12  Bosnia and Herzegovina          5.81
# 13              Montenegro          5.58
# 14                Bulgaria          5.27
# 15                 Albania          5.12
# 16         North Macedonia          5.10

# %% [markdown]
# **Grouping the Data:**
# - **``df_CE_Europe.groupby("country_name")``**: This groups the DataFrame by the country_name column.
#
# **Selecting the Column:**
# - **``["ladder_score"]``**: This selects the ladder_score column for aggregation.
#
# **Calculating the Mean:**
# - **``.mean()``**: Computes the average ladder score for each country.
#
# **Sorting the Results:**
# - **``.sort_values(ascending=False)``**: Sorts the grouped means in descending order, showing countries with higher average ladder scores first.
#
# **Resetting the Index:**
# - **``.reset_index()``**: Resets the index of the resulting Series to convert it back into a DataFrame. This makes country_name a regular column in the DataFrame instead of an index.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code creates a ``bar plot`` to visualize the ``average ladder_score`` for ``countries in Central and Eastern Europe``, using the grouped DataFrame.**

# %%
# Set the figure size (optional, uncomment if desired)
# plt.figure(figsize=(12, 8), dpi=100)

# Create a bar plot
ax = sns.barplot(data=grp, x="country_name", y="ladder_score")
# Since df is already value-sorted, there is no need to use the order parameter.

# Customize the plot title and axes
plt.title('Ladder Scores of Central and Eastern Europe Countries', fontsize=14, c="darkblue")
plt.xticks(fontsize=10, rotation=80)  # Rotate x-axis labels for better readability

# Add labels to the bars
ax.bar_label(ax.containers[0], size=8, c="darkred")

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's check for the potential outliers in the perceptions_of_corruption feature/column of the CE_Europe region:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``generates descriptive statistics`` for the ``perceptions_of_corruption`` column in the df_CE_Europe DataFrame.**

# %%
# Descriptive statistics for the perceptions_of_corruption

df_CE_Europe["perceptions_of_corruption"].describe()
# Out:
# count   17.00
# mean     0.85
# std      0.10
# min      0.53
# 25%      0.81
# 50%      0.88
# 75%      0.92
# max      0.94
# Name: perceptions_of_corruption, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code creates a ``horizontal box plot`` to visualize the ``distribution of the perceptions_of_corruption`` column in the df_CE_Europe DataFrame.**

# %%
# Set the figure size
plt.figure(figsize=(9, 4))

# Create a horizontal box plot
sns.boxplot(x=df_CE_Europe["perceptions_of_corruption"], orient="h")

# Customize the plot
plt.title('Perceptions of Corruption in Central and Eastern Europe', fontsize=14, c="darkblue")
plt.xlabel('Perceptions of Corruption')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code creates a ``histogram`` to visualize the ``distribution of the perceptions_of_corruption`` column in the df_CE_Europe DataFrame.**

# %%
# Set the figure size
plt.figure(figsize=(9, 4))

# Create a histogram
sns.histplot(df_CE_Europe["perceptions_of_corruption"], bins=20)

# Customize the plot
plt.title('Distribution of Perceptions of Corruption in Central and Eastern Europe', fontsize=12, c="darkblue")
plt.xlabel('Perceptions of Corruption')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's manually calculate Q1, Q3, IQR, Lower Limit, Upper Limit for detecting potential outliers:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the first (Q1) and third (Q3) quartiles`` of the ``perceptions_of_corruption`` column in the df_CE_Europe DataFrame using NumPy's ``percentile()`` function.**

# %%
# Calculate the first and third quartiles
Q1, Q3 = np.percentile(df_CE_Europe["perceptions_of_corruption"], [25, 75])

# Display the First and Third Quartiles
Q1, Q3
# Out:
# (0.812, 0.917)

# %% [markdown]
# - **``Q1 (First Quartile)``**: Indicates that 25% of the perceptions of corruption scores are below this value.
# - **``Q3 (Third Quartile)``**: Indicates that 75% of the perceptions of corruption scores are below this value.
#
# These quartiles are useful for understanding the spread and central tendency of the data, and they can also be used to calculate the interquartile range (IQR), which is IQR=Q3−Q1. The IQR is often used to identify outliers in the data.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the Interquartile Range (IQR)`` using the ``first (Q1)`` and ``third quartile (Q3)`` values we obtained earlier.**

# %%
# Calculate the Inter Quartile Range (IQR)
IQR = Q3-Q1

# Display the Inter Quartile Range
IQR

# stats.iqr(df_CE_Europe["perceptions_of_corruption"])
# Out:
# 0.10499999999999998

# %% [markdown]
# - A larger IQR indicates greater variability in the middle half of the data, while a smaller IQR suggests that the data points are closer together.
# - The IQR is also used in identifying outliers. Typically, any data point that falls below Q1−1.5×IQR or above Q3+1.5×IQR is considered an outlier.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code ``calculates the lower limit`` for identifying outliers using the Interquartile Range (IQR) and the first quartile (Q1).**

# %%
# Calculate the LOWER Limit
lower_lim = Q1-1.5*IQR

# Display the LOWER Limit
lower_lim
# Out:
# 0.6545000000000001

# %% [markdown]
# - If the **``lower_lim value``** is, for example, **``0.6545``**, then **``any perception of corruption score below 0.6545 would be considered an outlier``**.
# - This helps in understanding which observations may need further investigation or could skew your analysis.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``calculates the upper limit`` for identifying outliers using the Interquartile Range (IQR) and the third quartile (Q3).**

# %%
# Calculate the UPPER Limit
upper_lim = Q3+1.5*IQR

# Display the UPPER Limit
upper_lim
# Out:
# 1.0745

# %% [markdown]
# - If the **``upper_lim value``** is, for instance, **``1.0745``**, then **``any perception of corruption score above 1.0745 would be considered an outlier``**.
# - This information is crucial for understanding the distribution of your data and for identifying values that may need further scrutiny.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``identifies potential outliers ``in the ``perceptions_of_corruption`` column of the df_CE_Europe DataFrame based on the previously calculated lower and upper limits.**

# %%
# Filtering for Outliers
potential_outliers = df_CE_Europe[(df_CE_Europe["perceptions_of_corruption"] < lower_lim) | (df_CE_Europe["perceptions_of_corruption"] > upper_lim)]

# Displaying for Outliers
potential_outliers
# Out:
#   country_name          regional_indicator  ladder_score  \
# 5      Estonia  Central and Eastern Europe          6.19
#
#    logged_gdp_per_capita  social_support  healthy_life_expectancy  \
# 5                  10.48            0.94                    68.80
#
#    freedom_to_make_life_choices  generosity  perceptions_of_corruption
# 5                          0.91       -0.11                       0.53

# %% [markdown]
# **Filtering for Outliers:**
# - **``df_CE_Europe[...]``**: This syntax filters the DataFrame to include only the rows that meet certain conditions.
# - **``(df_CE_Europe["perceptions_of_corruption"] < lower_lim)``**: This condition checks for values in the perceptions_of_corruption column that are less than the lower limit.
# - **``(df_CE_Europe["perceptions_of_corruption"] > upper_lim)``**: This condition checks for values that are greater than the upper limit.
# - The **``|``** operator combines these two conditions, meaning that either condition can be true for a row to be included in potential_outliers.
#
# **Result:**
# The resulting DataFrame, potential_outliers, contains only those rows from df_CE_Europe where the perceptions_of_corruption values are considered outliers based on the established limits.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``retrieve the indices of the potential outliers`` from the potential_outliers DataFrame, so we can simply access the index attribute.**

# %%
# Get the indices of the potential outliers

potential_outliers.index
# Out:
# Int64Index([5], dtype='int64')

# %% [markdown]
# - The output will be an index object (like Int64Index), listing the row numbers from the original df_CE_Europe DataFrame that correspond to the potential outliers.
# - Knowing these indices can be useful if we need to reference or manipulate the original DataFrame based on the identified outliers.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's apply the User Defined Function created above for detecting potential outliers:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **Previously a User Defined function ``find_outliers`` was defined to find outliers in a DataFrame. Below is an example of how we might implement such a function, along with how to use it with your df_CE_Europe DataFrame.**

# %%
def find_outliers(df, column, threshold=1.5):
    # Calculate Q1 and Q3
    Q1 = np.percentile(df[column], 25)
    Q3 = np.percentile(df[column], 75)
    IQR = Q3 - Q1
    
    # Calculate the lower and upper bounds
    lower_lim = Q1 - threshold * IQR
    upper_lim = Q3 + threshold * IQR
    
    # Identify outliers
    outliers = df[(df[column] < lower_lim) | (df[column] > upper_lim)]
    
    # Create a modified DataFrame without the outliers
    modified_df = df[~df.index.isin(outliers.index)]
    
    return modified_df, outliers

# %%
# Find outliers
modified_df, outliers = find_outliers(df_CE_Europe, 'perceptions_of_corruption', threshold=1.5)

# Print the results
print("Modified DataFrame:")
display(modified_df)  # Assuming you're using a Jupyter notebook, or replace with print(modified_df)
print("\nOutliers:")
display(outliers)  # Assuming you're using a Jupyter notebook, or replace with print(outliers)
# Out:
# Modified DataFrame:
#               country_name          regional_indicator  ladder_score  \
# 0           Czech Republic  Central and Eastern Europe          6.96
# 1                 Slovenia  Central and Eastern Europe          6.46
# 2                   Kosovo  Central and Eastern Europe          6.37
# 3                 Slovakia  Central and Eastern Europe          6.33
# 4                Lithuania  Central and Eastern Europe          6.25
# 6                   Poland  Central and Eastern Europe          6.17
# 7                  Romania  Central and Eastern Europe          6.14
# 8                   Serbia  Central and Eastern Europe          6.08
# 9                   Latvia  Central and Eastern Europe          6.03
# 10                 Hungary  Central and Eastern Europe          5.99
# 11                 Croatia  Central and Eastern Europe          5.88
# 12  Bosnia and Herzegovina  Central and Eastern Europe          5.81
# ...

# %% [markdown]
# **Function Definition:**
# - The find_outliers function takes a DataFrame (df), a column name (column), and a threshold for outlier detection (default is 1.5).
# - It calculates the first (Q1) and third (Q3) quartiles, computes the IQR, and then determines the lower and upper limits for identifying outliers.
#
# **Identifying Outliers:**
# - It creates a DataFrame of outliers by filtering for values that fall outside the calculated limits.
# - The modified DataFrame is created by excluding the outliers.
#
# **Returning the Results:**
# - The function returns both the modified DataFrame (without outliers) and the DataFrame of outliers.
#
# **Printing Results**:
# - The display() function is typically used in Jupyter notebooks for better formatting. If we're working in a different environment, we can simply use print(modified_df) and print(outliers) instead.
# - The printed results will show us the modified **``DataFrame WITHOUT outliers``** and a **``separate DataFrame containing the identified outliers``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``creates a new DataFrame`` df_CE_Europe_V by ``dropping the rows identified as potential outliers`` from the df_CE_Europe DataFrame.**

# %%
# Drop the potential outliers from the original DataFrame
df_CE_Europe_V = df_CE_Europe.drop(potential_outliers.index)

# Display the modified DataFrame
df_CE_Europe_V
# Out:
#               country_name          regional_indicator  ladder_score  \
# 0           Czech Republic  Central and Eastern Europe          6.96
# 1                 Slovenia  Central and Eastern Europe          6.46
# 2                   Kosovo  Central and Eastern Europe          6.37
# 3                 Slovakia  Central and Eastern Europe          6.33
# 4                Lithuania  Central and Eastern Europe          6.25
# 6                   Poland  Central and Eastern Europe          6.17
# 7                  Romania  Central and Eastern Europe          6.14
# 8                   Serbia  Central and Eastern Europe          6.08
# 9                   Latvia  Central and Eastern Europe          6.03
# 10                 Hungary  Central and Eastern Europe          5.99
# 11                 Croatia  Central and Eastern Europe          5.88
# 12  Bosnia and Herzegovina  Central and Eastern Europe          5.81
# 13              Montenegro  Central and Eastern Europe          5.58
# ...

# %% [markdown]
# **Dropping Rows:**
# - **``df_CE_Europe.drop(...)``**: This method is used to **``remove specified rows``** from the DataFrame.
# - **``potential_outliers.index``**: This retrieves the indices of the rows identified as potential outliers. The **``drop()``** method will **``remove these rows from the original DataFrame``**.
#
# **Creating a New DataFrame:**
# - The result is assigned to df_CE_Europe_V, which contains all the original data except for the rows that were identified as outliers.
#
# **Displaying the Modified DataFrame:**
# - After executing the code, df_CE_Europe_V will contain the **``cleaned dataset WITHOUT the outliers``**.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:125%; text-align:left;"><strong>👉 Let's visually examine how `perceptions_of_corruption` is distributed in the dataset:</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code creates a ``horizontal box plot`` to visualize the ``distribution of the perceptions_of_corruption`` column in the modified DataFrame df_CE_Europe_V, which ``excludes the previously identified outliers``.**

# %%
# Set the figure size
plt.figure(figsize=(9, 4))

# Create a horizontal box plot for the modified DataFrame
sns.boxplot(df_CE_Europe_V["perceptions_of_corruption"], orient="h")

# Costomize the plot
plt.title('Perceptions of Corruption (Outliers Removed)', fontsize=14, c="darkblue")
plt.xlabel('Perceptions of Corruption')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code creates a ``histogram with a kernel density estimate (KDE)`` overlay to visualize the ``distribution of the perceptions_of_corruption`` column in the modified DataFrame df_CE_Europe_V.**

# %%
# Set the figure size
plt.figure(figsize=(9, 4))

# Create a histogram
sns.histplot(df_CE_Europe_V["perceptions_of_corruption"], bins=20, kde=True);

# Customize the plot
plt.title('Distribution of Perceptions of Corruption (Outliers Removed)', fontsize=14, c="darkblue")
plt.xlabel('Perceptions of Corruption')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %% [markdown]
# - The histogram allows us to see the frequency distribution of perceptions of corruption after removing outliers.
# - The KDE curve provides insights into the overall shape of the distribution (e.g., normal, skewed).
# - We can assess characteristics such as:
#   - **``Central Tendency``**: Where most of the data points cluster.
#   - **``Spread``**: The range of values and how they are distributed.
#   - **``Peaks``**: Locations of high frequency of observations.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:125%; text-align:left;"><strong>🤔💭 The question for future study/analysis is what topic will be covered considering the World Happiness Report❓</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <!-- ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">END OF THE RECAP</p>
#  -->
# <div style="background-color:#E51A59; font-family:newtimeroman; color:#E51A59; font-size:350%; text-align:center; border-radius:10px 10px; height: 20px; display: flex; align-items: center; justify-content: center;">
#     <p style="margin: 0; position: absolute; top: 60%; left: 35%; transform: translate(50%, 50%);"><strong>END OF THE RECAP</strong></p>
# </div>
#
# **Now. it's time to relax! When you have time, take your coffee and read [this great article](https://worldhappiness.report/ed/2024/happiness-of-the-younger-the-older-and-those-in-between/) about the globbal state of happiness.**
#
# <p style="text-align: center;"><img src="https://i.ibb.co/KXw699K/world-hapiness6.jpg" class="img-fluid" alt="CLRSWY"></p>
#
# <p style="text-align: center;">
#     <a href="https://johnmenadue.com/global-happiness-up-six-points-since-last-year-73-now-say-they-are-happy/" target="_blank" style="text-decoration: none; color: inherit;">Image Credit</a>
# </p>
#
# ___
#
# <a href="https://clarusway.com/"><img align="center" src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="450" height="200" alt="CLRSWY_LOGO" title="Way to Reinvent Yourself"></a><br/>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ________

# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>
