# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <hr>
#
# <a href="https://lms.clarusway.com/mod/lesson/view.php?id=2463&pageid=4531&startlastseen=no"><img align="center" src="https://i.ibb.co/6Z5pQxD/lmss.png" alt="Open in Clarusway LMS" width="70" height="200" title="Open Clarusway Learning Management Sytem"></a>
#
# <a href="https://github.com/clarusway/DS-DE-0322-Students/blob/main/3-%20Classes%26Labs/2-DAwPY/DAwPy_S01_(Numpy_Arrays).ipynb"><img align="left" src="https://i.ibb.co/n3HWyQX/github-logo.png" alt="Open in Clarusway GitHub" width="90" height="150" title="Open and Execute in Clarusway GitHub Repository"></a>
#
# <a href="https://nbviewer.org/github/4dsolutions/clarusway_data_analysis/blob/main/DAwPy_S1_%28Numpy_Arrays%29/DAwPy_S1_%28Numpy_Arrays%29.ipynb"><img align="right" src="https://i.ibb.co/48wtV8c/nbviewer-badge.png" alt="Open in nbviewer" width="100" height="100" title="Open and Execute in nbviewer"></a><br/>
#
# <hr>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="500" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/XS0bxSH/best-bootcamps.png" width="300" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY_Courses"></p>

# %% [markdown]
# <img src=https://i.ibb.co/6gCsHd6/1200px-Pandas-logo-svg.png width="600" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 07</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#E51A59; font-size:200%; text-align:center; border-radius:10px 10px;">Handling Missing Values</p>
#
# <img src=https://i.ibb.co/RgknJfB/missing-value.png width="700" height="200">
#
#
# **[Working with Missing Data in Pandas](https://pandas.pydata.org/docs/user_guide/missing_data.html)**
#
# - Missing Data can occur when ``no information`` is provided for one or more items or for a whole unit. Missing Data is a very ``big problem in a real-life scenarios``. Pandas represents missing values with ``NaN`` (``Not a Number``). Missing Data can also refer to as ``NA`` (an acronym for ``Not Available``) values in Pandas. In DataFrame sometimes many datasets simply arrive with missing data, either because it exists and was ``not collected`` or it ``never existed``.
#
# **[When and Why Is Data Missed?](https://www.tutorialspoint.com/python_pandas/python_pandas_missing_data.htm)**
#
# - Let us consider an online survey where different users being surveyed for a product. ``Many a times, people do NOT share all the information`` related to them. For Example, different users being surveyed may choose ``not to share their income``, some users may choose ``not to share the address``. Few people share their experience, but not how long they are using the product; few people share how long they are using the product, their experience but not their contact information. Thus, `in some or the other way a part of data is always missing``, and this is very ``common in real time``.
#
#
# **[Missing Value Handling Methods](https://becominghuman.ai/imputing-missing-values-f00a770d9cc4)**
#
# - **``Delete all instances with at least a missing value``**: If you do this method then, the size of the dataset should be large enough to represent the population without those instances.<br>
# - **``Recover redoing the experiment or contacting the subject``**: This is one of the high-cost methods to recover the values, redoing an experiment takes time and cost money, moreover if it's a public opinion kind of dataset, then acts like GDPR restrict future uses to contact the subject in some cases.<br>
# - **``Domain Experts Guessing``**: By consulting the domain experts it is possible to guess the missing values with their experience but this method is a hectic and highly cost method due to the high hourly rates of experts.<br>
# - **``Fill with mean``**: This is one of the easiest and most primary methods of imputing missing values, by filling each missing value with the average of the attribute. This is not always good to use because it reduces the variability of the data but in some cases makes sense.<br>
# - **``Fill with median``**: Similar to the above method the problem is it reduces the variability of the data. Moreover, if the missing values are distributed then it could increase the noise of the data as well.<br>
# - **``Using Machine Learning algorithms``**: There are two different ways of using ML for imputation, first the multiple-regression analysis, by creating a regression equation using the rest of the data it is possible to predict missing values. This method needs more complete instances to train the model. Finally, the most common and popular method is the Multiple Imputation. where there are multiple missing values based on the correlations for the missing data and then averages the simulated datasets by incorporating random errors in your predictions
#
# **🎥 [YouTube Video Source: Python Pandas Tutorial: Handle Missing Data; fillna, dropna, interpolate](https://www.youtube.com/watch?v=EaGbS7eWSs0)**<br>
# **🎥 [YouTube Video Source: Python Pandas Tutorial: Handle Missing Data; replace function](https://www.youtube.com/watch?v=XOxABiMhG2U)**<br>
# **🎥 [YouTube Video Source: Handling Missing Values in Pandas Dataframe](https://www.youtube.com/watch?v=uDr67HBIPz8)**

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [TYPE OF NAN VALUES](#1)
# * [DETECTING MISSING VALUES](#2)
# * [CONVERTING INAPPROPRIATE VALUES TO NAN VALUES](#3)
# * [MISSING VALUE HANDLING METHODS](#4)
# * [THE END OF THE SESSION - 07](#5)

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")  # to suppress all warnings

# %% [markdown]
# - **``Importing Libraries``**: Make sure to import the required libraries before beginning your. You need both pandas and numpy.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - ``import warnings``: This imports the warnings module, which is part of Python's standard library and provides a way to issue warning messages.
# - ``warnings.filterwarnings("ignore")``: This function call tells Python to ignore all warning messages that would normally be printed. This can be useful when we want to focus on the output of your program without being distracted by warnings.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:125%; text-align:left;"><strong>📢 Caution ❗❗❗</strong></p>
#
#
# - Ignoring warnings can sometimes hide important issues in our code, so use this approach judiciously. It's generally better to address the underlying causes of warnings rather than suppressing them.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Define the data

id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]  # list of strings

gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]  # list of strings

# list of strings with Numpy "nan"
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]  

# list of strings with Numpy "nan" & "None" type
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]  

# Numpy array with "mixed" data types ("int", "str", & "np.nan")
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])  

# Numpy array with "mixed" data types (int & np.nan)
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])  

# Numpy array with mixed data types (int, None, & np.nan)
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])  

# Create the DataFrame
df = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })

# Display the DataFrame
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# - **``Columns:``**
#   - **``id``**: Unique identifiers for each individual.
#   - **``gender``**: Gender of the individuals (M/F).
#   - **``status``**: Employment status (e.g., FT for full-time, PT for part-time, '-' for unspecified).
#   - **``dept``**: Department in which the individual works (with some missing values).
#   - **``var1``**: A numeric variable with some missing and non-numeric values (e.g., "-").
#   - **``var2``**: Another numeric variable, which also contains some missing values.
#   - **``salary``**: Salary information with some missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# - **``Data Definition``**: The data created above is defined as ``lists`` or ``NumPy arrays``. The use of ``np.nan`` and ``None`` allows for missing values.
#
# - **``The Cast of Characters:``**
#   - In this dataset, we have 11 individuals, each with a unique identifier (id), gender, employment status, department, and various attributes related to their jobs and earnings.
#
# - **``Employment Status and Departments:``**
#   - The dataset reveals a ``mix`` of ``full-time (FT)`` and ``part-time (PT)`` employees, with some entries marked as **``"-"``** or **``NaN``**, suggesting ``uncertainty`` or ``missing information`` regarding their employment status.
#   - Departments range from ``Data Science (DS)`` and ``Full Stack (FS)`` to ``AWS``, indicating a ``diverse work environment``. However, several entries have ``missing`` or ``inappropriate values``, pointing to potential data quality issues.
# - **``Numeric Variables:``**
#   - **``V1``**: This variable seems to represent some form of internal scoring or performance metric, with values ranging from 1 to 14. However, it includes NaN, which indicates missing data, as well as a "-" from one entry, suggesting that at least one individual may not have been assessed or recorded correctly.
#   - **``V2``**: This variable appears to represent another performance or evaluation metric, with some individuals receiving NaN values. It shows a wider range of scores, but the presence of NaN indicates gaps in the data.
#   - **``Salary``**: The salary data also contains NaN and None, reflecting either unreported salaries or possibly individuals who did not receive compensation due to various reasons.Gender Representation
#   - **``Gender``**: The dataset includes a balance of **``male (M)``** and **``female (F)``** employees, although the missing values in various fields may mask potential biases or trends in employment status, department distribution, or compensation.
#
# - **``Insights and Concerns:``**
#   - **``Data Gaps``**: The presence of **``NaN``**, **``None``**, and **``"-"``** indicates **``potential data quality issues``**. These gaps may hinder effective analysis and decision-making.
#   - **``Performance Metrics``**: The metrics **``V1``** and **``V2``** could be crucial for assessing employee performance or departmental effectiveness, but their reliability is compromised due to missing values.
#   - **``Salary Anomalies``**: The **``salary``** data provides insights into compensation trends, yet the missing values could skew any analysis regarding pay equity or department performance.
#
# - **``Conclusion:``**
#   - The dataset is a ``snapshot of a diverse workforce`` with several areas for improvement in data collection and management. Addressing the missing values and ensuring data integrity would enhance the potential for meaningful analysis and insights into employee performance, departmental effectiveness, and overall organizational health.
#
# <hr>
#
# In pandas, the data types (dtypes) are organized in a hierarchy that helps manage and manipulate data efficiently. Here's an overview of the dtype hierarchy in pandas:
#
# **1. General Categories of Dtypes:**
# - **``Numeric Types:``**
#   - **``Integer:``**
#       - **``int64``**: 64-bit signed integer (Signed integers can represent both positive and negative values. Unsigned integers can only represent non-negative values (zero and positive numbers))
#       - **``int32``**: 32-bit signed integer
#       - **``int16``**: 16-bit signed integer
#       - **``int8``**: 8-bit signed integer
#      - **``Unsigned Integer:``**
#       - **``uint64, uint32, uint16, uint8``**: Unsigned variants of the integer types.
#   - **``Floating Point:``**
#       - **``float64``**: 64-bit floating point
#       - **``float32``**: 32-bit floating point
#       - **``float16``**: 16-bit floating point
#    - **``Complex:``**
#       - **``complex64``**: Complex numbers (two 32-bit floats)
#       - **``complex128``**: Complex numbers (two 64-bit floats)
#   - **``Boolean:``**
#      - **``bool``**: Represents True or False values.
# - **``Object Types:``**
#    - **``object``**: A generic type used for mixed data types, often for strings.
# - **``String Types:``**
#     - **``string``**: A newer string type that handles text data more efficiently.
#     - **``unicode``**: Represents Unicode strings (in older versions).
# - **``Datetime Types:``**
#   - **``datetime64``**: Represents date and time values.
#    - **``timedelta``**: Represents differences between dates or times.
#    - **``Period``**: Represents a span of time.
#
# **2. Type Casting:**
# Pandas allows you to change the dtype of a column using the .astype() method:
# - ``df['Salary'].astype('float64')`` **==>** Change integer to float
#
# **[See the numpy dtype hierarchy](https://numpy.org/doc/stable/reference/arrays.scalars.html)**

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Type of NaN Values</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **🧐 [Values considered “missing”](https://pandas.pydata.org/docs/user_guide/missing_data.html)**
#
# - **``NaN``** stands for **``Not A Number``**, and nan values are **``constants``**. Its primary constant is to act as a **``placeholder for any missing numerical values``** in the array, so is a **``common missing data representation``**. It is a special **``floating-point``** value and **``CANNOT be converted``** to any other type than float.
#
# - As data comes in many shapes and forms, Pandas aims to be flexible with regard to handling missing data. While **``NaN``** is the **default missing value marker** for reasons of **computational speed and convenience**, we need to be able to easily detect this value with data of different types: floating point, integer, boolean, and general object. In many cases, however, the Python **``None``** will arise and we wish to also consider that “missing” or “not available” or “NA”.
#
# **In Pandas missing data is represented by two value:**
#
# - **``None``**: None is a Python **``singleton object``** that is often used for missing data in Python code. A singleton object is a design pattern that restricts the instantiation of a class to one single instance.
# - **``NaN ``**: NaN (an acronym for **``Not a Number``**), is a **``special floating-point``** value recognized by all systems that use the standard IEEE floating-point representation
#
# **🧐 [Data Cleaning with Python and Pandas: Detecting Missing Values](https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b)**<br>
# **🧐 [8 Methods For Handling Missing Values With Python Pandas](https://towardsdatascience.com/8-methods-for-handling-missing-values-with-python-pandas-842544cdf891)**<br>
# **🧐 [Missing values in pandas (nan, None, pd.NA)](https://note.nkmk.me/en/python-pandas-nan-none-na/)**<br>
# **🧐 [Handling Missing Data](https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html)**<br>
# **🧐 [Practical Strategies to Handle Missing Values](https://towardsdatascience.com/practical-strategies-to-handle-missing-values-626f9c43870b)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Let us first examine the Dataset:**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>💡👉🏾 Let's explore how important info() is to understand what is needed througout the analysis:</strong></p>
#
# - Although only **``one (1)``** **``"NaN"``** value looks like appearing in the 👉 **``"status"``** column, in fact, there are **``3 null values`` 🤔💭**.
# - The observations including 👉 **``"-"``** signs do **``NOT appear as NaN`` 🤔💭**.
# - Therefore, the dataset needs to be examined in more detail by looking at **``"unique"``** values and **``"value_counts"``**.
#
# In this sense, the 👉 **``df.info()``** output provides a **``comprehensive overview of the DataFrame's structure``**, highlighting the **``presence of missing values``** and the **``types of data stored``**. This information is ``crucial for deciding on data cleaning and preprocessing steps``.

# %%
# Concise summary of a DataFrame's structure

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 748.0+ bytes

# %% [markdown]
# - **``Total Entries``**: The DataFrame contains ``11 entries`` (``rows``).
#  - **``Columns and Non-Null Counts``**:
#    - **``id``**: ``11 non-null`` values; all entries are present.
#    - **``gender``**: ``11 non-null`` values; all entries are present.
#    - **``👉status``**: ``10 non-null`` values; ``1 entry`` is ``missing``.🤔💭
#    - **``dept``**: ``9 non-null`` values; ``2 entries`` are ``missing``.
#    - **``👉var1``**: ``11 non-null`` values; all entries are present.🤔💭
#    - **``var2``**: ``8 non-null`` values; ``3 entries`` are ``missing``.
#    - **``salary``**: ``8 non-null`` values; ``3 entries`` are ``missing``.
# - **``Data Types``**:
#   - **``object``**: ``6 columns`` are of type ``object``, which typically indicates string data.
#   - **``float64``**: ``1 column (var2)`` is of type ``float``, indicating it contains numerical data.
# - **``Memory Usage``**: The DataFrame uses approximately ``744 bytes of memory``.
#
# <hr>
#
# - **``Potential Actions``**:
#   - **``Handling Missing Values``**:
#     - Consider filling or dropping rows/columns with missing values, especially in ``"status"``, ``"dept"``, ``"var2"``, and ``"salary"``.
# <hr>
# - **``Data Types``**:
#   - The ``"salary"`` column contains ``numeric values`` stored as ``object``, which may ``need conversion`` to a numeric type for calculations.
#   - The ``"var1"`` column also contains ``mixed data types`` (including ``strings`` and ``np.nan``), which may require cleaning.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''    
    
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + " " + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

# %%
check_obj_columns(df)
# Out:
# Column status has mixed object types.
# Column dept has mixed object types.
# Column salary has mixed object types.

# %% [markdown]
# The message indicates that the **``following columns``** in our DataFrame contain **``mixed object types``**, meaning they include ``different data types within the same column``:
#
# - **``Column status``**: This column may contain both ``string values`` (like ``"FT"``, ``"PT"``) and ``other types`` (like ``np.nan`` or similar).
# - **``Column dept``**: This column likely contains a ``mix of string values`` (like ``"DS"``, ``"FS"``, ``"AWS"``) and ``missing values`` (like ``None`` or ``np.nan``).
# - **``Column salary``**: This column seems to have a ``variety of data types``, including ``numeric values`` and possibly ``strings`` or ``missing values``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:120%; text-align:left;"><strong>📌 Addressing mixed object types is crucial for ensuring the integrity of the DataFrame and for performing accurate data analysis.``</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Types of ``NaN``:</strong></p>
#
#
# **The following code snippetes ``determine the types of data`` using the ``type()`` function in Python:**

# %%
# Check the type of "np.nan"

type(np.nan)  # np.nan's default type is float.
# Out:
# float

# %% [markdown]
# - **``np.nan``**: This represents a **``"Not a Number"``** value, which is used in numerical computations to denote missing or undefined values.
# - **``Type``**: Despite being used to indicate missing data, **``np.nan``** is of type **``float``**. This is because it is a floating-point representation of "not a number" and is **``consistent with the behavior of floating-point arithmetic``** in Python and NumPy, making it an integral part of handling missing data in numerical arrays and DataFrames.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check the type of "np.NaN"

type(np.NaN)  # np.NaN's default type is float as well.
# Out:
# float

# %% [markdown]
# - **``np.NaN``**: ``Similar to`` **``np.nan``**, **``np.NaN``** also represents a **``"Not a Number"``** value, indicating missing or undefined data.
# - **``Type``**: Both **``np.nan``** and **``np.NaN``** are of type **``float``**, as they are designed to represent **``floating-point``** numbers in computations.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>💡👉 Both ``np.nan`` and ``np.NaN`` are treated as ``floats`` in Python and are ``used for handling missing values`` in numerical data.</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check the type of "None"

type(None)  # None's default type is "NoneType".
# Out:
# NoneType

# %% [markdown]
# **``NoneType``** in Python is the **``data type of the object``** when the **``object does NOT have any value``**. The **``None``** keyword is used to define a ``null value``, or ``no value at all``. **``None``** is ``NOT the same as`` ``0``, ``False``, or an ``empty string``. **``None``** is a ``data type of its own`` (``NoneType``) and **``only None can be None``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>💡👉 When is NoneType used❓</strong></p>
#
# It is useful in many places. It is the default return type of the function when the function does NOT return any value.
#
# - <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:125%; text-align:left;"><strong>📌 Use cases (Examples):</strong></p>
#
#   - If the Python **``regular expression``** in ``re.search()`` does NOT match, it returns ``NoneType`` object.
#   - When you search **``key``** in the Python ``dictionary`` and the key is **``NOT present``**, it returns ``NoneType`` object.
#   - The ``None`` keyword is also used for matching or identifying **``if a certain function returns any value or not``**.
#
# **🧐 [What is NoneType in Python and Null Equivalent?](https://www.csestack.org/nonetype-in-python-null/)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Operations with ``NaN``:</strong></p>
#
# The following statements demonstrate various behaviors of ``NaN`` and ``floating-point comparisons`` in Python using NumPy. Understanding these behaviors is crucial for handling missing values and performing numerical operations accurately.
#
# When performing **``mathematical operations with NaN``** (Not a Number) in Python, especially using NumPy or pandas, the results can often be **``counterintuitive``**.
#
# **``Basic Operations with NaN:``**
# - **``Addition``**: Adding NaN to any number or another NaN ``results in NaN``.
# - **``Subtraction``**: Subtracting NaN from any number or another NaN also ``results in NaN``.
# - **``Multiplication:``** Multiplying NaN by any number or another NaN ``results in NaN``.
# - **``Division``**: Dividing any number by NaN or dividing NaN by any number ``results in NaN``.
# - **``Exponential``**: Any operation that involves NaN will ``return NaN``.
# <hr>
#
# **``Comparisons Involving NaN:``**
# - **``Equality``**: ``NaN is NOT equal to NaN``. This is a defining characteristic of NaN.
# - **``Inequality``**: ``Any comparison with NaN`` (greater than, less than, etc.) will ``return False``.
# <hr>
#
# **``Summary:``**
# - **``Propagation of NaN``**: Operations involving ``NaN generally propagate the NaN value``, meaning ``if any operand is NaN, the result will also be NaN``.
# - **``Special Comparisons``**: NaN is ``treated uniquely in comparisons``, and it is essential to handle it carefully in data analysis to avoid misleading results.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# 1. Subtracting NaN from NaN
print(np.nan - np.nan)  # Output: nan (any operation involving NaN yields NaN).  

# 2. Adding NaN to NaN
print(np.nan + np.nan)  # Output: nan (any operation involving NaN yields NaN).

# 3. Adding 10 to NaN
print(np.nan + 10)  # Output: nan (any operation involving NaN yields NaN).

# 4. Multiplying 0 by NaN
print(0 * np.nan)  # Output: nan (any operation with NaN results in NaN).

# 5. Subtracting 10 from NaN
print(np.nan - 10)  # Output: nan (any operation involving NaN yields NaN).

# 6. Checking if NaN is equal to NaN
print(np.nan == np.nan)  # Output: False (NaN is not considered equal to itself).

# 7. Checking if infinity is greater than NaN
print(np.inf > np.nan)  # Output: False (comparison with NaN yields False).

# 8. Checking if NaN is NaN
print(np.nan is np.nan)  # Output: True (both refer to the same NaN object).

# 9. Checking if NaN is in a list containing NaN
print(np.nan in [np.nan])  # Output: True (list contains NaN).

# 10. Checking if NaN is in a set containing NaN
print(np.nan in set([np.nan]))  # Output: True (sets can contain NaN).

# 11. Checking floating-point equality
print(0.3 == 3 * 0.1)  # Output: False (due to floating-point precision issues).
# Out:
# nan
# nan
# nan
# nan
# nan
# False
# False
# True
# True
# True
# False

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:125%; text-align:left;"><strong>🎁🎉 COMPLIMENTARY INFO:</strong></p>
#
#
# At first, reading that **``np.nan == np.nan``** is **``False``** can trigger a reaction of confusion and frustration. ``Although either side of NaN==NaN contains the same value`` and their type is Number but they are **``NOT same``**. According to ECMA-262, either side of **``==``** or **``===``** contains **``NaN``** then it will result **``false``** value. [You may find a details rules in here](https://262.ecma-international.org/5.1/#sec-11.9.3)
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>💡👉 Equality vs. Identity</strong></p>
#
# To understand why **``np.nan in [np.nan]``** is **``True``**, we have to look at the difference between equality and identity.
#
# - **``Equality``** refers to the concept that most Python programmers know as **``“==”``**. This is used to ask Python **``whether the content of the variable is the same as the content of another variable``**.The **``content of NaN``** is **``NEVER equal to the content of another NaN``**.
#
# - **``Identity``** is when we are asking Python **``if a variable is the same as another variable``**, meaning we are asking Python **``whether the two variables share the same identity``**. Python assigns an **``id to each variable``** that is created, and ids are compared when Python looks at the identity of a variable in an operation. However, **``np.nan``** is a **``single object``** that **``always has the same id``**, no matter which variable you assign it to.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:120%; text-align:left;"><strong>📌 REMEMBER: Python checks identity before checking equality.</strong></p>
#
#
# **🧐 [Why np.nan==np.nan returns False](https://stackoverflow.com/questions/20320022/why-in-numpy-nan-nan-is-false-while-nan-in-nan-is-true)**<br>
# **🧐 [Navigating The Hell of NaNs in Python](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)**<br>
# **🧐 [How do you identify NP NaN?](https://fazerpergunta.com/biblioteca/artigo/read/127332-how-do-you-identify-np-nan)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>Memory address of ``NaN``:</strong></p>

# %%
a = np.nan
b = np.nan

# Print the memory addresses (IDs) of a and b
print(id(a))  # Output: Memory address of a
print(id(b))  # Output: Memory address of b

# Check for equality
print(a == b)  # Output: False

# Check for identity
print(a is b)  # Output: True or False (depending on the implementation)

# Check for identity
print(np.nan in [np.nan])  # Output: True
# Out:
# 1605938093392
# 1605938093392
# False
# True
# True

# %% [markdown]
# - **``nan``** ``not being equal to`` **``nan``** is part of the definition of nan, so that part's easy.
# - As for **``nan in [nan]``** being **``True``**, that's because **``identity is tested before equality`**` for containment in lists. We're comparing the same two objects.
# - The reason for this is that;
#   - **``== operator``** compares the values of both the operands and checks for value equality.
#   - **``is operator``**, on the other hand, checks whether both the operands refer to the same object or not.
#
# In fact, you can print out the **IDs** of both **a** and **b** and see that they **refer to the same object**.
#
# - **🧐 What is the None keyword in Python? [ANSWER01](https://www.educative.io/edpresso/what-is-the-none-keyword-in-python), [ANSWER02](https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object)**
#
# - **🧐 Difference between None and NaN in Pandas [ANSWER01](https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas), [ANSWER02](https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb)**
#
# - **🧐 Difference between np.nan and np.NaN [ANSWER](https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan)**
#
# - **🧐 Difference between nan and 'nan' in Python [ANSWER01](https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python), [ANSWER02](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:150%; text-align:left;"><strong>Let us examine the Null values in "salary", "status", and "var1" features:</strong></p>
#
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>First; "salary" column:</strong></p>

# %%
# Let us remember "salary" feature:

# Numpy array with mixed data types (int, None, & np.nan)
# salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])  

# Access and display the 'salary' column in the DataFrame
df["salary"]
# Out:
# 0      NaN
# 1       54
# 2       59
# 3      120
# 4       58
# 5       75
# 6     None
# 7      136
# 8       60
# 9      125
# 10     NaN
# Name: salary, dtype: object

# %% [markdown]
# - **``Missing Values``**: Any entries that are missing (like np.nan or None) will be displayed as ``NaN`` or ``None``.
# - **``NoneType``** in Python is a **``data type``** that simply shows that an **``object has NO value/has a value of None``**. - --- **``None``** and **``NaN``** sound similar, ``look similar BUT are actually quite different``.
#   - The ``None`` is a Python **``internal type``** which can be considered as the equivalent of NULL.
#   - The ``None`` keyword is used to define a null value, or NO value at all.
#   - The ``None`` is NOT the same as ``0``, ``False``, or an ``empty string``. It is a ``datatype of its own`` (``NoneType``) and **``only None can be None``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:125%; text-align:left;"><strong>📌 RECOMMENTED: While ``missing values`` are ``NaN`` in ``numerical arrays``, they are ``None`` in ``object arrays``.</strong></p>
#
#    - ``Numerical Data``: Use ``NaN`` to indicate missing values.
#    - ``Object Data``: Use ``None`` to indicate missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>The following statement highlights a <span style="color:red;">common scenario</span> in Pandas where a DataFrame column has a general data type (like object), but individual entries within that column may have specific types (like float).</strong></p>

# %%
# Check the type of the first element in the salary column

type(df["salary"][0])

# The type of the value at the index number 0 of the "salary" column is floating point.
# Out:
# float

# %% [markdown]
# - In pandas, **``missing values (like NaN)``** are represented as **``float types``**. Therefore, if the first element in the salary column is NaN, its type will be float.
#   - <class 'float'>
# - If the first element is a valid number (e.g., 54), the output would be:
#   - ``<class 'numpy.float64'>``
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check the value and its type at index 6

type(df["salary"][6])

# The type of the value at the index number 6 of the "salary" column is NoneType.
# Out:
# NoneType

# %% [markdown]
# - **``NoneType``** indicates that the value at df.salary[6] is **``None``**, which is used to **``signify missing data``** in Python.
# - This is **``distinct from NaN``**, which is typically used for numeric missing values in pandas.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check the value and its type at index 1

type(df["salary"][1])
# Out:
# int

# %% [markdown]
# The outputs indicate that the ``"salary"`` column in our DataFrame contains a ``mix of numeric values and missing entries``:
# - **``type(df.salary[0])``** is **``float``**:
#   - This suggests that the `first entry (index 0)`` in the ``"salary"`` column is a ``floating-point`` number. It could be a valid salary value.
# - **``type(df.salary[6])``** is **``NoneType``**:
#   - This indicates that the ``seventh entry (index 6)`` is ``missing`` or ``null``. In pandas, this value is often represented as ``NaN`` (``Not a Number``) or ``None``, which allows it to be treated as a missing value.
# - **``type(df.salary[1])``** is **``int``**:
#   - This indicates that the ``second entry (index 1)`` is an ``integer``. In this context, it could represent a salary that is a whole number.
# <hr>
#
# - The **``presence of different types``** (e.g., float, int, NoneType) in the same column suggests that the **``column has mixed data types``**.
# - This situation is **``common in Pandas``** when dealing with data that includes both numeric values and missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Second; "status" column:</strong></p>

# %%
# Let us remember "status" feature:

# list of strings with Numpy "nan"
# status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]  # list of strings with Numpy nan

# Access and display the 'salary' column in the DataFrame
df["status"]
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %% [markdown]
# - **``Index``**: The leftmost column (0 to 10) represents the index of the DataFrame. Each number corresponds to the position of the entry in the DataFrame.
# - **``Values``**:
#   - **``FT``**: Represents ``"Full-Time"``.
#   - **``PT``**: Represents ``"Part-Time"``.
#   - 📌 **``-``**: A ``hyphen`` placeholder that may signify an ``unspecified`` or ``irrelevant`` status.
#   - 📌 **``NaN``**: This indicates a ``missing value`` in the last entry (index 10).
# - **``Data Type``**: The **``dtype: object``** indicates that this ``column`` is of type ``object``, which is typically used in Pandas **``to handle mixed types``**, including strings.
# <hr>
#
# 📌 **``Potential Issues:``**
# - 👉 **``Mixed Values``**: The presence of both ``strings`` (``FT``, ``PT``, ``-``) and ``NaN`` suggests that this column may ``NOT be ideal`` for certain types of analysis without preprocessing.
# - 👉 **``Understanding Placeholder``**: The ``-`` should be ``clarified``. If it represents a missing status, it might be more appropriate to ``replace it with NaN`` or a ``more meaningful value``.
# <hr>
#
# 📌 **``Suggested Actions:``**
# - 👉 **``Data Cleaning``**:
#   - 💡 ``Consider replacing - with NaN`` or ``another appropriate value`` to maintain consistency.
#
# - 👉 **``Handling Missing Values``**:
#   - 💡 ``Decide how to handle the NaN values``, either by ``filling`` them, ``dropping`` them, or ``replacing`` them based on your analysis needs.
# - 👉 **``Checking Unique Values``**:
#   - 💡 We can ``check the unique values`` in the ``"status"`` column to better understand its contents:
#     - df['status'].unique()
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>The following statement highlights a <span style="color:red;">common scenario</span> in Pandas where a DataFrame column has a general data type (like object), but individual entries within that column may have specific types (like float).</strong></p>

# %%
# Check type of any observation in "status" column

type(df["status"][2])

# The type of the value at the index number 2 of the "status" column is integer.
# Out:
# str

# %%
# Check type of any observation in "status" column

type(df["status"][10])
# Out:
# float

# %% [markdown]
# The outputs indicate that the **``"status"``** column in our DataFrame contains a **``mix of numeric values and missing entries``**:
#
# - **``type(df.status[2])``** is **``str``**:
#   - This indicates that the **``value at index 2``** is a **``string``**. In our case, it is ``'-'`` (``hyphen``), which is a placeholder representing ``some unspecified status``.
# - **``type(df.status[10])``** is **``float``**:
#   - This indicates that the ``value at index 10`` is **``NaN``** (``Not a Number``), which is how Pandas represents missing values. In pandas, ``NaN`` is treated as a **``float type``**.
#   <hr>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:125%; text-align:left;"><strong>📌 WRAP UP:</strong></p>
#
#
# - The **``presence of different types``** (e.g., str, float, int, NoneType) in the same column suggests that the column has **``mixed data types``**.
# - This situation is **``common in Pandas``** when dealing with data that includes string, numeric values, and missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>Third; "var1" column:</strong></p>

# %%
# Let us remember "var1" feature:

# Numpy array with "mixed" data types ("int", "str", & "np.nan")
# V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6]) 

# Access and display the 'var1' column in the DataFrame

df["var1"]
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %% [markdown]
# **The output reveals that the ``"var1"`` column contains ``mixed types``, including strings that represent ``numeric values`` as well as ``placeholders`` for missing values.**
# - **``Values``**: The output shows the values in the status column, which includes various statuses (e.g., "FT", "PT", "-", and NaN).
# - **``Index``**: The index on the left corresponds to the row numbers in the DataFrame.
# - **``Data Type``**: The dtype indicates that the data type of the Series is object, which is typical for string data in pandas.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check type of any observation in "var1" column

type(df["var1"][3])
# Out:
# str

# %% [markdown]
# **``'nan'`` became a ``string`` here, but it's is expected to be ``'NaN'``, a floating-point number.**
# - Although the ``value at index 3`` was created by ``np.nan`` at the beginning, it is now represented as string ``nan`` (a string here, NOT the np.nan float). The ``type of NaN`` value created by np.nan before became ``str`` due to another string (``"-"`` - ``hyphen``) expression in the ``"var1"`` column. Thus, when you check ``type(df.var1[3])``, it returns ``str``, ``NOT float``.
# - This means that the entry is actually the ``string 'nan'`` now, which is ``different from the actual NaN`` used for missing values in Pandas.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check type of any observation in "var1" column

type(df["var1"][0])
# Out:
# str

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Check type of any observation in "var1" column

type(df["var1"][10])

# type(df.var1.iloc[-1])
# Out:
# str

# %% [markdown]
# **Similarly, the types of other values, such as df.var1``[0]`` and df.var1``[10]``, in the ``"var1"`` column became ``string`` due to a string (``"-"`` Hyphen) expression.**
#
# **📌 So be careful that the ``presence of any non-numeric strings`` (like '-') can ``cause`` the ``entire column`` to be treated as an ``object type``, specifically strings.**
#
# - **``The dtype: object``** indicates that the **``entire column``** is treated as an **``object type``**, which can include ``strings``, ``numbers``, and ``other types``.
# The presence of ``non-numeric strings`` (like ``'nan'`` and ``'-'``) means that the column may ``require cleaning for numerical analysis``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:125%; text-align:left;"><strong>📌 Therefore, it can be concluded that it is crucial to understand how any null values comes out and how they are created and treated at the begining.</strong></p>
#
#
# 💡 **``Suggested Actions:``**
# - 👉 **``Mixed Data``**: Since the columns contain both numeric-like strings and actual string values, it is important to clean and standardize the data to ensure consistent types.
# - 👉 **``Numerical Operations``**: If we attempt to perform numerical operations on such columns without cleaning it, we may encounter errors or unexpected results.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Detecting Missing Values</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **``NaN``**, standing for **``"Not A Number"``**, is a **``numeric data type``** used to represent any value that is **``undefined``** or **``unpresentable``**.
#
# - For example, 0/0 is undefined as a real number and is, therefore, represented by NaN.
# - The square root of a negative number is an imaginary number that CANNOT be represented as a real number, so, it is represented by NaN.
#
# **``NaN``** is also assigned to variables, in a computation, that do NOT have values and have yet to be computed.

# %%
# Let's remember our DataFrame:

df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# - **``Mixed Data Types``**:
#   - The **``"var1"``** column contains both ``numeric values`` and the ``string 'nan'``, which should be converted to actual NaN.
#   - The **``status``** column has placeholders like ``'-'`` (hyphen), which may need to be standardized.
# - **``Missing Values``**:
#   - ``Several columns`` contain ``NaN``, which can complicate analysis. We should decide how to handle these missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>isnull() & isna():</strong></p>
#
# - Pandas **[isnull()](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html)**, and **[isna()](https://pandas.pydata.org/docs/reference/api/pandas.isna.html)** methods are used to check and manage NULL values in a DataFrame.
#   - The function returns a boolean same-sized object indicating if the values are NA. NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values.
#
# 📌 **``Note``**: Characters such as **``empty strings``** **``''``** or **``numpy.inf``** are **``NOT considered NA values``** (unless we set pandas.options.mode.use_inf_as_na=True).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following code identifies missing values in our DataFrame. Both methods serve the same purpose and return a DataFrame of the same shape as df, with ``boolean values indicating whether each entry is missing``:**

# %%
# Check for "missing" values using isnull()
display(df.isnull())

# Check for "missing" values using isna()
df.isna()

# Both give the same result. Returns "True" for "null values" and "False" for "non-null values".
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# ...

# %% [markdown]
# - **``df.isnull()``**: This will ``return a DataFrame`` with **``True``** for positions ``where there are missing values`` (NaN or None) and **``False``** ``otherwise``.
# - **``df.isna()``**: This will yield the ``same output as isnull()`` method, as ``both methods are equivalent in functionality``.
# <hr>
#
# Pandas **[notnull()](https://pandas.pydata.org/docs/reference/api/pandas.notnull.html)** and **[notna()](https://pandas.pydata.org/docs/reference/api/pandas.notna.html)** functions detects existing/ non-missing values in the dataframe. The function returns a boolean object having the same size as that of the object on which it is applied, indicating whether each individual value is a na value or not. All of the non-missing values gets mapped to true and missing values get mapped to false.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:120%; text-align:left;"><strong>📌📢 Note: Characters such as ``empty strings`` or ``numpy.inf`` are ``NOT considered NA values``.</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following identifies ``non-missing values`` in your DataFrame. Both methods return a DataFrame of the same shape as df, with ``boolean values indicating whether each entry is NOT missing``:**

# %%
# Check for "non-missing "values using notnull()
display(df.notnull())

# Check for "non-missing" values using notna()
df.notna()

# Both give the same result. Returns "True" for non-null values and False for null values.
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# ...

# %% [markdown]
# - **``df.notnull()``**: This will ``return a DataFrame`` with **``True``** for positions ``where there are non-missing values`` and **``False``** ``otherwise``.
# - **``df.notna()``**: This will yield the ``same output as notnull()``, as both methods are ``equivalent in functionality``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>isnull().any():</strong></p>
#
# The method ``df.isnull().any()`` is useful for ``checking each column`` in the DataFrame to see ``if there are any missing values (NaN)``. It returns ``a Series`` with ``boolean values``, indicating whether each column contains ``at least one missing value``.
#
# **🧐 [Python Documentation on any()](https://docs.python.org/3/library/functions.html)**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code identifies which columns in the DataFrame contain missing values:**

# %%
# columns/variables containing any missing values

# Check for any "null" values in each column
df.isnull().any()
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %% [markdown]
# **``Explanation:``** Using ``df.isnull().any()`` is a quick way to identify which columns in the DataFrame contain missing values.
# - Each entry in the resulting Series corresponds to a column in the DataFrame.
# - **``True``** indicates that there is ``at least one missing value`` in that column, while **``False``** indicates there are ``NO missing values``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``checks for missing values (NaN) across each row`` in the DataFrame. It returns ``a Series`` with ``boolean values`` indicating whether each row contains ``at least one missing value``:**

# %%
# rows containing any missing values

# Check for any "null" values in each row
df.isnull().any(axis=1)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %% [markdown]
# **``Explanation:``** Using ``df.isnull().any(axis=1)`` is a quick way to identify which rows in the DataFrame contain missing values. This can help you decide on further data cleaning or preprocessing steps, such as filtering out incomplete records or filling in missing values.
# - Each entry in the resulting Series corresponds to a row in the DataFrame.
# - **``True``** indicates that there is ``at least one missing value in that row``, while **``False``** indicates that the row has ``NO missing values``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``counts the number of missing values (NaN) in each column`` of the DataFrame. It returns ``a Series`` with the ``count of missing values for each column``:**

# %%
# number of missing values in the columns

# Count the number of "null" values in each column
df.isnull().sum()
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# **``Explanation:``** Using df.isnull().sum() is a straightforward way to get a quick overview of how many missing values are present in each column of your DataFrame. This information is crucial for data cleaning and preprocessing.
# - Each entry in the resulting Series corresponds to a column in the DataFrame.
# - The number represents how many missing values (NaN or None) are present in that column.
#    - For example, if ``"status"`` has 2 missing values, it indicates that there are two entries in the ``"status"`` column that are NaN.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code calculates the ``total number of missing values (NaN)`` in the ``entire DataFrame``. It works by first summing the missing values in each column and then summing those totals to ``get a single scalar`` value representing the overall count of missing values:**

# %%
# number of missing values in the all DataFrame

df.isnull().sum().sum()
# Out:
# 9

# %% [markdown]
# **``Explanation:``** Using **``df.isnull().sum().sum()``** is an effective way to quickly find the **``total number of missing values``** in the DataFrame, which is important for data cleaning and analysis.
# - **``df.isnull()``**: Creates a **``boolean DataFrame``** where **``each entry is True if the value is NaN``** and **``False otherwise``**.
# - **``.sum()``**: When called on a DataFrame, it **``sums up the True values (which are treated as 1) for each column``**, resulting in a Series where each entry represents the count of NaN values for that column.
# - **``Second .sum()``**: This sums the values in the Series from the previous step, giving the **``total count of NaN values``** across the entire DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code identifies missing values in our DataFrame. It returns a ``DataFrame`` of the ``same shape as df``, with ``boolean values indicating whether each entry is missing``:**

# %%
# Check for null values in the 'salary' column

df["salary"].isnull()
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# Name: salary, dtype: bool

# %% [markdown]
# - **``True Values``**: The output shows **``True``** for rows **``where the salary value is missing``** (e.g., NaN or None).
# - **``False Values``**: False indicates that the **``actual salary for that row is present``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code checks ``if there are any missing values (NaN)`` in the ``"salary"`` column of the DataFrame. It returns a ``boolean value``; **``True``** if there is ``at least one missing value`` and **``False``** if there are ``NO missing values``:**

# %%
# Check if there are any null values in the 'salary' column

df["salary"].isnull().any()
# Out:
# True

# %% [markdown]
# **``Explanation:``** Using ``df.salary.isnull().any()`` is a straightforward way to check for the presence of missing values specifically in the salary column, which can help you decide on further data cleaning or preprocessing steps.
# - **``df.salary.isnull()``**: This creates a ``boolean Series`` where each entry is **``True``** ``if the corresponding value in the ``"salary"`` column is NaN`` and **``False``** ``otherwise``.
# - **``.any()``**: This checks the boolean Series and returns **``True``** ``if any of the entries are True`` (i.e., if there is ``at least one NaN`` in the ``"salary"`` column).
#   - **``True Output``**: This indicates that there is **``at least one missing value``** in the salary column.
#   - **``False Output``**: If there were **``no missing values``**, it would return **``False``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code counts the ``number of missing values (NaN)`` in the ``"salary"`` column of the DataFrame. It returns an ``integer`` representing the ``total count of missing values`` in that ``specific column``:**

# %%
# Count the number of null values in the 'salary' column

df["salary"].isnull().sum()
# Out:
# 3

# %% [markdown]
# **``Explanation:``** Using ``df.salary.isnull().sum()`` is an effective way to quickly find out how many missing values are present in the salary column. The output will be an integer representing the total count of null values in the salary column.
# - **``df.salary.isnull()``**: This creates a ``boolean Series`` where ``each entry`` is **``True``** ``if the corresponding value in the salary column is NaN`` and **``False``** ``otherwise``.
# - **``.sum()``**: When called on a boolean Series, it ``counts the number of True values`` (which represent the NaN entries), giving you the ``total count of missing values``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code calculates the ``percentage of missing values`` (NaN) in each column of the DataFrame. This is useful for understanding the extent of missing data in your dataset:**

# %%
# Calculate the percentage of missing values for each column

df.isnull().sum()/len(df)*100
# Out:
# id         0.000000
# gender     0.000000
# status     9.090909
# dept      18.181818
# var1       0.000000
# var2      27.272727
# salary    27.272727
# dtype: float64

# %% [markdown]
# - **``df.isnull().sum()``**: This combination counts the ``number of missing values`` (NaN) in ``each column``.
# - **``len(df)``**: This gives the ``total number of rows`` in the DataFrame.
# - **``Division and multiplication``**: Dividing the count of missing values by the total number of rows gives the ``proportion of missing values``, which is then multiplied by 100 to convert it into a percentage.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``filters the DataFrame`` and returns ``only the rows`` that contain ``at least one missing value`` (NaN). This is useful for identifying and examining incomplete records in your dataset:**

# %%
# Filter the DataFrame to show only rows with at least one null value

df[df.isnull().any(axis=1)]
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 8   P009      M     PT   NaN   14   3.0     60
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# - **``Explanation:``** Using ``df[df.isnull().any(axis=1)]`` is an effective way to identify and analyze rows with missing data in your DataFrame.
# - **``Filtered Rows``**: The output contains only those rows from the DataFrame that have at least one missing value in any column.
# - **``Use Case``**: This is useful for identifying and examining rows with missing data, which can help in deciding how to handle those missing values.
#
#   - **``df.isnull()``**: This creates a ``boolean DataFrame`` indicating where the values are NaN.
#   - **``.any(axis=1)``**: This ``checks each row`` for ``any True values``, returning ``a Series of boolean`` values where **``True``** indicates that the ``row contains at least one missing value``.
#   - **``df[...]``**: This uses boolean indexing to filter the DataFrame, ``returning only the rows that meet the condition``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``filter the DataFrame`` and returns ``only the rows that do NOT contain any missing values`` (NaN). The ``tilde (~)`` operator ``negates the boolean values``, allowing you to select complete records:**

# %%
# Filter the DataFrame to show only rows without any null values using "~"

df[~df.isnull().any(axis = 1)]
# Out:
#      id gender status dept var1  var2 salary
# 2  P003      M      -  AWS    5   5.0     59
# 3  P004      F     FT  AWS  nan   8.0    120
# 4  P005      M     PT   DS    7  11.0     58
# 7  P008      F      -   FS   10   2.0    136
# 9  P010      F     FT   DS    -   7.0    125

# %% [markdown]
# **``Explanation:``** Using ``df[~df.isnull().any(axis=1)]`` is an effective way to identify and work with complete records in your DataFrame.
# - **``df.isnull()``**: This creates a ``boolean DataFrame`` indicating ``where the values are NaN``.
# - **``.any(axis=1)``**: This checks ``each row`` for ``any True values``, returning ``a Series of boolean`` values where **``True``** indicates that the ``row`` contains ``at least one missing value``.
# - **``~ (tilde operator)``**: This ``negates the boolean Series``, so ``True becomes False`` and ``vice versa``.
# - **``df[...]``**: This uses boolean indexing to ``filter the DataFrame``, returning only the rows that do NOT have any missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:120%; text-align:left;"><strong>🚨📢🤔📝 BE ALWAYS CAUTIOUS THAT: <span style="color:blue;"> There have been string "nan" and "-" values in some columns whose data type is supposed to be integer and string. BUT they do NOT look like as usual "NaN" in the DataFrame.</strong></p>
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>isnull().all() & df[] vs loc[]:</strong></p>
#
# **The following code ``filters the DataFrame`` and returns ``only the rows`` where ``all values are missing (NaN)``. This can be useful for identifying completely empty records in your dataset:**

# %%
# Let's remember our DataFrame

df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
# Filter the DataFrame to show only rows where all values are null

df.loc[df.isnull().all(axis=1)]

# df[df.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, gender, status, dept, var1, var2, salary]
# Index: []

# %% [markdown]
# ``The output returns an empty DataFrame since each row has at least one missingvalue.``
#
# **``Explanation:``** Using ``df.loc[df.isnull().all(axis=1)]`` is a way to identify and work with rows where all the data is missing.
# - **``df.isnull()``**: This creates a ``boolean DataFrame`` indicating ``where the values are NaN``.
# - **``.all(axis=1)``**: This checks ``each row`` for ``all values`` being ``True``, returning ``a Series of boolean`` values where **``True``** indicates that ``all entries in that row are NaN``.
# - **``df.loc[...]``**: This uses the boolean Series to ``filter the DataFrame``, returning only the rows that have all missing values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code ``filters the DataFrame`` and returns ``only the row``s where the ``"salary"`` column contains ``missing values (NaN)``:**

# %%
# Filter rows where the "salary" column is null
df.loc[df["salary"].isnull()]

# df[df.salary.isnull()]
# Out:
#       id gender status dept var1  var2 salary
# 0   P001      M     FT   DS    2   8.0    NaN
# 6   P007      M     FT   FS  nan   NaN   None
# 10  P011      M    NaN  AWS    6   9.0    NaN

# %% [markdown]
# - **``df.salary.isnull()``**: This creates a ``boolean Series`` where`` each entry`` is **``True``** ``if the corresponding value in the "salary" column is NaN``, and **``False``** ``otherwise``.
# - **``df.loc[...]``**: This uses the ``boolean Series`` to ``filter the DataFrame``, returning only the rows where the condition is True (i.e., where the salary is missing).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Converting Inappropriate Values to NaN Values</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - **[pd.to_numeric()](https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html)**
# - **[Series.map()](https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html0)**
# - **[pd.DataFrame.replace()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html)**

# %%
# Let's remember our DataFrame

df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>a. The first approach to convert inappropriate values:</strong></p>
#
# - **The following approach using ``pd.to_numeric(df['var1'], errors='coerce')`` is an effective method for converting inappropriate values in a DataFrame column to NaN.**

# %%
# Convert 'var1' to numeric, coercing errors to NaN

pd.to_numeric(df['var1'], errors='coerce')
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# The key here is the **``errors='coerce'``** parameter of to_numeric.
#
# - 📌 The **``errors='coerce'``** parameter specifies that ``any value that CANNOT be converted to a numeric type (such as strings like "-" or NaN) should be replaced with NaN`` instead of raising an error.
#
#
# Per **🧐 [the Documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html)** it will replace any value which cannot be converted with **``NaN``**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>b. The second approach to convert inappropriate values:</strong></p>
#
# **The following expression ``df["var1"].map({"-": np.nan})`` is a way to replace specific values in the ``var1`` column of DataFrame ``with NaN``. Here’s how it works:**

# %%
# Replace "-" with NaN in the 'var1' column

df["var1"].map({"-": np.nan})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: var1, dtype: float64

# %% [markdown]
# 📢❗🚨🔥 **Important Note:** When **``arg``** parameter is a dictionary, values in Series that are **NOT** in the dictionary (as keys) are **``converted to NaN``**. However, if the dictionary is a dict subclass that defines __missing__ (i.e. provides a method for default values), then this default is used rather than NaN.
#
# While using **``map()``** is effective for replacing specific values, it **``may NOT be as efficient as replace()``** method for **``multiple replacements``** or for more general cases. For broader cleaning tasks, consider using ``replace()`` which can handle multiple replacements at once.
#
# [SOURCE](https://www.w3resource.com/pandas/series/series-map.php#:~:text=The%20map()%20function%20is,a%20dict%20or%20a%20Series.&text=Mapping%20correspondence.&text=If%20'ignore'%2C%20propagate%20NaN,them%20to%20the%20mapping%20correspondence.).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:120%; text-align:left;"><strong>🚨📢🤔📝 BE ALWAYS CAUTIOUS THAT: <span style="color:blue;"> other values should remain unchanged while using map() function directly.</strong></p>
#
# - When **``arg``** parameter is a dictionary, values in Series that are NOT in the dictionary (as keys) are converted to NaN. However, if the dictionary is a dict subclass that defines __missing__ (i.e. provides a method for default values), then this default is used rather than NaN [SOURCE](https://www.w3resource.com/pandas/series/series-map.php#:~:text=The%20map()%20function%20is,a%20dict%20or%20a%20Series.&text=Mapping%20correspondence.&text=If%20'ignore'%2C%20propagate%20NaN,them%20to%20the%20mapping%20correspondence.).
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:120%; text-align:left;"><strong>c. The third approach to convert inappropriate values:</strong></p>
#
# **The following expression ``df["var1"].replace(to_replace="-", value=np.nan)`` is a straightforward way to replace specific values in a pandas DataFrame column with NaN. Here’s how this works:**
#   - After running the code, the ``var1`` column in the DataFrame will have ``NaN`` in place of any occurrences of ``"-"``, while all other numeric values remain intact. This method is particularly useful for cleaning data before further analysis, as it ``ensures that non-numeric placeholders are properly handled as missing values``.

# %%
# Replace "-" with NaN in the 'var1' column

df["var1"].replace(to_replace="-", value=np.nan)
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %% [markdown]
# - **``Function Purpose:``**
#   - **``The replace()``** method in pandas is used to replace specified values in a DataFrame or Series with new values. It’s versatile and can handle single values, lists, or dictionaries for replacements.
# - **``Parameters:``**
#   - **``to_replace="-"``** specifies the value you want to replace, which in this case is the string "-".
#   - **``value=np.nan``** indicates that the specified value should be replaced with NaN.
# - **``Resulting Series:``**
#   - The result of this operation is a new Series where all occurrences of "-" are replaced with NaN, while all other values remain unchanged.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``df["var1"].replace("-", np.nan).astype("float")`` combines two operations to clean and convert the data in the ``var1`` column of the the DataFrame. Here's how it works:**
#
#   - After executing the code, the ``var1`` column will have ``NaN`` in place of ``"-"``, and ``all values will be converted to float``:

# %%
# Replace "-" with NaN and convert the column to float

df["var1"].replace("-", np.nan).astype("float")
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``Replace Operation:``**
#   - **``df["var1"].replace("-", np.nan)``**: This part replaces all occurrences of the string ``"-"`` in the ``var1`` column with ``NaN``.
#   - This is useful for cleaning the data, as "-" often indicates missing or invalid data.
# - **``Type Conversion:``**
#   - **``.astype("float")``**: After replacing ``"-"`` with ``NaN``, this method converts the entire Series to a ``float type``.
#   - This is ``necessary`` because the ``presence of NaN`` (which is a float in pandas) means that the ``entire column should be treated as float`` rather than integer or object.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# There is still NO CHANGE in the original "var1" column

df.var1
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The cleaned and converted Series is then reassigned to the original ``var1`` column in the DataFrame, updating it in place.**

# %%
# Replace "-" with NaN, convert to float, and reassign it to the orginal
df["var1"] = df["var1"].replace("-", np.nan).astype("float")

# Display the modified Series
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **Let's do the same conversion for the elements in the ``"status"`` column:**

# %%
# Let's convert the "-" values in the "status" column to "NaN", and reassign it to the orginal
df["status"] = df["status"].replace("-", np.nan)

# Display the modified Series
df["status"]
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %% [markdown]
# - This code effectively cleans the status column by removing the placeholder ``("-")`` and replacing it with ``NaN``. This process is crucial for maintaining ``data integrity`` and ensuring that subsequent analyses can be accurately performed on the dataset.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Let's look at how our DatFrame look like now.

# Display the modified DataFrame
display(df)

# Display the summary of DataFrame
df.info()
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  8 non-null      object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
# ...

# %% [markdown]
# - 🥳👏 Now the columns **``status``**, **``dept``**, **``var1``**, **``var2``**, and **``salary``** have missing values in an appropriate form (indicated by the non-null counts). This suggests that you can go further for data cleaning or imputation process, especially if you plan to perform analyses that require complete cases.
#
# - **``Data Types:``**
#   - The **``var1``** and **``var2``** columns are stored as ``float64``, which is appropriate for numeric values. **``However``**, the **``salary``** column is ``still of type object``, which may require conversion to a numeric type (e.g., float) for analysis.
#     - If necessary, convert the ``salary`` column to a numeric type using ``pd.to_numeric()``, similar to how you handled ``var1``.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [raw]
# The DataFrame structure at the beginning
#
#        ['id',  'gender', 'status', 'dept', 'var1', 'var2', 'salary]
#  0	    P001	   M    	FT  	DS  	2        8.0     NaN
#  1   	P002       F    	PT  	FS  	3        NaN  	 54
#  2	    P003       M    	-   	AWS  	5        5.0  	 59
#  3	    P004	   F    	FT   	AWS  	nan      8.0  	 120
#  4	    P005	   M    	PT  	DS  	7        11.0  	 58
#  5  	P006	   F    	PT  	None  	1        NaN  	 75
#  6	    P007	   M    	FT  	FS  	nan      NaN  	 None
#  7  	P008	   F    	-   	FS  	10       2.0  	 136
#  8  	P009	   M    	PT  	NaN  	14       3.0  	 60
#  9  	P010	   F    	FT  	DS  	-        7.0  	 125
#  10 	P011	   M    	NaN  	AWS  	6        9.0  	 NaN

# %% [markdown]
# Everythings look like great with respect to inappropriate values. Before going further for applying handling methods for miising values, the categorical values in ``"gender"`` feature ``can be converted into numerical`` ones using ``map()`` method rather than ``replace()`` method; nevertheless, it's up to you since you can come over this kind of issue later by applying various methods as well, such as **``get_dummies()``**, ``OneHot Encoding`` and ``Label Encoding`` techniques.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``df["gender"].map({"M": 1, "F": 0})`` is used to convert the categorical values in the ``gender`` column of the DataFrame to numeric values:**

# %%
# Map 'M' to 1 and 'F' to 0
df["gender"].map({"M": 1, "F": 0})

#df["gender"].replace({"M" : 1, "F" : 0})
#df["gender"].replace(["M", "F"], [1, 0])
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# Name: gender, dtype: int64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Display the "gender" feature to see NO CHANGE in the orginal column

df.gender
# Out:
# 0     M
# 1     F
# 2     M
# 3     F
# 4     M
# 5     F
# 6     M
# 7     F
# 8     M
# 9     F
# 10    M
# Name: gender, dtype: object

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# After handling inapropriate values in the the DataFrame, let's look at how it looks like now:

# Display the DataFrame
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Display the info about DataFrame
display(df.info())

# Check the number of missing values for each column
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  8 non-null      object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 748.0+ bytes
# None
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# - **``DataFrame Structure``**: The **``info()``** output gives you a **``quick overview of the DataFrame``**, showing **``which columns contain missing values``** and **``their data types``**.
# - **``Missing Values``**: The **``isnull().sum()``** output identifies **``which columns have missing data``** and **``how much``**. This is crucial for deciding how to handle these missing values (e.g., imputation, removal).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#E51A59; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Missing Value Handling Methods</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#  1. <b>Deleting (Dropping) Rows</b> ----->if it has more than 70-75% of missing values
#
#  2. <b>Replacing (Filling) With Mean/Median/Mode (Imputation)</b>--->can be applied on a feature which has numeric data
#
#  3. <b> Assigning An Unique Category</b>--->If a categorical feature has definite number of classes, we can assign another class
#
#  4. <b>Predicting The Missing Values</b>---> we can predict the nulls with the help of a machine learning algorithm like linear regression
#
#  5. <b>Using Algorithms Which Support Missing Values</b>--->KNN is a machine learning algorithm which works on the principle of distance measure.  This algorithm can be used when there are nulls present in the dataset.  KNN considers the missing values by taking the majority of the K nearest values

# %% [markdown]
# ## <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>1 - Dropping:</strong></p>
#
#  - **[pandas.Series.dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dropna.html)**
#  - **[pandas.Series.drop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.drop.html)**

# %%
# Let's remember our DataFrame

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# **The following method ``df.dropna(axis=0, how="any", inplace=False)`` is used to handle missing values by removing them from the DataFrame.**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
# it removes the rows which contains any (at least one missing value) missing value

df.dropna(axis=0, how="any", inplace=False)
# Out:
#      id gender status dept  var1  var2 salary
# 4  P005      M     PT   DS   7.0  11.0     58

# %% [markdown]
# - **``📌 axis=0``**: This specifies that you want to drop rows (the ``default is 0``, which refers to ``rows``). If set to ``1``, it would ``drop columns`` instead.
# - **``📌 how="any"``**: This means that if ``any of the values`` in a row are ``NaN``, that ``entire row will be dropped``.
#   - If you set **``how="all"``**, it would ``drop the row only if all values are NaN``.
# - **``inplace=False``**: This indicates that the operation should NOT modify the original DataFrame. Instead, it returns a new DataFrame with the missing values removed.
#   - If you set **``inplace=True``**, the original DataFrame would be modified directly.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:120%; text-align:left;"><strong>🚨📢🤔📝 BE ALWAYS CAUTIOUS THAT: <span style="color:blue;"> dropping rows can lead to ``loss of potentially valuable data``. It's often a good idea to ``first analyze the extent of missing values`` and consider other strategies (like imputation) if a significant portion of your data is missing.</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression removes rows from the DataFrame that contain any missing values (null values) (at least one missing value).**

# %%
# Drop rows with any (at least one missing value) missing values

df.dropna(axis=1, how="any", inplace=False)
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %% [markdown]
# - **``df.dropna()``**: This method is used to drop missing values from a DataFrame.
# - **``axis=0``**: This specifies that the operation should be applied to rows. If set to 1, it would apply to columns.
# - **``how="any"``** This parameter specifies the condition for dropping:
#   - **``how="any"``** means that if any value in the row is null, the entire row will be dropped.
#   - If set to **``how="all"``**, it would drop the row only if all values in that row are null.
# - **``inplace=False``**: This means that the operation will not modify the original DataFrame. Instead, it will return a new DataFrame with the rows dropped. If set to True, the original DataFrame would be modified in place.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression removes rows from the DataFrame where all values are missing (null values).**

# %%
# Drop columns where "all values are NaN"

df.dropna(axis=1, how="all", inplace=False)
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# - **``df.dropna()``**: This method is used to drop missing values from a DataFrame.
# - **``axis=1``**: This specifies that the operation should be applied to columns. If set to 0, it would apply to rows.
# - **``how="all"``**: This parameter specifies the condition for dropping:
#   - **``how="all"``** means that if all values in the column are null, that entire column will be dropped.
#   - If set to **``how="any"``**, it would drop the column if any value in that column is null.
# - **``inplace=False``**: This means that the operation will not modify the original DataFrame. Instead, it will return a new DataFrame with the specified columns dropped. If set to True, the original DataFrame would be modified in place.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:120%; text-align:left;"><strong>📢✍🏼📝 REMINDER:</strong></p>
#
# - 👉 **[any](https://docs.python.org/3/library/functions.html#any)** : If **``any NA``** values are present, drop that row or column.
# - 👉 **[all](https://docs.python.org/3/library/functions.html#all)** : If **``all values``** are **``NA``**, drop that row or column
#
# **🧐 [Pandas dropna() - Drop Null/NA Values from DataFrame](https://www.journaldev.com/33492/pandas-dropna-drop-null-na-values-from-dataframe)**
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``adds a new column`` named ``delete_me`` to the DataFrame, initializing all its values to NaN (Not a Number).**

# %%
# let's create a column containing full of missing value.

# Add a new column 'delete_me' filled with NaN
df["delete_me"] = np.nan

# Display the modified DataFrame
df
# Out:
#       id gender status  dept  var1  var2 salary  delete_me
# 0   P001      M     FT    DS   2.0   8.0    NaN        NaN
# 1   P002      F     PT    FS   3.0   NaN     54        NaN
# 2   P003      M    NaN   AWS   5.0   5.0     59        NaN
# 3   P004      F     FT   AWS   NaN   8.0    120        NaN
# 4   P005      M     PT    DS   7.0  11.0     58        NaN
# 5   P006      F     PT  None   1.0   NaN     75        NaN
# 6   P007      M     FT    FS   NaN   NaN   None        NaN
# 7   P008      F    NaN    FS  10.0   2.0    136        NaN
# 8   P009      M     PT   NaN  14.0   3.0     60        NaN
# 9   P010      F     FT    DS   NaN   7.0    125        NaN
# 10  P011      M    NaN   AWS   6.0   9.0    NaN        NaN

# %% [markdown]
# - **``df["delete_me"]``**: This accesses or creates a new column named delete_me in the DataFrame df.
# - **``= np.nan``**: This sets all values in the new column to NaN. This is often used to signify missing or undefined data.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``removes columns from the DataFrame that contain only missing values (null values)``.**

# %%
# Drop columns where "all values are NaN"
df.dropna(axis=1, how="all", inplace=True)

# Display the modified DataFrame
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# - **``df.dropna()``**: This method is used to drop missing values from a DataFrame.
# - **``axis=1``**: This specifies that the operation should be applied to columns. If set to 0, it would apply to rows.
# - **``how="all"``**: This parameter specifies the condition for dropping:
#   - how="all" means that if all values in the column are null, that entire column will be dropped.
#   - If set to how="any", it would drop the column if any value in that column is null.
# - **``inplace=True``**: This means that the operation will modify the original DataFrame in place, removing the columns directly from df without creating a new DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following command ``drops columns`` from the DataFrame ``based on the number of non-missing values they contain``.**
#   - After executing the below code, the resulting DataFrame will retain only the columns that have at least 9 non-null entries:

# %%
# Keep only the columns with at least 9 non-NA values.

# Drop columns with less than 9 non-null values
df.dropna(axis=1, thresh=8, inplace=False)

# df.dropna(axis=1, how="any", thresh=9, inplace=False)  # TypeError: You cannot set both the how and thresh arguments at the same time.
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# - **``df.dropna()``**: This method is used to drop missing values from a DataFrame.
# - **``axis=1``**: This specifies that the operation should be applied to columns. If set to 0, it would apply to rows.
# - **``thresh=9``**: This parameter specifies the **``minimum number of non-null values required to keep a column``**. In this case, a column must have at least 9 non-null values to be retained.
# - **``inplace=False``**: This means that the operation will **``NOT modify the original DataFrame``**. Instead, it will return a new DataFrame with the specified columns dropped. If set to True, the original DataFrame would be modified in place.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:120%; text-align:left;"><strong>📢✍🏼📝 REMINDER:</strong></p>
#
# - 👉 **``thresh=N``** requires that a column has **``at least N number``** **non-NaNs to survive.** [Source](https://stackoverflow.com/questions/51584906/thresh-in-dropna-for-dataframe-in-pandas-in-python/51584935)

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression removes specific rows from the DataFrame based on their index labels ``[1, 3, 5]``.**

# %%
# Drop rows with index labels 1, 3, and 5

df.drop([1, 3, 5])
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# - **``df.drop()``**: This method is used to drop specified labels from rows or columns in a DataFrame.
# - **``[1, 3, 5]``**: This is a list of index labels for the rows you want to drop. In this case, rows with index 1, 3, and 5 will be removed.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``removes specific columns`` from the DataFrame.**

# %%
# df.drop(["var1", "var2"]) # gives an error

df.drop(["var1", "var2"], axis=1)
# Out:
#       id gender status  dept salary
# 0   P001      M     FT    DS    NaN
# 1   P002      F     PT    FS     54
# 2   P003      M    NaN   AWS     59
# 3   P004      F     FT   AWS    120
# 4   P005      M     PT    DS     58
# 5   P006      F     PT  None     75
# 6   P007      M     FT    FS   None
# 7   P008      F    NaN    FS    136
# 8   P009      M     PT   NaN     60
# 9   P010      F     FT    DS    125
# 10  P011      M    NaN   AWS    NaN

# %% [markdown]
# - **``df.drop()``**: This method is used to **``drop specified labels``** from rows or columns in a DataFrame.
# - **``["var1", "var2"]``**: This is a **``list of column labels we want to drop``**. In this case, the columns named **``var1``** and **``var2``** will be removed.
# - **``axis=1``**: This specifies that the **``operation``** should be ``**applied to columns``**. If set to 0, it would apply to rows.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``removes specific rows`` from the DataFrame based on their ``index labels [1, 3, 5]``.**

# %%
# Drop rows with index 1, 3, and 5

df.drop(index=[1, 3, 5])
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# - **``df.drop()``**: This method is used to **``drop specified labels``** from rows or columns in a DataFrame.
# - **``index=[1, 3, 5]``**: This specifies the **``index labels of the rows we want to drop``**. In this case, rows with index **``1``**, **``3``**, and **``5``** will be removed.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``removes specific columns`` from the DataFrame.**

# %%
# Drop columns 'id' and 'var1'

df.drop(columns=["id", "var1"])
# Out:
#    gender status  dept  var2 salary
# 0       M     FT    DS   8.0    NaN
# 1       F     PT    FS   NaN     54
# 2       M    NaN   AWS   5.0     59
# 3       F     FT   AWS   8.0    120
# 4       M     PT    DS  11.0     58
# 5       F     PT  None   NaN     75
# 6       M     FT    FS   NaN   None
# 7       F    NaN    FS   2.0    136
# 8       M     PT   NaN   3.0     60
# 9       F     FT    DS   7.0    125
# 10      M    NaN   AWS   9.0    NaN

# %% [markdown]
# - **``df.drop()``**: This method is used to **``drop specified labels``** from rows or columns in a DataFrame.
# - **``columns=["id", "var1"]``**: This specifies the **``columns we want to drop``**. In this case, the columns named **``id``** and **``var1``** will be removed.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ## <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:125%; text-align:left;"><strong>2 - Filling Missing Values (Imputation):</strong></p>
#
#
# Before going ahead with imputation, let us remember what is a missing value. a missing value is the part of the dataset that seems missing or is a null value, maybe due to some missing data during research or data collection.
#
# Having a missing value in a machine learning model which will be your next step in your journey after Data Analytics is considered very inefficient and hazardous because of the following reasons:
#
# - Reduces the efficiency of the ML model.
# - Affects the overall distribution of data values.
# - It leads to a biased effect in the estimation of the ML model.
#
# By imputation, we mean to replace the missing or null values with a particular value in the entire dataset. Imputation can be done using any of the following basic techniques. In sum, Imputation methods are those where the missing data are filled in to create a complete data matrix that can be analyzed using standard methods.
#
#  - **[pandas.DataFrame.fillna()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html)**
#  - **[pandas.DataFrame.where()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.where.html)**
#  - **[pandas.DataFrame.interpolate()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html)**

# %%
# Let's remember our DataFrame first:

# Display the original DataFrame
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#  ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>a. Filling with a specific value:</strong></p>
#
# **The following command ``fills missing values (NaN)`` in the DataFrame with a ``specific value``—in this case, ``0``.**

# %%
# Fill NaN values with 0

df.fillna(0)
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0       0
# 1   P002      F     PT   FS   3.0   0.0      54
# 2   P003      M      0  AWS   5.0   5.0      59
# 3   P004      F     FT  AWS   0.0   8.0     120
# 4   P005      M     PT   DS   7.0  11.0      58
# 5   P006      F     PT    0   1.0   0.0      75
# 6   P007      M     FT   FS   0.0   0.0       0
# 7   P008      F      0   FS  10.0   2.0     136
# 8   P009      M     PT    0  14.0   3.0      60
# 9   P010      F     FT   DS   0.0   7.0     125
# 10  P011      M      0  AWS   6.0   9.0       0

# %% [markdown]
# - **``df.fillna()``**: This method fills missing values in a DataFrame.
# - **``0``**: This specifies that **``all NaN values``** should be **``replaced with 0``**.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:green; font-size:120%; text-align:left;"><strong>📢✍🏼📝 REMINDER: <span style="color:blue;"> If we want to modify the original DataFrame in place (without creating a new DataFrame), we can use the inplace=True parameter.</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression is used to ``access`` the column ``named var1`` in the DataFrame.**

# %%
# Access the 'var1' column

df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``df["var1"]``**: This accesses the column labeled var1 in the DataFrame and returns it as a Pandas Series. We can use this expression to view, manipulate, or analyze the data in that specific column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:120%; text-align:left;"><strong>📢✍🏼📝 REMINDER: <span style="color:blue;"> If var1 does NOT exist in the DataFrame, you will receive a KeyError.</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The expression ``replaces all missing values (NaN)`` in the ``column var1`` of the DataFrame with ``0``.**

# %%
# Fill NaN values in 'var1' with 0

df["var1"].fillna(0)
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``df["var1"]``**: This accesses the column named var1 in the DataFrame df.
# - **``.fillna(0)``**: This method replaces all NaN values in the accessed Series (the var1 column) with 0.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:red; font-size:120%; text-align:left;"><strong>📢✍🏼📝 REMINDER: <span style="color:blue;"> The fillna method returns a new Series with the NaN values replaced; it does NOT modify the original DataFrame or Series unless we specify inplace=True.</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>b. Filling with any Proper Value:</strong></p>
#
# - Filling missing values with proper values can be done in several ways, depending on the context of your data and the analysis you want to perform. Here are some common methods to fill missing values in a pandas DataFrame with appropriate values:
#
#   - **``1. Filling with the Mean``**: You can fill missing values in a numerical column with the mean of that column. Good for numerical data when the distribution is not skewed (mean) or is skewed (median).
#   - **``2. Filling with the Median``**: Filling missing values with the median can be more robust, especially for skewed distributions. Good for numerical data when the distribution is not skewed (mean) or is skewed (median).
#   - **``3. Forward Fill (FFill)``**: This method fills missing values with the last valid observation. Useful in time series data where you want to carry forward the last observation.
#   - **``4. Backward Fill (BFill)``**: This method fills missing values with the next valid observation. Useful when the future value is a better estimate for the missing value.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:120%; text-align:left;"><strong>🚨📢🤔📝 BE ALWAYS CAUTIOUS THAT: <span style="color:blue;"> Choose the appropriate filling method based on the characteristics of your data and the analytical goals.</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the mean (average)`` of the values in the ``column var1`` of the DataFrame.**

# %%
# Calculate the mean of 'var1'

df["var1"].mean()
# Out:
# 6.0

# %% [markdown]
# - **``df["var1"]``**: This accesses the column named var1 in the DataFrame df.
# - **``.mean()``**: This method calculates the mean of the values in the Series. It automatically ignores any NaN (missing) values in the computation.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#FF0000; font-size:120%; text-align:left;"><strong>🚨📢🤔📝 Important Notes: <span style="color:blue;"></strong></p>
#
# - If the entire column consists of NaN values, the mean will return NaN.
# - We can also specify additional parameters in the mean() method, such as skipna, which is True by default (it skips NaN values).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``replaces missing values (NaN)`` in the ``column var1`` of the DataFrame with the mean of that column.**

# %%
# Fill NaN values in 'var1' with the mean of 'var1'

df["var1"].fillna(df["var1"].mean())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``df["var1"]``**: This accesses the var1 column in the DataFrame.
# - **``.mean()``**: This calculates the mean of the values in the var1 column, ignoring any NaN values.
# - **``.fillna(...)``**: This method replaces NaN values in the var1 column with the calculated mean.
#
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the median`` of the values in the ``column var1`` of the DataFrame.**

# %%
# Calculate the median of 'var1'

df["var1"].median()
# Out:
# 5.5

# %% [markdown]
# - **``df["var1"]``**: This **``accesses the var1 column``** in the DataFrame.
# - **``.median()``**: This method **``computes the median``** of the values in the Series.
#   - The median is the middle value when the data is sorted. If there is an even number of observations, it returns the average of the two middle values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``replaces missing values (NaN)`` in the ``column var1`` of the DataFrame with the ``median`` of that column.**

# %%
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
# Fill NaN values in 'var1' with the median of 'var1'

df["var1"].fillna(df["var1"].median())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.5
# 4      7.0
# 5      1.0
# 6      5.5
# 7     10.0
# 8     14.0
# 9      5.5
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``df["var1"]``**: This accesses the var1 column in the DataFrame.
# - **``.median()``**: This calculates the median of the values in the var1 column, ignoring any NaN values.
# - **``.fillna(...)``**: This method replaces NaN values in the var1 column with the calculated median.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``computes the mean (average)`` of ``all numeric columns`` in the DataFrame.**

# %%
# Calculate the mean of "all" numeric columns

df.mean(numeric_only=True)
# Out:
# var1    6.000
# var2    6.625
# dtype: float64

# %% [markdown]
# - **``df.mean()``**: This method calculates the mean of the DataFrame's columns.
# - **``numeric_only=True``**: This parameter ensures that only numeric columns are considered for the mean calculation. Non-numeric columns (like strings or objects) will be ignored.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``replaces missing values (NaN)`` in the DataFrame with the ``mean of each numeric column``.**

# %%
# Fill NaN values with the mean of numeric columns

df.fillna(df.mean(numeric_only=True))
# Out:
#       id gender status  dept  var1    var2 salary
# 0   P001      M     FT    DS   2.0   8.000    NaN
# 1   P002      F     PT    FS   3.0   6.625     54
# 2   P003      M    NaN   AWS   5.0   5.000     59
# 3   P004      F     FT   AWS   6.0   8.000    120
# 4   P005      M     PT    DS   7.0  11.000     58
# 5   P006      F     PT  None   1.0   6.625     75
# 6   P007      M     FT    FS   6.0   6.625   None
# 7   P008      F    NaN    FS  10.0   2.000    136
# 8   P009      M     PT   NaN  14.0   3.000     60
# 9   P010      F     FT    DS   6.0   7.000    125
# 10  P011      M    NaN   AWS   6.0   9.000    NaN

# %% [markdown]
# - **``df.mean(numeric_only=True)``**: This calculates the mean of all numeric columns in the DataFrame, ignoring non-numeric columns and NaN values.
# - **``.fillna(...)``**: This method replaces any NaN values in the DataFrame with the corresponding mean values calculated in the previous step.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``replaces missing values (NaN)`` in specific columns of the DataFrame with ``designated values``.**

# %%
# Fill NaN values based on specified conditions

df.fillna({
           "dept": "other",
           "var1": df.var1.mean(numeric_only=True),
           "var2": df.var2.median()
          })
# Out:
#       id gender status   dept  var1  var2 salary
# 0   P001      M     FT     DS   2.0   8.0    NaN
# 1   P002      F     PT     FS   3.0   7.5     54
# 2   P003      M    NaN    AWS   5.0   5.0     59
# 3   P004      F     FT    AWS   6.0   8.0    120
# 4   P005      M     PT     DS   7.0  11.0     58
# 5   P006      F     PT  other   1.0   7.5     75
# 6   P007      M     FT     FS   6.0   7.5   None
# 7   P008      F    NaN     FS  10.0   2.0    136
# 8   P009      M     PT  other  14.0   3.0     60
# 9   P010      F     FT     DS   6.0   7.0    125
# 10  P011      M    NaN    AWS   6.0   9.0    NaN

# %% [markdown]
# - **``fillna({...})``**: This method fills NaN values in the DataFrame with specified values from a dictionary.
# - **``"dept": "other"``**: This sets NaN values in the dept column to the string "other".
# - **``"var1"``**: df.var1.mean(numeric_only=True): This calculates the mean of the var1 column (ignoring NaN values) and uses it to fill NaN values in that column.
# - **``"var2"``**: df.var2.median(): This calculates the median of the var2 column (ignoring NaN values) and uses it to fill NaN values in that column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the mean of the numeric columns`` var1 and var2 in the DataFrame.**

# %%
df.mean(numeric_only=True)[["var1", "var2"]]
# Out:
# var1    6.000
# var2    6.625
# dtype: float64

# %% [markdown]
# - **``df.mean(numeric_only=True)``**: This calculates the mean of all numeric columns in the DataFrame, ignoring non-numeric columns and any NaN values.
# - **``[["var1", "var2"]]``**: This selects only the means of the specified columns var1 and var2 from the resulting Series.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``replaces missing values (NaN)`` in the DataFrame for the specific numeric columns var1 and var2 with their ``respective mean values``.**

# %%
# Fill NaN values in 'var1' and 'var2' with their means

df.fillna(df.mean(numeric_only=True)[["var1", "var2"]])
# Out:
#       id gender status  dept  var1    var2 salary
# 0   P001      M     FT    DS   2.0   8.000    NaN
# 1   P002      F     PT    FS   3.0   6.625     54
# 2   P003      M    NaN   AWS   5.0   5.000     59
# 3   P004      F     FT   AWS   6.0   8.000    120
# 4   P005      M     PT    DS   7.0  11.000     58
# 5   P006      F     PT  None   1.0   6.625     75
# 6   P007      M     FT    FS   6.0   6.625   None
# 7   P008      F    NaN    FS  10.0   2.000    136
# 8   P009      M     PT   NaN  14.0   3.000     60
# 9   P010      F     FT    DS   6.0   7.000    125
# 10  P011      M    NaN   AWS   6.0   9.000    NaN

# %% [markdown]
# - **``df.mean(numeric_only=True)``**: This computes the mean of all numeric columns in the DataFrame, ignoring non-numeric columns and NaN values.
# - **``[["var1", "var2"]]``**: This selects the means of the specified columns var1 and var2.
# - **``fillna(...)``**: This method replaces NaN values in the DataFrame with the calculated mean values for the respective columns.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# #### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>🔥 where() method replaces values where the condition is False. 🔥</strong></p>
#
#
# Pandas **``where()``** method is used to check a DataFrame for one or more condition and return the result accordingly. By default, it replaces the values of the rows where the condition evaluates to **``False``** with desired value. The **``where()``** method is the opposite of the The **``mask()``** method.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following expression ``creates a DataFrame`` that indicates`` whether each value in the original DataFrame is not a missing value (NaN)``.**

# %%
# Display DataFrame showing where values are NaN
display(df.isna())

# Display DataFrame showing where values are NOT NaN
df.notna()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False    True  False  False  False   False
# 3   False   False   False  False   True  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False   True   True    True
# 7   False   False    True  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False   True  False   False
# 10  False   False    True  False  False  False    True
#       id  gender  status   dept   var1   var2  salary
# 0   True    True    True   True   True   True   False
# 1   True    True    True   True   True  False    True
# 2   True    True   False   True   True   True    True
# 3   True    True    True   True  False   True    True
# ...

# %% [markdown]
# - **``isna()``** and **``notna()``** can be used to identify missing values in a DataFrame ``in different ways``.
#   - **``isna()``** Purpose: This method returns a DataFrame of the same shape as the original, where each cell contains ``True`` if the ``corresponding cell`` in the original DataFrame is ``NaN (missing)`` and ``False`` ``otherwise``.
#      - **``Output Explanation``**: The output DataFrame indicates the locations of missing values. For example:
#        - ``True`` indicates that the value is ``NaN``.
#        - ``False`` indicates that the value is ``not NaN``.
#   - **``notna() Purpose``**: This method returns a DataFrame of the same shape as the original, where each cell contains True if the corresponding cell in the original DataFrame is not NaN (i.e., it contains a valid value) and False if it is NaN.
#      - **``Output Explanation``**: The output DataFrame indicates the locations of non-missing values. For example:
#        - ``True`` indicates that the value is present (``not NaN``).
#        - ``False`` indicates that the value is ``NaN``.
#
# <img src=https://i.ibb.co/PgcgQ2F/isna-vs-notna.png width="500" height="200">
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``replaces NaN values`` in the DataFrame with the ``mean of each numeric column``, while keeping non-NaN values unchanged.**

# %%
# df.where(pd.notna(df), df.mean(numeric_only=True), axis="columns")

df.where(cond=df.notna(), other=df.mean(numeric_only=True), axis = 1)
# Out:
#       id gender status dept  var1    var2 salary
# 0   P001      M     FT   DS   2.0   8.000    NaN
# 1   P002      F     PT   FS   3.0   6.625     54
# 2   P003      M    NaN  AWS   5.0   5.000     59
# 3   P004      F     FT  AWS   6.0   8.000    120
# 4   P005      M     PT   DS   7.0  11.000     58
# 5   P006      F     PT  NaN   1.0   6.625     75
# 6   P007      M     FT   FS   6.0   6.625    NaN
# 7   P008      F    NaN   FS  10.0   2.000    136
# 8   P009      M     PT  NaN  14.0   3.000     60
# 9   P010      F     FT   DS   6.0   7.000    125
# 10  P011      M    NaN  AWS   6.0   9.000    NaN

# %% [markdown]
# - **``df.notna()``**: This creates a boolean DataFrame indicating which values in df are not NaN (True for non-NaN values).
# - **``df.mean(numeric_only=True)``**: This calculates the mean of all numeric columns in the DataFrame, ignoring any NaN values.
# - **``df.where(...)``**: This method replaces values in df based on the condition.
# - **``cond``**: If the condition is True (i.e., the value is not NaN), it keeps the original value.
# - **``other``**: If the condition is False (i.e., the value is NaN), it replaces it with the mean of the corresponding column.
# - **``axis=1``**: This specifies that the operation should be applied across columns (for each row).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Let us remember our DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 Fill ``NaN`` values using an ``interpolation`` method.</strong></p>
#
# - **[interpolate()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html)** function in Pandas is basically used to fill NA values in the dataframe or series by generating points between given points. Therefore, this is a very powerful function to fill the missing values. It uses various interpolation techniques to fill the missing values rather than hard-coding the value.
#
# **🧐 [How do pandas interpolate missing values?](https://note.nkmk.me/en/python-pandas-interpolate/)**
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following expression ``fills missing values (NaN)`` in the DataFrame by estimating them based on surrounding values.**
# - This method performs **``linear interpolation by default``**, but it can also be configured to use different methods.

# %%
# Interpolate to fill NaN values

df.interpolate()
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   6.5     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   6.0   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   8.0     75
# 6   P007      M     FT    FS   5.5   5.0   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS  10.0   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 Let's see the effect of parameters on a simple series:</strong></p>

# %%
# Create the Series with None values
s = pd.Series([None, 54.0, 59.0, 120.0, 58.0, 75.0, None, 136.0, 60.0, 125.0, None])

# Display the Series
s
# Out:
# 0       NaN
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6       NaN
# 7     136.0
# 8      60.0
# 9     125.0
# 10      NaN
# dtype: float64

# %% [markdown]
# - **``Creating the Series``**: The Series s is created with some None values.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the Pandas Series s using interpolation, but it applies a restriction on where the interpolation can occur. Specifically, it will only interpolate NaN values that are surrounded by non-NaN values on both sides.**

# %%
# Interpolate missing values with limit_area set to "inside"

s.interpolate(limit_area="inside")
# Out:
# 0       NaN
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6     105.5
# 7     136.0
# 8      60.0
# 9     125.0
# 10      NaN
# dtype: float64

# %% [markdown]
# - **``s.interpolate()``**: This method fills NaN values by estimating them based on surrounding values.
# - **``limit_area="inside"``**: This parameter restricts the interpolation to only those NaN values that are between non-NaN values. NaNs at the start or end of the Series will not be interpolated.
#
#   - In this example, the interpolation fills the NaN value at index 6, which is between the non-NaN values at indices 5 and 7. However, the NaNs at the start (index 0) and end (index 10) remain unchanged because they do not have non-NaN neighbors on both sides.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the Pandas Series ``s`` using interpolation, but it allows for interpolation beyond the boundaries of non-NaN values.**
# - Specifically, it will fill NaN values at the beginning and end of the Series if there are valid values in the opposite direction.

# %%
# Interpolate missing values with limit_area set to "outside"

s.interpolate(limit_area="outside")
# Out:
# 0       NaN
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6       NaN
# 7     136.0
# 8      60.0
# 9     125.0
# 10    125.0
# dtype: float64

# %% [markdown]
# - **``s.interpolate()``**: This method fills NaN values by estimating them based on surrounding values.
# - **``limit_area="outside"``**: This parameter allows interpolation to fill NaN values at the start and end of the Series, extending the interpolation beyond the immediate non-NaN neighbors.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
#
# - The NaN at index 0 is filled with the first valid value (54.0).
# - The NaN at index 6 is filled based on the surrounding values, extending the interpolation from the non-NaN values at indices 5 and 7.
# - The NaN at index 10 is filled with the last valid value (125.0).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the Pandas Series ``s`` using ``backward interpolation``, while also allowing interpolation beyond the boundaries of non-NaN values.**

# %%
s.interpolate(limit_direction="backward", limit_area="outside")
# Out:
# 0      54.0
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6       NaN
# 7     136.0
# 8      60.0
# 9     125.0
# 10      NaN
# dtype: float64

# %% [markdown]
# - **``s.interpolate()``**: This method fills NaN values by estimating them based on surrounding values.
# - **``limit_direction="backward"``**: This specifies that the interpolation should look for valid values only in the backward direction (i.e., toward the start of the Series).
# - **``limit_area="outside"``**: This allows interpolation to fill NaN values at the beginning and end of the Series, extending the interpolation beyond the immediate non-NaN neighbors.
#
# In this example:
#
# - The NaN at index 0 is filled with the first valid value found when looking backward (54.0).
# - The NaN at index 6 is filled with the last valid value before it (75.0).
# - The NaN at index 10 is filled with the last valid value in the Series (125.0).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``chains multiple interpolation methods`` to ``fill missing values (NaN)`` in the Pandas Series ``s``.**
# - Each method addresses NaN values in different ways, progressively filling in missing data.

# %%
# Chain multiple interpolations

result = (
          s.interpolate(limit_area="inside")
          .interpolate(limit_area="outside")
          .interpolate(limit_direction="backward", limit_area="outside")
         )

# or:
# s.interpolate(limit_direction='both')

# %%
result
# Out:
# 0      54.0
# 1      54.0
# 2      59.0
# 3     120.0
# 4      58.0
# 5      75.0
# 6     105.5
# 7     136.0
# 8      60.0
# 9     125.0
# 10    125.0
# dtype: float64

# %% [markdown]
# - **``s.interpolate(limit_area="inside"):``**
#   - This fills NaN values that are between non-NaN values, meaning it only interpolates NaN values that have non-NaN neighbors on both sides.
# - **``.interpolate(limit_area="outside"):``**
#   - This extends the previous interpolation by allowing it to fill NaN values at the beginning and end of the Series, using available values from within the Series.
# - **``.interpolate(limit_direction="backward", limit_area="outside"):``**
#   - This final step looks for valid values in the backward direction to fill NaN values, including those at the edges of the Series. It fills NaN values at the start and end of the Series using the last known values.
#
# For more information about [interpolation](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/)
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>c. Filling the Missing Values of Categorical Variables:</strong></p>
#
#
# - To fill missing values in categorical variables, such as the ``"dept"`` column in the DataFrame, you can use the ``mode`` (the most frequent value) of that column. Let's examine the concept along with examples:

# %%
# Let us remember our DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the mode`` of the values in the ``dept column`` of the DataFrame.**
# - The mode is the value that appears most frequently in a dataset.

# %%
# Calculate the mode of the 'dept' column

df["dept"].mode()
# Out:
# 0    AWS
# 1     DS
# 2     FS
# Name: dept, dtype: object

# %% [markdown]
# - **``df["dept"]``**: This accesses the dept column in the DataFrame.
# - **``.mode()``**: This method returns the mode(s) of the column. If there are multiple modes (i.e., multiple values occur with the same highest frequency), it will return all of them.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``retrieves the most frequently occurring value (mode)`` from the ``dept column`` of the DataFrame.**

# %%
# Get the most frequent value (mode) of the 'dept' column

df["dept"].mode()[0]
# Out:
# 'AWS'

# %% [markdown]
# - **``df["dept"]``**: This accesses the dept column in the DataFrame.
# - **``.mode()``**: This method calculates the mode(s) of the column and returns a Series of the most frequent values.
# - **``[0]``**: This retrieves the first mode from the Series. If there are multiple modes, it will return the first one.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# ### 📢❗🚨🔥 **``Important Note``**: When you have ``more than one mode`` in a dataset (i.e., a multimodal distribution), it can complicate the process of filling missing values for categorical variables. Here are some considerations and potential approaches:
#
# - **``Issues with Multiple Modes:``**
#   - **``Ambiguity``**: If there are multiple modes, choosing one to fill missing values may NOT represent the data accurately, as each mode may reflect different categories that are equally common.
#   - **``Loss of Information``**: By selecting only one mode, you might lose important information about the distribution of categories in your dataset.
# - **``Strategies to Handle Multiple Modes:``**
#   - **``Random Selection:``**
#     - If there are multiple modes, you can ``randomly select one`` of the modes to fill the missing values. This introduces some variability but can be a reasonable approach if all modes are equally valid.
#
#   - **``Fill with All Modes:``**
#     - Instead of replacing missing values with a single mode, you could ``create a new category`` like "Other" or "Multiple Modes" to indicate that there were multiple common categories. This preserves the information about the modes.
#
#   - **``Use Frequency Distribution:``**
#     - Analyze the frequency of each mode and decide to fill missing values with the mode that has the highest frequency. If all modes have the same frequency, you can choose any one of them or use random selection.
#   - **``Consider Domain Knowledge:``**
#     - Use your understanding of the data context to decide which mode makes the most sense to use for filling in missing values.
#
#   - 📌 **``Using Grouping to Fill Missing Values:``** selecting the mode based on grouping by other features is indeed a highly effective strategy for filling missing values in categorical variables. This approach leverages relationships in the data, allowing for a more context-aware imputation.
#     - **``Group by Other Features``**: You can group the DataFrame by one or more relevant features and then calculate the mode for each group. This allows you to fill missing values in a way that respects the structure of your data.
#     - **``Impute Missing Values``**: Fill the missing values in the categorical variable with the mode of the relevant group.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
#
# **The following expression ``fills missing values (NaN)`` in the ``dept column`` of the DataFrame with the ``most frequently occurring value (mode)`` from that column.**

# %%
df["dept"]
# Out:
# 0       DS
# 1       FS
# 2      AWS
# 3      AWS
# 4       DS
# 5     None
# 6       FS
# 7       FS
# 8      NaN
# 9       DS
# 10     AWS
# Name: dept, dtype: object

# %%
# Fill NaN values in the 'dept' column with the mode

df["dept"].fillna(df["dept"].mode()[0])
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %% [markdown]
# - **``df["dept"].mode()[0]``**: This retrieves the most common value (mode) from the dept column. If there are multiple modes, it selects the first one.
# - **``.fillna(...)``**: This method replaces NaN values in the dept column with the specified value, which in this case is the mode of the column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the ``dept column`` of the DataFrame using ``backward filling (backward propagation)``.**

# %%
# Fill NaN values in the 'dept' column using backward fill

df["dept"].fillna(method="bfill")
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      FS
# 6      FS
# 7      FS
# 8      DS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %% [markdown]
# - **``method="bfill"``**: This parameter specifies that the missing values should be filled with the next valid observation (i.e., the next non-NaN value found below the missing value in the column).
# - **``.fillna(...)``**: This method replaces NaN values in the column based on the specified filling method.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The NaN values in the dept column are filled with the next available non-NaN value found below them.
# - The backward fill (bfill) effectively "propagates" the next valid value upward to fill in the gaps.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the ``status column`` of the DataFrame using ``forward filling (forward propagation)``.**

# %%
# Fill NaN values in the 'status' column using forward fill

df["status"].fillna(method="ffill")
# Out:
# 0     FT
# 1     PT
# 2     PT
# 3     FT
# 4     PT
# 5     PT
# 6     FT
# 7     FT
# 8     PT
# 9     FT
# 10    FT
# Name: status, dtype: object

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The NaN values in the status column are filled with the most recent valid value found above them.
# - The forward fill (ffill) effectively "propagates" the last valid value downward to fill in the gaps.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#008000; font-size:125%; text-align:left;"><strong>REMINDER:</strong></p>
#
#
# - **pad / ffill:** propagate last valid observation forward to next valid
# - **backfill / bfill:** use next valid observation to fill gap.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>🏆 d. Filling by condition & by Group of the Categorical Variables:</strong></p>
#
#
# When dealing with missing values in categorical variables, especially in a DataFrame with multiple features, it's ``often effective`` to fill these missing values based on specific conditions related to other variables. Here’s a brief explanation of the approach:
#
# - **``📌 Contextual Filling``**: Instead of filling missing values indiscriminately, this method uses context from related   features (like numerical variables) to make informed decisions on how to fill missing values.
# - **``📌 Forward Fill``**: Initially, you can use forward filling (ffill) to propagate the last known valid observation in the categorical variable. This ensures that immediate gaps are filled with the most recent information.
# - **``📌 Group by Conditions``**: This method ensures that the filled values are more representative of the data, leading to better data quality for analysis. It maintains the relationships between categorical and numerical variables, which can be crucial for subsequent modeling or analysis.
#   - **``Categorization``**: Split the data into groups based on conditions related to other variables (e.g., salary thresholds).
#   - **``Filling Strategy``**: For each group, determine the most frequent category (mode) and use it to fill missing values in the categorical variable. This respects the context of the data, as it uses the most common value relevant to that specific group.

# %%
# Let us remember our DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the ``dept column`` of the DataFrame using ``forward filling (forward propagation)``, and it modifies the original DataFrame directly.**

# %%
# Fill NaN values in the 'dept' column using "forward fill" and modify the original DataFrame
df["dept"].fillna(method="ffill", inplace=True)

# Display the updated DataFrame
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# - **``method="ffill"``**: This parameter specifies that the missing values should be filled with the last valid observation (i.e., the last non-NaN value found above the missing value in the column).
# - **``inplace=True``**: This argument indicates that the operation should modify the original DataFrame directly instead of returning a new DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The NaN values in the dept column are filled with the most recent valid value found above them using forward fill (ffill).
# - The inplace=True argument ensures that the changes are made directly to the original DataFrame df.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 Let's fill the missing values at "status" column with defined condition by "salary"</strong></p>
#
#
# - **The following expression ``selects and accesses specific rows`` in the DataFrame ``based on a condition`` applied to the ``salary column``.**

# %%
# Select 'status' values where 'salary' is greater than or equal to 100

df.loc[df["salary"]>=100, "status"]
# Out:
# 3     FT
# 7    NaN
# 9     FT
# Name: status, dtype: object

# %% [markdown]
# - **``df["salary"] >= 100``**: This condition creates a boolean Series that is True for rows where the salary is greater than or equal to 100 and False otherwise.
# - **``df.loc[...]``**: The .loc method is used to access a group of rows and columns by labels or a boolean array.
# - **``"status"``**: This specifies that you want to select the status column for those rows that meet the condition.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The expression retrieves the status of employees whose salary is greater than or equal to 100.
# - The result is a Series containing the status values from the rows that meet the condition.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``selects and accesses specific rows`` in the DataFrame where the ``salary is less than 100``.**

# %%
# Select 'status' values where 'salary' is less than 100

df.loc[df["salary"]<100, "status"]
# Out:
# 1     PT
# 2    NaN
# 4     PT
# 5     PT
# 8     PT
# Name: status, dtype: object

# %% [markdown]
# - **``df["salary"] < 100``**: This condition creates a boolean Series that is True for rows where the salary is less than 100 and False otherwise.
# - **``df.loc[...]``**: The .loc method is used to access a group of rows and columns by labels or a boolean array.
# - **``"status"``**: This specifies that you want to select the status column for those rows that meet the condition.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The expression retrieves the status of employees whose salary is less than 100.
# - The result is a Series containing the status values from the rows that meet the condition.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expressions ``attempt to fill missing values (NaN)`` in the ``status`` column of the DataFrame, ``based on conditions`` applied to the ``salary`` column.**

# %%
# Fill NaN values for salary >= 100
df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0], inplace=True)

# Fill NaN values for salary < 100
df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0], inplace=True)

# Display the DataFrame
df  # inplace=True didn't work
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# Caveat
# Using inplace=True in this context may not behave as expected because fillna() returns a new Series when applied on a filtered DataFrame. Thus, the NaN values may not actually be filled in the original DataFrame.
#
# Correct Approach
# To ensure that the NaN values are filled correctly, you might want to assign the result back to the DataFrame. Here’s how you can do it:
# # To ensure that the NaN values are filled correctly, you might want to assign the result back to the DataFrame.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expressions ``fills missing values (NaN)`` in the ``status`` column of the DataFrame, ``based on conditions`` applied to the ``salary`` column.**

# %%
# Fill NaN values for salary >= 100
df.loc[df["salary"]>=100, "status"] = df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0])

# Fill NaN values for salary < 100
df.loc[df["salary"]<100, "status"] = df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0])

# Display the DataFrame
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 Let's fill the last missing value at "status" column with the mode of the group of "gender" and "dept"</strong></p>
#
#
# - **The following expression ``calculates the most frequently occurring value (mode)`` in the ``status column for each combination of gender and dept`` in the DataFrame.**

# %%
# Calculate the mode of 'status' for each combination of 'gender' and 'dept'

df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()[0])
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %% [markdown]
# - **``df.groupby(["gender", "dept"])``**: This groups the DataFrame by the unique combinations of gender and dept.
# - **``["status"]``**: This specifies that we want to focus on the status column within each group.
# - **``.apply(lambda x: x.mode()[0])``**: This applies a function to each group, where x represents the status values for that group. The mode() function finds the most frequently occurring value, and [0] retrieves the first mode (in case there are multiple modes).
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The results show the most common status for each combination of gender and dept.
# - The use of groupby combined with apply allows for efficient aggregation and analysis of categorical data.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills or creates a new Series`` where ``each entry in the status column`` is ``replaced with the most frequently occurring value (mode)`` for the ``corresponding group defined by gender and dept``.**

# %%
# Use transform to fill the status with the mode for each gender and dept combination

df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %% [markdown]
# - **``df.groupby(["gender", "dept"])``**: This groups the DataFrame by unique combinations of gender and dept.
# - **``["status"]``**: This specifies that we are focusing on the status column within each group.
# - **``.transform(lambda x: x.mode()[0])``**: The transform method applies a function to each group and returns a Series with the same index as the original DataFrame. The function lambda x: x.mode()[0] computes the mode of status for each group and returns that value for all rows in the group.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The new column status_filled contains the most common status for each unique combination of gender and dept.
# - The transform method allows you to maintain the original DataFrame's shape while filling in values based on group calculations.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``creates a new column`` in the DataFrame called trans_status.**
# - This new column will contain the most frequently occurring value (mode) of the status column for each combination of gender and dept.

# %%
# df["trans_status"] = df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()[0])
# TypeError: incompatible index of inserted column with frame index

# Create a new column 'trans_status' filled with the mode of 'status' for each gender and dept combination
df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])

# Display the modified DataFrame
df
# Out:
#       id gender status dept  var1  var2 salary trans_status
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT
# 1   P002      F     PT   FS   3.0   NaN     54           FT
# 2   P003      M     PT  AWS   5.0   5.0     59           PT
# 3   P004      F     FT  AWS   NaN   8.0    120           FT
# 4   P005      M     PT   DS   7.0  11.0     58           FT
# 5   P006      F     PT   DS   1.0   NaN     75           FT
# 6   P007      M     FT   FS   NaN   NaN   None           FT
# 7   P008      F     FT   FS  10.0   2.0    136           FT
# 8   P009      M     PT   FS  14.0   3.0     60           FT
# 9   P010      F     FT   DS   NaN   7.0    125           FT
# 10  P011      M    NaN  AWS   6.0   9.0    NaN           PT

# %% [markdown]
# - **``df.groupby(["gender", "dept"])``**: This groups the DataFrame by unique combinations of gender and dept.
# - **``["status"]``**: This specifies that we are focusing on the status column within each group.
# - **``.transform(lambda x: x.mode()[0])``**: The transform method applies a function to each group and returns a Series with the same index as the original DataFrame. The function lambda x: x.mode()[0] computes the mode of status for each group and returns that value for all rows in the group.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The new column trans_status contains the most common status for each unique combination of gender and dept.
# - If there are no valid modes (e.g., if all values in a group are NaN), the code handles it by checking if the mode is empty.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the ``status column`` of the DataFrame with the ``most frequently occurring value (mode)`` for ``each combination of gender and dept``.**

# %%
# Fill NaN values in the 'status' column with the mode for each gender and department combination

df["status"].fillna(df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0]), inplace=True)
# df["status"].fillna(df["trans_status"], inplace=True)

# Display the updated DataFrame
df
# Out:
#       id gender status dept  var1  var2 salary trans_status
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT
# 1   P002      F     PT   FS   3.0   NaN     54           FT
# 2   P003      M     PT  AWS   5.0   5.0     59           PT
# 3   P004      F     FT  AWS   NaN   8.0    120           FT
# 4   P005      M     PT   DS   7.0  11.0     58           FT
# 5   P006      F     PT   DS   1.0   NaN     75           FT
# 6   P007      M     FT   FS   NaN   NaN   None           FT
# 7   P008      F     FT   FS  10.0   2.0    136           FT
# 8   P009      M     PT   FS  14.0   3.0     60           FT
# 9   P010      F     FT   DS   NaN   7.0    125           FT
# 10  P011      M     PT  AWS   6.0   9.0    NaN           PT

# %% [markdown]
# - **``df.groupby(["gender", "dept"])``**: This groups the DataFrame by unique combinations of gender and dept.
# - **``["status"]``**: This specifies that we are focusing on the status column within each group.
# - **``.transform(lambda x: x.mode()[0])``**: The transform method applies a function to each group. The function lambda x: x.mode()[0] computes the mode of status for each group and returns that value for all rows in the group. This creates a Series where each entry corresponds to the mode for its respective group.
# - **``.fillna(...)``**: This method fills NaN values in the status column with the values obtained from the transform operation.
# - **``inplace=True``**: This modifies the original DataFrame directly.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The NaN values in the status column are filled with the most common status for each unique combination of gender and dept.
# - The use of transform allows for an efficient and straightforward way to fill missing values based on group statistics while maintaining the DataFrame's structure.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# # Where we LEFT

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 Let's fill the missing values at "salary" column with the mean of the group of "status" and "dept"</strong></p>
#
#
# - **The following expression ``calculates the average (mean) salary for each department`` in the DataFrame.**

# %%
# Calculate the average salary for each department

df.groupby("dept")["salary"].mean()
# Out:
# dept
# AWS         89.5
# DS          86.0
# FS     83.333333
# Name: salary, dtype: object

# %% [markdown]
# - **``df.groupby("dept")``**: This groups the DataFrame by the unique values in the dept column.
# - **``["salary"]``**: This specifies that we are interested in the salary column within each group.
# - **``.mean()``**: This calculates the average salary for each department.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The output shows the average salary for each department in the DataFrame.
# - The groupby method allows for easy aggregation of data based on categorical variables.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the average (mean) salary for each combination of status and dept`` in the DataFrame.**

# %%
# Calculate the average salary for each combination of status and department

df.groupby(["status", "dept"])["salary"].mean()
# Out:
# status  dept
# FT      AWS     120.0
#         DS      125.0
#         FS      136.0
# PT      AWS      59.0
#         DS       66.5
#         FS       57.0
# Name: salary, dtype: object

# %% [markdown]
# - **``df.groupby(["status", "dept"])``**: This groups the DataFrame by unique combinations of the status and dept columns.
# - **``["salary"]``**: This specifies that we are focusing on the salary column within each group.
# - **``.mean()``**: This calculates the average salary for each combination of status and dept.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the average (mean) salary for each combination of status and dept``, and then it assigns that mean value back to each row in the original DataFrame.**

# %%
# Calculate the average salary for each combination of status and department

df.groupby(["status", "dept"])["salary"].transform("mean")
# Out:
# 0     125.0
# 1      57.0
# 2      59.0
# 3     120.0
# 4      66.5
# 5      66.5
# 6     136.0
# 7     136.0
# 8      57.0
# 9     125.0
# 10     59.0
# Name: salary, dtype: object

# %% [markdown]
# - **``df.groupby(["status", "dept"])``**: This groups the DataFrame by unique combinations of the status and dept columns.
# - **``["salary"]``**: This specifies that we are focusing on the salary column.
# - **``.transform("mean")``**: The transform method computes the mean salary for each group but returns a Series with the same index as the original DataFrame. This means each row will have the mean salary corresponding to its group.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The new column mean_salary contains the average salary for each unique combination of status and dept, with each row reflecting the appropriate mean value based on its group.
# - The transform method allows you to enrich the original DataFrame with aggregated information while maintaining the same shape.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``creates a new column`` in the DataFrame called trans_salary.**
# - This new column will contain the average (mean) salary for each combination of status and dept, effectively reflecting the mean salary for the respective group in each row.

# %%
# Create a new column 'trans_salary' with the mean salary for each combination of status and department
df["trans_salary"] = df.groupby(["status","dept"])["salary"].transform("mean")


df
# Out:
#       id gender status dept  var1  var2 salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT        125.0
# 1   P002      F     PT   FS   3.0   NaN     54           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.0     59           PT         59.0
# 3   P004      F     FT  AWS   NaN   8.0    120           FT        120.0
# 4   P005      M     PT   DS   7.0  11.0     58           FT         66.5
# 5   P006      F     PT   DS   1.0   NaN     75           FT         66.5
# 6   P007      M     FT   FS   NaN   NaN   None           FT        136.0
# 7   P008      F     FT   FS  10.0   2.0    136           FT        136.0
# 8   P009      M     PT   FS  14.0   3.0     60           FT         57.0
# 9   P010      F     FT   DS   NaN   7.0    125           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.0    NaN           PT         59.0

# %% [markdown]
# - **``df.groupby(["status", "dept"])``**: This groups the DataFrame by unique combinations of the status and dept columns.
# - **``["salary"]``**: This specifies that we are focusing on the salary column.
# - **``.transform("mean")``**: The transform method computes the mean salary for each group and returns a Series with the same index as the original DataFrame. This means that each row will have the mean salary corresponding to its group.
# - **``df["trans_salary"] = ...``**: This assigns the resulting Series to a new column trans_salary in the original DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The new column mean_salary contains the average salary for each unique combination of status and dept, with each row reflecting the appropriate mean value based on its group.
# - The transform method allows you to enrich the original DataFrame with aggregated information while maintaining the same shape.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the ``salary column`` of the DataFrame with the ``average (mean) salary for each combination of status and dept``.**

# %%
# Fill NaN values in the 'salary' column with the mean salary for each combination of status and department

df["salary"].fillna(df.groupby(["status", "dept"])["salary"].transform("mean"), inplace=True)
# df["salary"].fillna(df["trans_salary"], inplace=True)


df
# Out:
#       id gender status dept  var1  var2  salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT        125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT         59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT        120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT         66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT         66.5
# 6   P007      M     FT   FS   NaN   NaN   136.0           FT        136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT        136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT         57.0
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT         59.0

# %% [markdown]
# - **``df.groupby(["status", "dept"])``**: This groups the DataFrame by unique combinations of the status and dept columns.
# - **``["salary"]``**: This specifies that we are focusing on the salary column within each group.
# - **``.transform("mean")``**: The transform method computes the mean salary for each group and returns a Series that aligns with the original DataFrame's index. This means each row will have the average salary for its corresponding group.
# - **``df["salary"].fillna(...)``**: This method fills NaN values in the salary column with the values obtained from the transform operation.
# - **``inplace=True``**: This modifies the original DataFrame directly, updating the salary column.
#
# In this example:
#
# - The NaN values in the salary column are filled with the mean salary for each unique combination of status and dept.
# - The use of transform allows for filling missing values based on group-level statistics while maintaining the original DataFrame structure.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 Let's fill the missing values at "var1" column with the mean of the group of "gender" and "status"</strong></p>
#
#
# - **The following expression ``calculates the average (mean)`` of the ``var1 column for each combination of gender and status`` in the DataFrame.**

# %%
# Calculate the mean of 'var1' for each combination of gender and status

df.groupby(["gender", "status"])["var1"].mean(numeric_only=True)
# Out:
# gender  status
# F       FT        10.0
#         PT         2.0
# M       FT         2.0
#         PT         8.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``df.groupby(["gender", "status"])``**: This groups the DataFrame by unique combinations of the gender and status columns.
# - **``["var1"]``**: This specifies that we want to focus on the var1 column within each group.
# - **``.mean(numeric_only=True)``**: This calculates the mean of var1 for each group. The numeric_only=True parameter ensures that only numeric values are considered, which is useful if var1 contains mixed data types.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The output shows the average of var1 for each unique combination of gender and status.
# - The numeric_only=True parameter ensures that any non-numeric values in var1 are ignored when calculating the mean.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the average (mean)`` of the ``var1 column for each combination of gender and status``, and then it assigns that mean value back to each row in the original DataFrame.**

# %%
# Calculate the mean of 'var1' for each combination of gender and status

df.groupby(["gender","status"])["var1"].transform("mean")
# Out:
# 0      2.0
# 1      2.0
# 2      8.0
# 3     10.0
# 4      8.0
# 5      2.0
# 6      2.0
# 7     10.0
# 8      8.0
# 9     10.0
# 10     8.0
# Name: var1, dtype: float64

# %% [markdown]
# - **``df.groupby(["gender", "status"])``**: This groups the DataFrame by unique combinations of the gender and status columns.
# - **``["var1"]``**: This specifies that we are focusing on the var1 column within each group.
# - **``.transform("mean")``**: The transform method calculates the mean for each group and returns a Series with the same index as the original DataFrame, meaning each row will have the mean value corresponding to its group.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The new column mean_var1 contains the average of var1 for each unique combination of gender and status.
# - The use of transform allows you to enrich the original DataFrame with group-level statistics while maintaining the same shape.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the average (mean)`` of the ``var1 column for each combination of gender and status``, and it assigns that mean value to a new variable trans_var1.**

# %%
# Calculate the mean of 'var1' for each combination of gender and status 

trans_var1 = df.groupby(["gender", "status"])["var1"].transform("mean")

# %% [markdown]
# - **``df.groupby(["gender", "status"])``**: This groups the DataFrame by unique combinations of the gender and status columns.
# - **``["var1"]``**: This specifies that we are focusing on the var1 column within each group.
# - **``.transform("mean")``**: The transform method calculates the mean for each group and returns a Series that aligns with the original DataFrame's index. This means that each row in trans_var1 will have the mean value corresponding to its group.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The variable trans_var1 contains the average of var1 for each unique combination of gender and status.
# - The new column mean_var1 in the DataFrame reflects these mean values, enriching the data with group-level insights.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills the missing values (NaN)`` in the ``var1 column`` of the DataFrame with the ``corresponding mean values calculated earlier in trans_var1``.**
# - This approach ensures that each NaN in var1 is replaced with the mean value for its specific group defined by the gender and status columns.

# %%
# Fill NaN values in 'var1' with the corresponding mean values in trans_var1
df["var1"].fillna(trans_var1, inplace=True)


df
# Out:
#       id gender status dept  var1  var2  salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT        125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT         59.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0           FT        120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT         66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT         66.5
# 6   P007      M     FT   FS   2.0   NaN   136.0           FT        136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT        136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT         57.0
# 9   P010      F     FT   DS  10.0   7.0   125.0           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT         59.0

# %% [markdown]
# - **``df["var1"]``**: This refers to the var1 column in the DataFrame.
# - **``.fillna(trans_var1, inplace=True)``**: The fillna method replaces NaN values in var1 with the values from trans_var1. - **``The inplace=True``** parameter modifies the original DataFrame directly.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The NaN value in var1 has been filled with the mean of var1 for the corresponding group of gender and status.
# - The fillna method allows for efficient handling of missing data, improving data completeness for subsequent analyses.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# **Let's fill the missing values at "var2" column with the mean of group of "status"**

# %%
# Retrieve the 'var2' column

df["var2"]
# Out:
# 0      8.0
# 1      NaN
# 2      5.0
# 3      8.0
# 4     11.0
# 5      NaN
# 6      NaN
# 7      2.0
# 8      3.0
# 9      7.0
# 10     9.0
# Name: var2, dtype: float64

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the average (mean)`` of the ``var2 column for each unique value in the status column`` of the DataFrame.**

# %%
# Calculate the mean of 'var2' for each unique value in 'status'

df.groupby(["status"])["var2"].mean(numeric_only=True)
# Out:
# status
# FT    6.25
# PT    7.00
# Name: var2, dtype: float64

# %% [markdown]
# - **``df.groupby(["status"])``**: This groups the DataFrame by the unique values in the status column.
# - **``["var2"]``**: This specifies that we are focusing on the var2 column within each group.
# - **``.mean(numeric_only=True)``**: This calculates the mean of var2 for each group. The numeric_only=True parameter ensures that only numeric values are considered, which is particularly useful if var2 contains mixed data types.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The output shows the average of var2 for each unique value in the status column.
# - This approach allows you to analyze how a specific variable varies across different categories or groups within your DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``calculates the average (mean)`` of the ``var2 column for each unique value in the status column`` and assigns that mean value to each row in a new variable called trans_var2.**
# - This allows each row to reflect the average value of var2 for its respective group.

# %%
# Calculate the mean of 'var2' for each unique value in 'status'
trans_var2 = df.groupby(["status"])["var2"].transform("mean")


trans_var2
# Out:
# 0     6.25
# 1     7.00
# 2     7.00
# 3     6.25
# 4     7.00
# 5     7.00
# 6     6.25
# 7     6.25
# 8     7.00
# 9     6.25
# 10    7.00
# Name: var2, dtype: float64

# %% [markdown]
# - **``df.groupby(["status"])``**: Groups the DataFrame by unique values in the status column.
# - **``["var2"]``**: Focuses on the var2 column within each group.
# - **``.transform("mean")``**: Computes the mean for each group and returns a Series that aligns with the original DataFrame's index, allowing you to assign it back to the DataFrame or use it for further calculations.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>👉🏾 In this example:</strong></p>
#
# - The variable trans_var2 contains the mean of var2 for each unique value in the status column.
# - The new column mean_var2 reflects these mean values, providing insights into the data by showing how var2 averages differ by status.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``fills missing values (NaN)`` in the ``var2 column`` of the DataFrame with the ``corresponding mean values calculated in trans_var2``.**
# - This ensures that each NaN in var2 is replaced with the mean value for its specific group defined by the status column.

# %%
# Fill NaN values in 'var2' with the corresponding mean values in "trans_var2"

df["var2"].fillna(trans_var2, inplace=True)

# %% [markdown]
# - **``df["var2"]``**: This refers to the var2 column in the DataFrame.
# - **``.fillna(trans_var2, inplace=True)``**: The fillna method replaces NaN values in var2 with the values from trans_var2. - **``The inplace=True``** parameter modifies the original DataFrame directly.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Display the modified DataFrame

df
# Out:
#       id gender status dept  var1   var2  salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.00   125.0           FT        125.0
# 1   P002      F     PT   FS   3.0   7.00    54.0           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.00    59.0           PT         59.0
# 3   P004      F     FT  AWS  10.0   8.00   120.0           FT        120.0
# 4   P005      M     PT   DS   7.0  11.00    58.0           FT         66.5
# 5   P006      F     PT   DS   1.0   7.00    75.0           FT         66.5
# 6   P007      M     FT   FS   2.0   6.25   136.0           FT        136.0
# 7   P008      F     FT   FS  10.0   2.00   136.0           FT        136.0
# 8   P009      M     PT   FS  14.0   3.00    60.0           FT         57.0
# 9   P010      F     FT   DS  10.0   7.00   125.0           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.00    59.0           PT         59.0

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# ### <p style="background-color:#FFFFFF; font-family:newtimeroman; color:blue; font-size:120%; text-align:left;"><strong>e. Filling with Interpolation:</strong></p>
#
#
# The phrase **``"Interpolating missing values"``** refers to the **``process of estimating and filling in missing data points in a dataset based on the values surrounding them``**. This is particularly useful in datasets where values are expected to change in a ``continuous manner``, such as ``time series data`` or ``measurements taken at regular intervals``.
#
# Pandas **``dataframe.interpolate()``** function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value [Source 01](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/), [Source 02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html) & [Source 03](https://note.nkmk.me/en/python-pandas-interpolate/)
#
# - **``Key Concepts of Interpolation:``**
#    - **``Estimation``**: Interpolation uses existing data points to estimate values at missing points. This helps maintain the integrity of the dataset without introducing arbitrary values.
#    - **``Methods``**: Various methods can be used for interpolation, including:
#    - **``Linear Interpolation``**: Estimates the missing value by connecting two known points with a straight line.
#    - **``Polynomial Interpolation``**: Fits a polynomial curve to the known data points to estimate missing values.
#    - **``Spline Interpolation``**: Uses piecewise polynomials (splines) to create a smooth curve that passes through known data points.
#    - **``Time-based Interpolation``**: In time series data, methods can take into account the time dimension for more accurate estimates.
# - **``Applications``**: Interpolation is commonly used in:
#    - **``Data Cleaning``**: Filling gaps in datasets before analysis.
#    - **``Signal Processing``**: Estimating missing readings in sensor data.
#    - **``Economics and Finance``**: Filling in missing economic indicators or stock prices.

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``loads the "flights" dataset from the Seaborn library``, which is a popular data visualization library in Python.**
# - The "flights" dataset contains information about airline flights, including details such as the year, month, number of passengers, and more.

# %%
# Load the DataFrame
flights = sns.load_dataset("flights")

# Display the DataFrame
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# The flights dataset contains three columns: **``year``**, **``month``**, and **``passengers``**, which provide **``insights into the number of airline passengers over time``**.
#
#
# - **``sns``**: This refers to the Seaborn library, which you need to import first.
# - **``load_dataset("flights")``**: This function loads the specified dataset. In this case, "flights" refers to a built-in dataset provided by Seaborn.
#
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``checks for missing values (NaN)`` in the flights DataFrame.**

# %%
# Check for missing values in the dataset

flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %% [markdown]
# - **``flights.isnull()``**: This method returns a DataFrame of the same shape as flights, where each entry is True if the corresponding entry in flights is NaN (missing) and False otherwise.
# - **``.sum()``**: This method sums up the True values (which are treated as 1) for each column, effectively counting the number of missing values in each column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``creates a plot of the passengers`` column in the flights DataFrame using the Pandas plotting capabilities.**
# - This will generally produce a line plot that visualizes the number of passengers over time (by month and year).

# %%
# you don't need to know how this plotting happens.
# just focus on the time-series line

# Create a figure with a specified size
plt.figure(figsize=(12, 5))  # Width: 12 inches, Height: 6 inches

# Plot the number of passengers over time
flights.passengers.plot(title='Number of Passengers Over Time', xlabel='Time', ylabel='Number of Passengers')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``creates a shallow copy`` of the flights DataFrame and assigns it to the variable flights_copy.**
# - This means that flights_copy contains the same data as flights, but **``any modifications made to flights_copy will NOT affect the original flights DataFrame``**.

# %%
# Create a copy of the flights DataFrame

flights_copy = flights.copy()

# %% [markdown]
# - **``flights``**: This is the original DataFrame containing the flights dataset.
# - **``.copy()``**: This method creates a new DataFrame that is a copy of the original. It ensures that changes to the new DataFrame do not impact the original DataFrame.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``randomly assigns None (or NaN) values to 20 randomly selected rows`` in the passengers column of the flights_copy DataFrame.**

# %%
# Randomly assign None to 20 rows in the 'passengers' column

flights_copy.loc[np.random.randint(1, 144, 20),"passengers"] = None

# %% [markdown]
# - **``np.random.randint(1, 144, 20)``**: This generates 20 random integers between 1 and 143 (the range is exclusive of the upper bound). This is assuming the flights dataset has 144 rows (you can adjust this based on the actual number of rows in your dataset).
# - **``flights_copy.loc[...]``**: The .loc indexer is used to access a group of rows and columns by labels or a boolean array.
# "passengers": This specifies the column in which you want to assign the None values.
# - **``= None``**: This assigns None (which will be treated as NaN in a Pandas DataFrame) to the selected rows in the passengers column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following expression ``checks for missing values (NaN)`` in the flights_copy DataFrame.**
# - It returns the **``count of missing values for each column``** in the DataFrame.

# %%
# Check for missing values in the copied DataFrame

flights_copy.isnull().sum()
# Out:
# year           0
# month          0
# passengers    18
# dtype: int64

# %% [markdown]
# This output indicates that the **``year``** and **``month``** columns have **``NO missing values``**, while the **``passengers``** column has **``some missing values``** due to the assignment of None in earlier steps.
#
# - **``flights_copy.isnull()``**: This method returns a DataFrame of the same shape as flights_copy, where each entry is True if the corresponding entry is NaN (missing) and False otherwise.
# - **``.sum()``**: This method sums up the True values (which are treated as 1) for each column, effectively counting the number of missing values in each column.
#
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>
#
# **The following code will ``generate a line plot`` that visualizes the ``number of passengers over time``, with the x-axis typically representing the time (months and years) and the y-axis showing the number of passengers.**

# %%
# Create a figure with a specified size
plt.figure(figsize=(12, 5))  # Width: 12 inches, Height: 6 inches

# Plot the number of passengers over time
flights_copy.passengers.plot(title='Number of Passengers Over Time', xlabel='Time', ylabel='Number of Passengers')

# Display the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Create a figure with a specific size
plt.figure(figsize=(12, 5))

# Plot the passengers data with interpolation for missing values
flights_copy["passengers"].interpolate().plot(kind="line", 
                                              title='Interpolated Number of Passengers Over Time', 
                                              xlabel='Time',
                                              ylabel='Passengers')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Create a figure with a specified size
plt.figure(figsize=(12, 5))  # Width: 12 inches, Height: 6 inches

# Plot the number of passengers over time
flights.passengers.plot(title='Number of Passengers Over Time', xlabel='Time', ylabel='Number of Passengers')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %%
# Create a figure with a specified size
plt.figure(figsize=(12, 5))  # Width: 12 inches, Height: 6 inches

# Plot the number of passengers over time
flights_copy["passengers"].fillna(method="ffill").plot(title='Number of Passengers Over Time', 
                                                       xlabel='Time', 
                                                       ylabel='Number of Passengers')

# Show the plot
plt.show()

# %% [markdown]
# <p style="background-color:#FFFFFF; font-family:newtimeroman; color:#0000FF; font-size:110%; text-align:left;"><strong>-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------</strong></p>

# %% [markdown]
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#E51A59; font-size:150%; text-align:center; border-radius:10px 10px;">End of the Session - 07</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/TtRtYNn/healthy-lunch.jpg" width="800" height="200" class="img-fluid" alt="Lunch Time"></p>
#
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY"></p>
#
#
# <br><br><br>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="450" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>
